# %% [markdown]
# # 🧪 Prompt Engineering Lab with Gemini API — Enhanced Edition
#
# ## 📚 Lab Overview & Learning Objectives
#
# Lab นี้ออกแบบมาเพื่อให้ผู้เรียนได้ฝึกฝนเทคนิค Prompt Engineering ขั้นสูงผ่าน Gemini API โดยเริ่มจากพื้นฐานไปจนถึงเทคนิคขั้นสูง พร้อมระบบ Evaluation ที่ครบถ้วน
#
# ---
#
# ## 🗺️ Lab Roadmap — ภาพรวมเส้นทางการเรียนรู้
#
# ```
# ╔══════════════════════════════════════════════════════════════════════════════════╗
# ║                    🗺️ PROMPT ENGINEERING LEARNING PATH                         ║
# ╠══════════════════════════════════════════════════════════════════════════════════╣
# ║                                                                                ║
# ║  🟢 FOUNDATION (Part 0-2)                                                      ║
# ║  ┌─────────────┐    ┌─────────────────┐    ┌──────────────────┐                ║
# ║  │  Part 0     │───▶│   Part 1        │───▶│   Part 2         │                ║
# ║  │  Setup &    │    │   Few-shot      │    │   Chain-of-      │                ║
# ║  │  Connection │    │   Prompting ⭐   │    │   Thought ⭐⭐    │                ║
# ║  └─────────────┘    └─────────────────┘    └────────┬─────────┘                ║
# ║                                                      │                          ║
# ║  🟡 INTERMEDIATE (Part 3-4)                          ▼                          ║
# ║  ┌─────────────────────────┐    ┌──────────────────────────┐                   ║
# ║  │   Part 3                │    │   Part 4                 │                   ║
# ║  │   Self-Consistency      │◄──▶│   Prompt Chaining        │                   ║
# ║  │   CoT ⭐⭐⭐              │    │   ⭐⭐⭐                    │                   ║
# ║  └────────────┬────────────┘    └────────────┬─────────────┘                   ║
# ║               │                               │                                 ║
# ║  🟠 ADVANCED (Part 5-8)     ▼               ▼                                 ║
# ║  ┌──────────────────┐  ┌──────────────────┐  ┌──────────────────┐              ║
# ║  │   Part 5         │  │   Part 6         │  │   Part 7         │              ║
# ║  │   Reflection     │  │   Tree-of-       │  │   Self-Feedback  │              ║
# ║  │   ⭐⭐⭐⭐          │  │   Thought ⭐⭐⭐⭐⭐ │  │   ⭐⭐⭐⭐          │              ║
# ║  └────────┬─────────┘  └────────┬─────────┘  └────────┬─────────┘              ║
# ║           │                     │                      │                        ║
# ║           └─────────────────────┼──────────────────────┘                        ║
# ║                                 ▼                                               ║
# ║                      ┌──────────────────┐                                       ║
# ║                      │   Part 8         │                                       ║
# ║                      │   Self-Critique  │                                       ║
# ║                      │   ⭐⭐⭐⭐⭐         │                                       ║
# ║                      └────────┬─────────┘                                       ║
# ║                               │                                                 ║
# ║  🔴 EVALUATION (Part 9-10)    ▼                                                ║
# ║  ┌──────────────────────────────────────────────────┐                           ║
# ║  │   Part 9-10: Evaluation Methods                  │                           ║
# ║  │   • LLM-as-a-Judge    • Reference-free           │                           ║
# ║  │   • Pairwise          • BLEU/ROUGE               │                           ║
# ║  │   • Rubric-based      • Semantic Similarity      │                           ║
# ║  │   • Hallucination Detection                      │                           ║
# ║  └────────────────────────┬─────────────────────────┘                           ║
# ║                           ▼                                                     ║
# ║  🏆 CAPSTONE (Part 11)                                                          ║
# ║  ┌──────────────────────────────────────────────────┐                           ║
# ║  │   Part 11: Final Challenge                       │                           ║
# ║  │   Combined All Techniques + Full Evaluation      │                           ║
# ║  └──────────────────────────────────────────────────┘                           ║
# ║                                                                                ║
# ╚══════════════════════════════════════════════════════════════════════════════════╝
# ```
#
# ---
#
# ## 🧠 Prompt Engineering — ทำไมถึงสำคัญ?
#
# ### ปัญหาที่ Prompt Engineering แก้ได้
#
# ```
# ╔═══════════════════════════════════════════════════════════════════╗
# ║              🎯 WHY PROMPT ENGINEERING MATTERS                   ║
# ╠═══════════════════════════════════════════════════════════════════╣
# ║                                                                   ║
# ║  ❌ ปัญหาเมื่อไม่ใช้เทคนิค          ✅ เมื่อใช้เทคนิคที่ถูกต้อง  ║
# ║  ┌─────────────────────┐         ┌─────────────────────────┐     ║
# ║  │ • คำตอบไม่ตรงประเด็น │         │ • คำตอบแม่นยำ ตรงจุด    │     ║
# ║  │ • ขาดความสม่ำเสมอ   │   ───▶  │ • Output สม่ำเสมอ       │     ║
# ║  │ • มี Hallucination  │         │ • ลด Hallucination      │     ║
# ║  │ • ขาดเหตุผลรองรับ   │         │ • มี Reasoning ชัดเจน   │     ║
# ║  │ • ไม่สามารถทำงาน    │         │ • ทำงานซับซ้อนได้       │     ║
# ║  │   ซับซ้อนได้         │         │ • ประเมินคุณภาพได้      │     ║
# ║  └─────────────────────┘         └─────────────────────────┘     ║
# ║                                                                   ║
# ║  📊 ผลวิจัย: Few-shot + CoT ช่วยเพิ่มความถูกต้องได้ 40-70%      ║
# ║     ในงาน Reasoning (Wei et al., 2022)                           ║
# ╚═══════════════════════════════════════════════════════════════════╝
# ```
#
#
# ### Temperature & Sampling — ผลต่อ Output
#
# ```
# ╔══════════════════════════════════════════════════════════════╗
# ║          🌡️ TEMPERATURE EFFECT ON OUTPUT                     ║
# ╠══════════════════════════════════════════════════════════════╣
# ║                                                              ║
# ║  Temperature = 0.0 (Deterministic)                           ║
# ║  ┌─────────────────────────────────────────────┐            ║
# ║  │ █████████████████████████░░░░░░░░░░░░░░░░░░ │ "แมว"      ║
# ║  │ ██░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ │ "สุนัข"    ║
# ║  │ ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ │ "นก"       ║
# ║  └─────────────────────────────────────────────┘            ║
# ║  → เลือก "แมว" เสมอ (ผลลัพธ์เหมือนเดิมทุกครั้ง)             ║
# ║  → เหมาะกับ: Factual Q&A, Math, Classification              ║
# ║                                                              ║
# ║  Temperature = 0.7 (Balanced)                                ║
# ║  ┌─────────────────────────────────────────────┐            ║
# ║  │ █████████████████░░░░░░░░░░░░░░░░░░░░░░░░░░ │ "แมว"      ║
# ║  │ ██████████░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ │ "สุนัข"    ║
# ║  │ █████░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ │ "นก"       ║
# ║  └─────────────────────────────────────────────┘            ║
# ║  → มีโอกาสเลือกทุกตัว (น้ำหนักตามความน่าจะเป็น)             ║
# ║  → เหมาะกับ: Creative writing, Brainstorming                ║
# ║                                                              ║
# ║  Temperature = 1.5 (Very Creative)                           ║
# ║  ┌─────────────────────────────────────────────┐            ║
# ║  │ █████████░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ │ "แมว"      ║
# ║  │ ████████░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ │ "สุนัข"    ║
# ║  │ ███████░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ │ "นก"       ║
# ║  └─────────────────────────────────────────────┘            ║
# ║  → ความน่าจะเป็นเกือบเท่ากัน (สุ่มมาก อาจไม่ make sense)   ║
# ║  → ⚠️ ระวัง: อาจได้ output ที่ไม่สอดคล้อง                    ║
# ╚══════════════════════════════════════════════════════════════╝
# ```
#
# ---
#
# ```python

# %% [markdown]
# # 🧪 Prompt Engineering Advanced Lab with Gemini API
# # Enhanced Edition — with Extended Theory, Infographics & Evaluation
#
# ## 📋 Lab Description
# Lab นี้จะพาคุณเรียนรู้เทคนิค Prompt Engineering ขั้นสูงทั้ง 8 เทคนิค:
# 1. Few-shot Prompting
# 2. Chain-of-Thought (CoT)
# 3. Self-consistency Chain-of-Thought
# 4. Prompt Chaining
# 5. Reflection
# 6. Tree-of-Thought (ToT)
# 7. Self-feedback
# 8. Self-critique
#
# พร้อมระบบ Evaluation ขั้นสูง:
# - LLM-as-a-Judge (Single & Pairwise)
# - Reference-free Evaluation
# - Rubric-based Scoring
# - BLEU / ROUGE Score (Automated Metrics)
# - Semantic Similarity
# - Hallucination Detection
# - Multi-dimensional Evaluation Framework
#
# ## 🎯 Learning Outcomes
# - เข้าใจและประยุกต์ใช้เทคนิค Prompt Engineering ขั้นสูง
# - เปรียบเทียบข้อดี-ข้อเสียของแต่ละเทคนิค
# - สามารถเลือกเทคนิคที่เหมาะสมกับปัญหาต่างๆ
# - ประเมินคุณภาพ Output ด้วยวิธีการที่เป็นระบบและหลากหลาย

# %% [markdown]
# ---
# # 🔧 Part 0: Environment Setup
# ---
#
# ## 📖 ทฤษฎีพื้นฐาน: Gemini API
#
# **Gemini** คือ Large Language Model (LLM) จาก Google DeepMind
# ที่รองรับทั้ง text, image, audio, video (Multimodal)
#
# ### API Parameters ที่ควรรู้:
# ```
# ┌────────────────────┬───────────────────────────────────────┐
# │ Parameter          │ คำอธิบาย                              │
# ├────────────────────┼───────────────────────────────────────┤
# │ temperature        │ ความสุ่มของ output (0.0 - 2.0)       │
# │                    │ 0.0 = deterministic, 1.0+ = creative │
# │ top_p              │ Nucleus sampling threshold            │
# │ top_k              │ จำนวน tokens ที่พิจารณา              │
# │ max_output_tokens  │ จำนวน tokens สูงสุดใน response       │
# │ stop_sequences     │ token ที่หยุดสร้าง output            │
# └────────────────────┴───────────────────────────────────────┘
# ```
#
# ### เมื่อไหร่ใช้ Parameter ใด:
# ```
# 📊 Task ต้องการความแม่นยำ (Math, Classification):
#    → temperature = 0.0-0.2, top_p = 0.8
#
# ✍️ Task ต้องการความคิดสร้างสรรค์ (Writing, Brainstorming):
#    → temperature = 0.7-1.0, top_p = 0.95
#
# 🔄 Task ต้องการความหลากหลาย (Self-Consistency):
#    → temperature = 0.7-1.0 (ต้องการ diverse outputs)
# ```

# %%
# ติดตั้ง Library ที่จำเป็น
# !pip install google-genai
# Out:
# Requirement already satisfied: google-genai in /opt/venv/lib/python3.13/site-packages (1.62.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /opt/venv/lib/python3.13/site-packages (from google-genai) (4.12.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in /opt/venv/lib/python3.13/site-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai) (2.48.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /opt/venv/lib/python3.13/site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /opt/venv/lib/python3.13/site-packages (from google-genai) (2.12.5)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /opt/venv/lib/python3.13/site-packages (from google-genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /opt/venv/lib/python3.13/site-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /opt/venv/lib/python3.13/site-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /opt/venv/lib/python3.13/site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/venv/lib/python3.13/site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /opt/venv/lib/python3.13/site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /opt/venv/lib/python3.13/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/venv/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /opt/venv/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (46.0.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/venv/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (4.9.1)
# Requirement already satisfied: certifi in /opt/venv/lib/python3.13/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /opt/venv/lib/python3.13/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/venv/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (0.6.1)
# Requirement already satisfied: cffi>=2.0.0 in /opt/venv/lib/python3.13/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in /opt/venv/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (2.23)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Import Libraries
from google import genai
from google.genai import types
import json
import time
import re
import math
from typing import List, Dict, Any, Tuple, Optional
from collections import Counter

# %% [markdown]
# # 🔑 วิธีการขอ API Key จาก Google Gemini
#
# ## 📌 ขั้นตอนการขอ API Key
#
# ### ขั้นตอนที่ 1: เข้าสู่ Google AI Studio
#
# 1. เปิดเว็บเบราว์เซอร์แล้วไปที่ **[Google AI Studio](https://aistudio.google.com/)**
# 2. ลงชื่อเข้าใช้ด้วย **Google Account** ของคุณ
#
#
# ---
#
# ### ขั้นตอนที่ 2: สร้าง API Key
#
# 1. คลิกที่เมนู **"Get API Key"** (รับ API Key) ที่แถบด้านซ้าย
# 2. คลิกปุ่ม **"Create API Key"**
# 3. เลือก Google Cloud Project ที่ต้องการ (หรือสร้างใหม่)
# 4. ระบบจะสร้าง API Key ให้โดยอัตโนมัติ
#
# ---
#
# ### ขั้นตอนที่ 3: คัดลอก API Key
#
# 1. เมื่อได้ API Key แล้ว ให้คลิกปุ่ม **"Copy"** เพื่อคัดลอก
# 2. **⚠️ สำคัญ:** เก็บ API Key ไว้ในที่ปลอดภัย อย่าแชร์ให้ผู้อื่น

# %%
# กำหนด API Key และ Model
API_KEY = "Key"  # ใส่ API Key ของคุณ
MODEL_NAME = "gemini-2.0-flash"

# สร้าง Client
client = genai.Client(api_key=API_KEY)

# %%
# ทดสอบ Connection
response = client.models.generate_content(
    model=MODEL_NAME,
    contents="สวัสดี! ตอบสั้นๆ ว่าคุณพร้อมทำงานแล้ว"
)
print("✅ Connection Test:", response.text)
# Out:
# ✅ Connection Test: พร้อม!

# %%
# === Helper Function สำหรับใช้ตลอดทั้ง Lab ===

def call_gemini(prompt: str, temperature: float = 0.0, max_tokens: int = 2048) -> str:
    """Helper function สำหรับเรียก Gemini API"""
    response = client.models.generate_content(
        model=MODEL_NAME,
        contents=prompt,
        config=types.GenerateContentConfig(
            temperature=temperature,
            max_output_tokens=max_tokens,
        )
    )
    return response.text

def print_section(title: str, content: str, emoji: str = "🔹"):
    """Helper function สำหรับแสดงผลแบบสวยงาม"""
    print(f"\n{emoji} {title}")
    print("─" * 50)
    print(content)
    print("─" * 50)

# %% [markdown]
# ---
# # 📘 Part 1: Few-shot Prompting
# **ระดับความยาก: ⭐ (เริ่มต้น)**
#
# ---
# ## 📖 ทฤษฎีเชิงลึก
#
# **Few-shot Prompting** คือเทคนิคที่ให้ตัวอย่าง (examples) จำนวนหนึ่งใน prompt
# เพื่อช่วยให้ LLM เข้าใจรูปแบบและ pattern ที่ต้องการ
#
# ### 📊 Infographic: สเปกตรัมของ Shot Types
#
# ```
# ┌──────────────────────────────────────────────────────────────────────┐
# │                    📊 SHOT SPECTRUM                                  │
# │                                                                      │
# │  Zero-shot        One-shot        Few-shot        Many-shot         │
# │  (0 examples)     (1 example)     (2-5 examples)  (6+ examples)    │
# │                                                                      │
# │  ○────────────────●────────────────●────────────────●──────▶        │
# │                                                                      │
# │  Flexibility ◄─────────────────────────────────── Consistency       │
# │  HIGH                                              HIGH              │
# │                                                                      │
# │  Best for:        Best for:       Best for:        Best for:        │
# │  - Simple tasks   - Quick demo    - Complex format - Very specific  │
# │  - General Q&A    - Basic pattern - Consistent     - Custom domain  │
# │  - Model already  - When data     - Classification - Edge cases     │
# │    knows well       is limited    - Transformation   matter         │
# └──────────────────────────────────────────────────────────────────────┘
# ```
#
# ### 📐 หลักการออกแบบตัวอย่างที่ดี
#
# ```
# ┌─────────────────────────────────────────────────┐
# │         🎯 GOOD EXAMPLE DESIGN PRINCIPLES       │
# │                                                   │
# │  1. ✅ REPRESENTATIVE (เป็นตัวแทนที่ดี)           │
# │     → เลือกตัวอย่างที่ครอบคลุม cases สำคัญ       │
# │                                                   │
# │  2. ✅ DIVERSE (หลากหลาย)                         │
# │     → ไม่ใช้ตัวอย่างที่คล้ายกันหมด               │
# │                                                   │
# │  3. ✅ FORMATTED (มี format ชัดเจน)               │
# │     → Input/Output แยกกันชัด                      │
# │                                                   │
# │  4. ✅ BALANCED (สมดุล)                            │
# │     → ถ้าเป็น classification ครบทุก class         │
# │                                                   │
# │  5. ❌ AVOID: ตัวอย่างที่ขัดแย้งกัน               │
# │  6. ❌ AVOID: ตัวอย่างที่ยาวเกินไป                │
# │  7. ❌ AVOID: ตัวอย่างที่ ambiguous                │
# └─────────────────────────────────────────────────┘
# ```
#
# ### 🔬 งานวิจัยที่เกี่ยวข้อง
# - **Brown et al. (2020)** — "Language Models are Few-Shot Learners" (GPT-3 Paper)
#   พบว่า LLM สามารถเรียนรู้จากตัวอย่างในบริบทได้โดยไม่ต้อง fine-tune
# - **Min et al. (2022)** — "Rethinking the Role of Demonstrations"
#   พบว่า *format* ของตัวอย่างสำคัญกว่า *ความถูกต้อง* ของ label

# %%
# === Lab 1.1: Zero-shot vs Few-shot Comparison ===
# Task: จำแนกความรู้สึก (Sentiment Analysis) ของรีวิวร้านอาหาร

# Zero-shot
zero_shot_prompt = """
จำแนกความรู้สึกของรีวิวต่อไปนี้เป็น: บวก, ลบ, หรือ กลาง

รีวิว: "อาหารรสชาติดีมาก แต่รอนานไปหน่อย"
ความรู้สึก:
"""

response_zero = call_gemini(zero_shot_prompt)
print_section("Zero-shot Result", response_zero)
# Out:
# 🔹 Zero-shot Result
# ──────────────────────────────────────────────────
# ความรู้สึก: **กลาง**
#
# เหตุผล: รีวิวนี้มีทั้งส่วนที่เป็นบวก (อาหารรสชาติดีมาก) และส่วนที่เป็นลบ (รอนานไปหน่อย) ทำให้โดยรวมแล้วเป็นกลาง
#
# ──────────────────────────────────────────────────

# %%
# Few-shot (3 examples)
few_shot_prompt = """
จำแนกความรู้สึกของรีวิวร้านอาหารเป็น: บวก, ลบ, หรือ กลาง

ตัวอย่าง 1:
รีวิว: "อร่อยมากค่ะ บริการดีเยี่ยม จะกลับมาอีกแน่นอน!"
ความรู้สึก: บวก

ตัวอย่าง 2:
รีวิว: "ผิดหวังมาก อาหารเย็น พนักงานไม่สุภาพ"
ความรู้สึก: ลบ

ตัวอย่าง 3:
รีวิว: "อาหารพอใช้ได้ ราคาก็โอเค ไม่ได้โดดเด่นอะไร"
ความรู้สึก: กลาง

ตอนนี้จำแนกรีวิวนี้:
รีวิว: "อาหารรสชาติดีมาก แต่รอนานไปหน่อย"
ความรู้สึก:
"""

response_few = call_gemini(few_shot_prompt)
print_section("Few-shot Result", response_few)
# Out:
# 🔹 Few-shot Result
# ──────────────────────────────────────────────────
# ความรู้สึก: บวก
#
# ──────────────────────────────────────────────────

# %%
# === Lab 1.2: Few-shot สำหรับ Data Transformation ===
# Task: แปลงที่อยู่ไทยเป็น JSON format

few_shot_address = """
แปลงที่อยู่ภาษาไทยเป็น JSON format

ตัวอย่าง 1:
Input: "123/45 ซอยสุขุมวิท 21 ถนนสุขุมวิท แขวงคลองเตยเหนือ เขตวัฒนา กรุงเทพฯ 10110"
Output: {
  "house_number": "123/45",
  "soi": "สุขุมวิท 21",
  "road": "สุขุมวิท",
  "subdistrict": "คลองเตยเหนือ",
  "district": "วัฒนา",
  "province": "กรุงเทพมหานคร",
  "postal_code": "10110"
}

ตัวอย่าง 2:
Input: "89 หมู่ 5 ตำบลบางพลี อำเภอบางพลี จังหวัดสมุทรปราการ 10540"
Output: {
  "house_number": "89",
  "moo": "5",
  "subdistrict": "บางพลี",
  "district": "บางพลี",
  "province": "สมุทรปราการ",
  "postal_code": "10540"
}

ตอนนี้แปลงที่อยู่นี้:
Input: "456/7 ถนนเพชรบุรีตัดใหม่ แขวงบางกะปิ เขตห้วยขวาง กรุงเทพฯ 10310"
Output:
"""

response = call_gemini(few_shot_address)
print_section("Address Transformation Result", response)
# Out:
# 🔹 Address Transformation Result
# ──────────────────────────────────────────────────
# ```json
# {
#   "house_number": "456/7",
#   "road": "เพชรบุรีตัดใหม่",
#   "subdistrict": "บางกะปิ",
#   "district": "ห้วยขวาง",
#   "province": "กรุงเทพมหานคร",
#   "postal_code": "10310"
# }
# ```
#
# ──────────────────────────────────────────────────

# %%
# === Lab 1.3: Few-shot Sensitivity Analysis ===
# ทดลองเปลี่ยนจำนวน examples และดูผลกระทบ

def test_few_shot_sensitivity(test_input: str, examples: list, test_cases: list = [0, 1, 2, 3]):
    """
    ทดสอบว่าจำนวน examples มีผลต่อคุณภาพ output อย่างไร
    """
    results = {}
    
    for n in test_cases:
        if n == 0:
            prompt = f"""จำแนกความรู้สึกของรีวิวเป็น: บวก, ลบ, หรือ กลาง (ตอบแค่คำเดียว)

รีวิว: "{test_input}"
ความรู้สึก:"""
        else:
            selected_examples = examples[:n]
            examples_text = "\n\n".join(selected_examples)
            prompt = f"""จำแนกความรู้สึกของรีวิวเป็น: บวก, ลบ, หรือ กลาง (ตอบแค่คำเดียว)

{examples_text}

รีวิว: "{test_input}"
ความรู้สึก:"""
        
        response = call_gemini(prompt)
        results[f"{n}-shot"] = response.strip()
        print(f"  {n}-shot → {response.strip()}")
    
    return results

examples = [
    'รีวิว: "อร่อยสุดๆ แนะนำเลย!"\nความรู้สึก: บวก',
    'รีวิว: "แย่มาก ไม่มาอีกแล้ว"\nความรู้สึก: ลบ',
    'รีวิว: "ก็ธรรมดา ไม่ได้รู้สึกอะไรเป็นพิเศษ"\nความรู้สึก: กลาง',
]

print("📊 Few-shot Sensitivity Analysis:")
print("=" * 40)
sensitivity_results = test_few_shot_sensitivity(
    "อาหารรสชาติดี แต่พนักงานไม่ค่อยยิ้มแย้ม ราคาก็กลางๆ",
    examples
)
# Out:
# 📊 Few-shot Sensitivity Analysis:
# ========================================
#   0-shot → กลาง
#   1-shot → กลาง
#   2-shot → กลาง
#   3-shot → กลาง

# %% [markdown]
# ---
# # 📘 Part 2: Chain-of-Thought (CoT)
# **ระดับความยาก: ⭐⭐ (กลาง)**
#
# ---
# ## 📖 ทฤษฎีเชิงลึก
#
# **Chain-of-Thought (CoT)** คือเทคนิคที่กระตุ้นให้ LLM แสดงขั้นตอนการคิด
# อย่างเป็นลำดับก่อนให้คำตอบสุดท้าย ช่วยปรับปรุงความถูกต้องในงานที่ต้องใช้เหตุผล
#
# ### 📊 Infographic: CoT ทำงานอย่างไร
#
# ```
# ╔═══════════════════════════════════════════════════════════════════╗
# ║                  🧠 CHAIN-OF-THOUGHT MECHANISM                   ║
# ╠═══════════════════════════════════════════════════════════════════╣
# ║                                                                   ║
# ║  ❌ Standard Prompting (Direct Answer):                           ║
# ║  ┌──────────┐         ┌──────────┐                               ║
# ║  │ Question │ ──────▶ │  Answer  │   "Black Box" ❓               ║
# ║  └──────────┘         └──────────┘                               ║
# ║                                                                   ║
# ║  ✅ Chain-of-Thought Prompting:                                   ║
# ║  ┌──────────┐   ┌──────┐   ┌──────┐   ┌──────┐   ┌──────────┐  ║
# ║  │ Question │──▶│Step 1│──▶│Step 2│──▶│Step 3│──▶│  Answer  │  ║
# ║  └──────────┘   └──────┘   └──────┘   └──────┘   └──────────┘  ║
# ║                     │          │          │                       ║
# ║                 Decompose   Reason    Synthesize                 ║
# ║                 (แยกส่วน)  (ให้เหตุผล)  (สรุป)                    ║
# ║                                                                   ║
# ║  📊 Performance Gain (Wei et al., 2022):                         ║
# ║  ┌────────────────────────────────────────────┐                  ║
# ║  │ Task          │ Standard │  CoT   │ Gain   │                  ║
# ║  │───────────────│──────────│────────│────────│                  ║
# ║  │ GSM8K (Math)  │  17.7%   │ 57.1%  │ +39.4% │                  ║
# ║  │ SVAMP (Math)  │  63.2%   │ 79.0%  │ +15.8% │                  ║
# ║  │ CommonsenseQA │  73.5%   │ 80.5%  │ +7.0%  │                  ║
# ║  └────────────────────────────────────────────┘                  ║
# ╚═══════════════════════════════════════════════════════════════════╝
# ```
#
# ### 🔑 Trigger Phrases ที่ใช้กระตุ้น CoT
#
# ```
# ┌──────────────────────────────────────────────┐
# │         🔑 CoT TRIGGER PHRASES               │
# │                                                │
# │  English:                                      │
# │  • "Let's think step by step"                  │
# │  • "Show your work/reasoning"                  │
# │  • "Explain your thought process"              │
# │  • "Break this down into steps"                │
# │                                                │
# │  ภาษาไทย:                                      │
# │  • "คิดทีละขั้นตอน"                             │
# │  • "แสดงวิธีคิดทุกขั้นตอน"                      │
# │  • "อธิบายกระบวนการคิดของคุณ"                   │
# │  • "แยกปัญหาเป็นส่วนย่อย"                       │
# │                                                │
# │  💡 TIP: ยิ่งเจาะจง ยิ่งดี                      │
# │  แทนที่: "คิดทีละขั้นตอน"                       │
# │  ใช้:   "คิดทีละขั้นตอน: 1)ระบุข้อมูล          │
# │          2)ตั้งสมการ 3)คำนวณ 4)สรุป"            │
# └──────────────────────────────────────────────┘
# ```
#
# ### CoT Variants:
# ```
# CoT Family:
# ├── Zero-shot CoT: "Let's think step by step" (ไม่มีตัวอย่าง)
# ├── Few-shot CoT: มีตัวอย่างพร้อม reasoning steps
# ├── Self-Consistency CoT: หลาย paths → majority vote (Part 3)
# ├── Auto-CoT: ให้ LLM สร้างตัวอย่าง CoT เอง
# └── Multimodal CoT: CoT กับ image + text
# ```

# %%
# === Lab 2.1: Basic Chain-of-Thought ===
# Task: แก้ปัญหาคณิตศาสตร์

# ❌ Without CoT
no_cot_prompt = """
ร้านค้าขายเสื้อ 3 ตัว ราคาตัวละ 250 บาท และกางเกง 2 ตัว ราคาตัวละ 350 บาท
ถ้าลูกค้าได้ส่วนลด 10% รวมทั้งหมดลูกค้าต้องจ่ายเท่าไหร่?
"""

response_no_cot = call_gemini(no_cot_prompt)
print_section("Without CoT", response_no_cot, "❌")
# Out:
# ❌ Without CoT
# ──────────────────────────────────────────────────
# มาคำนวณราคาสินค้ากันก่อน:
#
# *   **เสื้อ:** 3 ตัว * 250 บาท/ตัว = 750 บาท
# *   **กางเกง:** 2 ตัว * 350 บาท/ตัว = 700 บาท
#
# รวมราคาสินค้าทั้งหมด: 750 บาท + 700 บาท = 1450 บาท
#
# คำนวณส่วนลด 10%: 1450 บาท * 10/100 = 145 บาท
#
# ราคาสินค้าหลังหักส่วนลด: 1450 บาท - 145 บาท = 1305 บาท
#
# ดังนั้น ลูกค้าต้องจ่ายเงินทั้งหมด 1305 บาท
# ──────────────────────────────────────────────────

# %%
# ✅ With CoT
cot_prompt = """
ร้านค้าขายเสื้อ 3 ตัว ราคาตัวละ 250 บาท และกางเกง 2 ตัว ราคาตัวละ 350 บาท
ถ้าลูกค้าได้ส่วนลด 10% รวมทั้งหมดลูกค้าต้องจ่ายเท่าไหร่?

กรุณาคิดทีละขั้นตอนอย่างละเอียด แสดงวิธีคิดทุกขั้นตอน
"""

response_cot = call_gemini(cot_prompt)
print_section("With CoT", response_cot, "✅")
# Out:
# ✅ With CoT
# ──────────────────────────────────────────────────
# แน่นอนครับ นี่คือวิธีคิดทีละขั้นตอน:
#
# **1. ราคารวมของเสื้อ:**
#
# *   เสื้อ 3 ตัว ราคาตัวละ 250 บาท
# *   ราคารวมเสื้อ = 3 * 250 = 750 บาท
#
# **2. ราคารวมของกางเกง:**
#
# *   กางเกง 2 ตัว ราคาตัวละ 350 บาท
# *   ราคารวมกางเกง = 2 * 350 = 700 บาท
#
# **3. ราคารวมทั้งหมดก่อนส่วนลด:**
#
# *   ราคารวมทั้งหมด = ราคารวมเสื้อ + ราคารวมกางเกง
# *   ราคารวมทั้งหมด = 750 + 700 = 1450 บาท
#
# **4. คำนวณส่วนลด:**
#
# *   ส่วนลด 10% ของราคารวมทั้งหมด
# *   ส่วนลด = (10/100) * 1450 = 145 บาท
#
# **5. ราคารวมหลังหักส่วนลด:**
#
# *   ราคารวมหลังหักส่วนลด = ราคารวมทั้งหมด - ส่วนลด
# *   ราคารวมหลังหักส่วนลด = 1450 - 145 = 1305 บาท
#
# **ดังนั้น ลูกค้าต้องจ่ายเงินทั้งหมด 1305 บาท**
# ──────────────────────────────────────────────────

# %%
# === Lab 2.2: CoT สำหรับ Logical Reasoning ===
# Task: วิเคราะห์ปัญหาทางธุรกิจ

cot_business_prompt = """
บริษัทมีข้อมูลดังนี้:
- ยอดขายเดือนที่แล้ว: 1,000,000 บาท
- ต้นทุนสินค้า: 60% ของยอดขาย
- ค่าใช้จ่ายคงที่: 250,000 บาท
- เป้าหมายกำไรสุทธิเดือนนี้: เพิ่มขึ้น 20%

คำถาม: บริษัทต้องเพิ่มยอดขายเท่าไหร่ (สมมติต้นทุนและค่าใช้จ่ายคงที่เท่าเดิม)?

กรุณาวิเคราะห์ทีละขั้นตอน:
1. คำนวณกำไรปัจจุบัน
2. คำนวณเป้าหมายกำไรใหม่
3. คำนวณยอดขายที่ต้องการ
4. สรุปผล
"""

response = call_gemini(cot_business_prompt)
print_section("Business Analysis with CoT", response)
# Out:
# 🔹 Business Analysis with CoT
# ──────────────────────────────────────────────────
# แน่นอนครับ มาวิเคราะห์ทีละขั้นตอนกัน:
#
# **1. คำนวณกำไรปัจจุบัน**
#
# *   **ต้นทุนสินค้า:** 1,000,000 บาท * 60% = 600,000 บาท
# *   **กำไรขั้นต้น:** 1,000,000 บาท - 600,000 บาท = 400,000 บาท
# *   **กำไรสุทธิ:** 400,000 บาท - 250,000 บาท = 150,000 บาท
#
# **2. คำนวณเป้าหมายกำไรใหม่**
#
# *   **กำไรที่เพิ่มขึ้น:** 150,000 บาท * 20% = 30,000 บาท
# *   **เป้าหมายกำไรสุทธิ:** 150,000 บาท + 30,000 บาท = 180,000 บาท
#
# **3. คำนวณยอดขายที่ต้องการ**
#
# *   **กำไรขั้นต้นที่ต้องการ:** 180,000 บาท (เป้าหมายกำไรสุทธิ) + 250,000 บาท (ค่าใช้จ่ายคงที่) = 430,000 บาท
# *   **อัตรากำไรขั้นต้น:** 100% - 60% (ต้นทุนสินค้า) = 40%
# *   **ยอดขายที่ต้องการ:** 430,000 บาท / 40% = 1,075,000 บาท
#
# **4. สรุปผล**
#
# บริษัทต้องเพิ่มยอดขายเป็น 1,075,000 บาท เพื่อให้ได้กำไรสุทธิตามเป้าหมายที่เพิ่มขึ้น 20% จากเดือนที่แล้ว
#
# **ดังนั้น บริษัทต้องเพิ่มยอดขาย:** 1,075,000 บาท - 1,000,000 บาท = **75,000 บาท**
#
# ──────────────────────────────────────────────────

# %%
# === Lab 2.3: Few-shot CoT ===
# รวม Few-shot กับ CoT เพื่อผลลัพธ์ที่ดียิ่งขึ้น

few_shot_cot_prompt = """
แก้ปัญหาคณิตศาสตร์โดยแสดงวิธีคิดทีละขั้นตอน

ตัวอย่าง 1:
โจทย์: มีแอปเปิ้ล 5 ลูก ซื้อเพิ่มมา 3 ลูก แล้วแบ่งให้เพื่อนไป 2 ลูก เหลือกี่ลูก?
วิธีคิด:
- ขั้นตอน 1: มีแอปเปิ้ลเริ่มต้น = 5 ลูก
- ขั้นตอน 2: ซื้อเพิ่ม = 5 + 3 = 8 ลูก
- ขั้นตอน 3: แบ่งให้เพื่อน = 8 - 2 = 6 ลูก
คำตอบ: 6 ลูก

ตัวอย่าง 2:
โจทย์: รถวิ่งด้วยความเร็ว 60 กม./ชม. ใช้เวลา 2.5 ชั่วโมง วิ่งได้ระยะทางเท่าไหร่?
วิธีคิด:
- ขั้นตอน 1: ใช้สูตร ระยะทาง = ความเร็ว × เวลา
- ขั้นตอน 2: แทนค่า = 60 × 2.5
- ขั้นตอน 3: คำนวณ = 150 กิโลเมตร
คำตอบ: 150 กิโลเมตร

ตอนนี้แก้โจทย์นี้:
โจทย์: ร้านกาแฟขายกาแฟแก้วละ 50 บาท ต้นทุน 20 บาท ถ้าวันนี้ขายได้ 45 แก้ว 
       และมีค่าเช่าร้านวันละ 500 บาท กำไรสุทธิวันนี้เท่าไหร่?
วิธีคิด:
"""

response = call_gemini(few_shot_cot_prompt)
print_section("Few-shot CoT Result", response)
# Out:
# 🔹 Few-shot CoT Result
# ──────────────────────────────────────────────────
# - **ขั้นตอน 1: คำนวณกำไรต่อแก้ว**
#     * กำไรต่อแก้ว = ราคาขาย - ต้นทุน
#     * กำไรต่อแก้ว = 50 บาท - 20 บาท = 30 บาท
#
# - **ขั้นตอน 2: คำนวณกำไรรวมจากการขายกาแฟ**
#     * กำไรรวม = กำไรต่อแก้ว × จำนวนแก้วที่ขายได้
#     * กำไรรวม = 30 บาท/แก้ว × 45 แก้ว = 1350 บาท
#
# - **ขั้นตอน 3: คำนวณกำไรสุทธิ**
#     * กำไรสุทธิ = กำไรรวม - ค่าเช่าร้าน
#     * กำไรสุทธิ = 1350 บาท - 500 บาท = 850 บาท
#
# **คำตอบ: กำไรสุทธิวันนี้คือ 850 บาท**
#
# ──────────────────────────────────────────────────

# %% [markdown]
# ### 📊 CoT vs Standard: เมื่อไหร่ควรใช้ CoT
#
# ```
# ┌────────────────────────────────────────────────────────────┐
# │            🎯 WHEN TO USE CoT?                             │
# │                                                            │
# │  ✅ USE CoT:                    ❌ DON'T NEED CoT:         │
# │  • Math problems               • Simple factual Q&A       │
# │  • Logic puzzles                • Translation              │
# │  • Multi-step reasoning         • Summarization            │
# │  • Cause-effect analysis        • Sentiment (simple)       │
# │  • Decision making              • Fill-in-the-blank        │
# │  • Code debugging               • Short creative writing   │
# │  • Business analysis                                       │
# │  • Scientific reasoning                                    │
# │                                                            │
# │  💡 Rule of thumb:                                         │
# │  ถ้ามนุษย์ต้อง "คิด" หลายขั้นตอน → ใช้ CoT              │
# │  ถ้ามนุษย์ตอบได้ทันที → ไม่จำเป็น                         │
# └────────────────────────────────────────────────────────────┘
# ```

# %% [markdown]
# ---
# # 📘 Part 3: Self-Consistency Chain-of-Thought
# **ระดับความยาก: ⭐⭐⭐ (กลาง-สูง)**
#
# ---
# ## 📖 ทฤษฎีเชิงลึก
#
# **Self-Consistency CoT** คือเทคนิคที่สร้างคำตอบหลายๆ ครั้ง
# แล้วเลือกคำตอบที่ consistent (สอดคล้องกัน) มากที่สุด
#
# ### 📊 Infographic: Self-Consistency ทำงานอย่างไร
#
# ```
# ╔══════════════════════════════════════════════════════════════════════╗
# ║              🔄 SELF-CONSISTENCY MECHANISM                          ║
# ╠══════════════════════════════════════════════════════════════════════╣
# ║                                                                      ║
# ║                      ┌──────────┐                                    ║
# ║                      │ Question │                                    ║
# ║                      └─────┬────┘                                    ║
# ║                ┌───────────┼───────────┐                             ║
# ║                │           │           │                             ║
# ║                ▼           ▼           ▼                             ║
# ║         ┌──────────┐ ┌──────────┐ ┌──────────┐                      ║
# ║         │ Path 1   │ │ Path 2   │ │ Path 3   │   (temperature > 0) ║
# ║         │ Step A   │ │ Step X   │ │ Step P   │                      ║
# ║         │ Step B   │ │ Step Y   │ │ Step Q   │                      ║
# ║         │ Step C   │ │ Step Z   │ │ Step R   │                      ║
# ║         └────┬─────┘ └────┬─────┘ └────┬─────┘                      ║
# ║              │           │           │                               ║
# ║              ▼           ▼           ▼                               ║
# ║         Answer: 42   Answer: 42   Answer: 38                        ║
# ║                                                                      ║
# ║         ┌─────────────────────────────┐                              ║
# ║         │     📊 Majority Vote        │                              ║
# ║         │     42: ██████████ (2 votes)│                              ║
# ║         │     38: █████ (1 vote)      │                              ║
# ║         │                             │                              ║
# ║         │     ✅ Final Answer: 42     │                              ║
# ║         └─────────────────────────────┘                              ║
# ║                                                                      ║
# ║  📈 Wang et al. (2023): Self-Consistency improves CoT by 1-24%      ║
# ║     on arithmetic and commonsense reasoning benchmarks              ║
# ╚══════════════════════════════════════════════════════════════════════╝
# ```
#
# ### 🔑 ข้อสำคัญ
#
# ```
# ┌─────────────────────────────────────────────────────────┐
# │            ⚙️ SELF-CONSISTENCY PARAMETERS               │
# │                                                          │
# │  1. Number of Samples (N):                               │
# │     • N = 3-5: ดีสำหรับงานทั่วไป                         │
# │     • N = 10-20: ดีสำหรับงานซับซ้อน                      │
# │     • N = 40+: ตามงานวิจัย (แต่ cost สูง)               │
# │                                                          │
# │  2. Temperature:                                         │
# │     • 0.5-0.8: ดีสำหรับ diverse but reasonable paths    │
# │     • > 1.0: อาจได้ paths ที่ไม่ make sense             │
# │                                                          │
# │  3. Voting Strategy:                                     │
# │     • Majority Vote: เลือกคำตอบที่มากที่สุด              │
# │     • Weighted Vote: ให้น้ำหนักตาม confidence            │
# │     • Plurality: เลือก unique answer ที่มากที่สุด        │
# │                                                          │
# │  4. Cost Consideration:                                  │
# │     • N samples = N × API calls = N × cost              │
# │     • Balance: quality vs. budget                        │
# └─────────────────────────────────────────────────────────┘
# ```

# %%
# === Lab 3.1: Self-Consistency Implementation ===

def self_consistency_cot(prompt: str, num_samples: int = 5, temperature: float = 0.7) -> Dict:
    """
    สร้างคำตอบหลายครั้งและเลือกคำตอบที่ consistent ที่สุด
    """
    responses = []
    final_answers = []
    
    for i in range(num_samples):
        response = call_gemini(prompt, temperature=temperature)
        responses.append(response)
        
        # พยายามดึงคำตอบสุดท้าย
        numbers = re.findall(r'\b\d+(?:,\d{3})*(?:\.\d+)?\b', response)
        if numbers:
            final_answers.append(numbers[-1].replace(',', ''))
        
        print(f"📝 Sample {i+1}: {response[:200]}...")
        print("-" * 50)
        time.sleep(1)  # Rate limiting
    
    # นับความถี่ของคำตอบ
    answer_counts = Counter(final_answers)
    
    return {
        "all_responses": responses,
        "extracted_answers": final_answers,
        "answer_distribution": dict(answer_counts),
        "most_common": answer_counts.most_common(1)[0] if answer_counts else None,
        "consistency_score": max(answer_counts.values()) / len(final_answers) if final_answers else 0
    }

# %%
# ทดสอบ Self-Consistency CoT
problem_prompt = """
แก้ปัญหานี้โดยแสดงวิธีคิดทีละขั้นตอน:

ร้านอาหารมีโต๊ะ 12 โต๊ะ แต่ละโต๊ะนั่งได้ 4 คน
วันนี้มีลูกค้ามา 35 คน และอีก 2 กลุ่ม กลุ่มละ 6 คน จะมาทีหลัง
ถามว่า: ร้านสามารถรองรับลูกค้าทั้งหมดได้หรือไม่? 
และถ้าได้ จะเหลือที่นั่งว่างกี่ที่?

แสดงวิธีคิด แล้วสรุปคำตอบเป็นตัวเลขที่นั่งที่เหลือ
"""

print("🔄 Running Self-Consistency CoT (3 samples)...")
result = self_consistency_cot(problem_prompt, num_samples=3)

print("\n" + "="*50)
print("📊 Results Summary:")
print(f"  Answer Distribution: {result['answer_distribution']}")
print(f"  Most Common Answer: {result['most_common']}")
print(f"  Consistency Score: {result['consistency_score']:.1%}")
# Out:
# 🔄 Running Self-Consistency CoT (3 samples)...
# 📝 Sample 1: แน่นอนครับ มาดูวิธีคิดและแก้ปัญหานี้ทีละขั้นตอนกัน:
#
# **1. หาจำนวนที่นั่งทั้งหมดในร้าน:**
#
# *   ร้านมี 12 โต๊ะ แต่ละโต๊ะนั่งได้ 4 คน
# *   ดังนั้น ร้านมีที่นั่งทั้งหมด: 12 โต๊ะ * 4 คน/โต๊ะ = 48 ที่นั่ง
#
# *...
# --------------------------------------------------
# 📝 Sample 2: มาแก้ปัญหานี้ไปพร้อมๆ กันนะครับ
#
# **ขั้นตอนที่ 1: หาจำนวนที่นั่งทั้งหมดในร้านอาหาร**
#
# *   ร้านอาหารมี 12 โต๊ะ
# *   แต่ละโต๊ะนั่งได้ 4 คน
# *   ดังนั้น จำนวนที่นั่งทั้งหมด = 12 โต๊ะ * 4 คน/โต๊ะ = 48 ที่นั่...
# --------------------------------------------------
# 📝 Sample 3: แน่นอนครับ มาดูวิธีคิดทีละขั้นตอนกัน:
#
# **1. หาจำนวนที่นั่งทั้งหมดในร้าน:**
#
# *   จำนวนโต๊ะ: 12 โต๊ะ
# *   จำนวนที่นั่งต่อโต๊ะ: 4 ที่นั่ง
# *   จำนวนที่นั่งทั้งหมด: 12 โต๊ะ * 4 ที่นั่ง/โต๊ะ = 48 ที่นั่ง
#
# **...
# --------------------------------------------------
#
# ==================================================
# 📊 Results Summary:
#   Answer Distribution: {'1': 3}
#   Most Common Answer: ('1', 3)
#   Consistency Score: 100.0%

# %%
# === Lab 3.2: Advanced Self-Consistency with Weighted Voting ===

def advanced_self_consistency(prompt: str, num_samples: int = 5) -> Dict:
    """
    Self-Consistency พร้อม confidence scoring
    """
    results = []
    
    enhanced_prompt = f"""
{prompt}

หลังจากคิดเสร็จ กรุณาให้:
1. คำตอบสุดท้าย (ตัวเลขหรือ Yes/No)
2. ความมั่นใจในคำตอบ (1-10)

Format:
คำตอบ: [your answer]
ความมั่นใจ: [1-10]
"""
    
    for i in range(num_samples):
        response = call_gemini(enhanced_prompt, temperature=0.8)
        
        # Extract answer and confidence
        answer_match = re.search(r'คำตอบ[:\s]*([^\n]+)', response)
        confidence_match = re.search(r'ความมั่นใจ[:\s]*(\d+)', response)
        
        answer = answer_match.group(1).strip() if answer_match else "N/A"
        confidence = int(confidence_match.group(1)) if confidence_match else 5
        
        results.append({
            "full_response": response,
            "answer": answer,
            "confidence": confidence
        })
        
        print(f"  Sample {i+1}: Answer={answer}, Confidence={confidence}/10")
        time.sleep(1)
    
    # Weighted voting
    weighted_answers = {}
    for r in results:
        ans = r["answer"]
        conf = r["confidence"]
        weighted_answers[ans] = weighted_answers.get(ans, 0) + conf
    
    best_answer = max(weighted_answers, key=weighted_answers.get)
    
    return {
        "results": results,
        "weighted_scores": weighted_answers,
        "best_answer": best_answer,
        "total_confidence": weighted_answers[best_answer]
    }

# %%
# ทดสอบ Advanced Self-Consistency
test_prompt = """
บริษัทกำลังพิจารณาขยายสาขาใหม่ มีข้อมูล:
- ต้นทุนเปิดสาขา: 2,000,000 บาท
- รายได้คาดการณ์ต่อเดือน: 350,000 บาท
- ค่าใช้จ่ายต่อเดือน: 280,000 บาท

คำถาม: กี่เดือนจึงจะคืนทุน? (ตอบเป็นจำนวนเต็ม)
"""

print("🔄 Running Advanced Self-Consistency...")
advanced_result = advanced_self_consistency(test_prompt, num_samples=3)

print("\n📊 Weighted Voting Results:")
print(f"  Weighted Scores: {advanced_result['weighted_scores']}")
print(f"  Best Answer: {advanced_result['best_answer']}")
# Out:
# 🔄 Running Advanced Self-Consistency...
#   Sample 1: Answer=29, Confidence=10/10
#   Sample 2: Answer=29, Confidence=10/10
#   Sample 3: Answer=29, Confidence=10/10
#
# 📊 Weighted Voting Results:
#   Weighted Scores: {'29': 30}
#   Best Answer: 29

# %% [markdown]
# ---
# # 📘 Part 4: Prompt Chaining
# **ระดับความยาก: ⭐⭐⭐ (กลาง-สูง)**
#
# ---
# ## 📖 ทฤษฎีเชิงลึก
#
# **Prompt Chaining** คือเทคนิคที่แบ่งงานซับซ้อนออกเป็นขั้นตอนย่อยๆ
# โดย output ของ prompt หนึ่งจะเป็น input ของ prompt ถัดไป
#
# ### 📊 Infographic: Prompt Chaining Architecture
#
# ```
# ╔══════════════════════════════════════════════════════════════════════╗
# ║              🔗 PROMPT CHAINING ARCHITECTURE                        ║
# ╠══════════════════════════════════════════════════════════════════════╣
# ║                                                                      ║
# ║  Single Monolithic Prompt (❌ ไม่แนะนำสำหรับงานซับซ้อน):           ║
# ║  ┌──────────────────────────────────────────────────┐               ║
# ║  │  "ทำ A, B, C, D, E ทั้งหมดพร้อมกัน"              │               ║
# ║  │  → มักได้ผลลัพธ์ไม่ดี เพราะ context ยาวเกินไป    │               ║
# ║  └──────────────────────────────────────────────────┘               ║
# ║                                                                      ║
# ║  Prompt Chaining (✅ แนะนำ):                                        ║
# ║  ┌─────┐    ┌─────┐    ┌─────┐    ┌─────┐    ┌─────────┐          ║
# ║  │ P1  │───▶│ P2  │───▶│ P3  │───▶│ P4  │───▶│ Final   │          ║
# ║  │Extract│   │Analyze│  │Plan │   │Refine│   │ Output  │          ║
# ║  └─────┘    └─────┘    └─────┘    └─────┘    └─────────┘          ║
# ║     │          │          │          │                              ║
# ║     └──context──┘──context──┘──context──┘                           ║
# ║                                                                      ║
# ║  ✨ Benefits:                                                        ║
# ║  • แต่ละขั้นตอนมี focus ชัดเจน                                      ║
# ║  • ควบคุมคุณภาพแต่ละขั้นตอนได้                                     ║
# ║  • Debug ง่าย (รู้ว่าผิดตรงไหน)                                    ║
# ║  • สามารถใช้ model ต่างกันในแต่ละขั้น                              ║
# ║  • เพิ่ม/ลด ขั้นตอนได้ง่าย                                         ║
# ║                                                                      ║
# ║  ⚠️ Limitations:                                                     ║
# ║  • Latency สูงขึ้น (หลาย API calls)                                ║
# ║  • Error propagation (ผิดขั้นแรก → ผิดหมด)                        ║
# ║  • Cost เพิ่มขึ้นตามจำนวนขั้นตอน                                   ║
# ╚══════════════════════════════════════════════════════════════════════╝
# ```
#
# ### 📐 Chaining Patterns ที่พบบ่อย
#
# ```
# Pattern 1: Sequential (ลำดับ)
# ┌─────┐ → ┌─────┐ → ┌─────┐ → ┌─────┐
# │  A  │   │  B  │   │  C  │   │  D  │
# └─────┘   └─────┘   └─────┘   └─────┘
# ตัวอย่าง: Extract → Analyze → Summarize → Format
#
# Pattern 2: Fan-out (กระจาย)
#                    ┌─────┐
#               ┌──▶│  B1 │
# ┌─────┐      │    └─────┘
# │  A  │──────┤    ┌─────┐
# └─────┘      ├──▶│  B2 │
#              │    └─────┘
#              │    ┌─────┐
#              └──▶│  B3 │
#                   └─────┘
# ตัวอย่าง: แบ่งบทความ → วิเคราะห์แต่ละส่วนแยก
#
# Pattern 3: Fan-in (รวม)
# ┌─────┐
# │  A  │────┐
# └─────┘    │    ┌─────┐
# ┌─────┐    ├──▶│  D  │
# │  B  │────┤    └─────┘
# └─────┘    │
# ┌─────┐    │
# │  C  │────┘
# └─────┘
# ตัวอย่าง: SWOT + Financial + Market → รวมเป็น Business Plan
#
# Pattern 4: Conditional (เงื่อนไข)
# ┌─────┐      YES → ┌─────┐
# │  A  │──────────▶│  B  │
# └─────┘      NO  → ┌─────┐
#                     │  C  │
#                     └─────┘
# ตัวอย่าง: ตรวจสอบ input → ถ้า valid → process, ถ้า invalid → fix
# ```

# %%
# === Lab 4.1: Basic Prompt Chaining ===
# Task: วิเคราะห์และสรุปบทความ

def prompt_chain_article_analysis(article: str) -> Dict:
    """
    Chain สำหรับวิเคราะห์บทความแบบหลายขั้นตอน
    """
    results = {}
    
    # Step 1: สกัดข้อมูลสำคัญ
    step1_prompt = f"""
วิเคราะห์บทความต่อไปนี้และสกัดข้อมูลสำคัญ:

บทความ:
{article}

กรุณาระบุ:
1. หัวข้อหลัก (Main Topic)
2. ประเด็นสำคัญ (Key Points) - ระบุ 3-5 ประเด็น
3. ข้อมูลตัวเลข/สถิติ (ถ้ามี)
4. บุคคล/องค์กรที่เกี่ยวข้อง

ตอบในรูปแบบ structured format
"""
    
    response1 = call_gemini(step1_prompt)
    results["step1_extraction"] = response1
    print("✅ Step 1: Information Extraction Complete")
    print(response1)
    print("-" * 50)
    
    # Step 2: วิเคราะห์ sentiment และ tone
    step2_prompt = f"""
จากข้อมูลที่สกัดได้:
{results['step1_extraction']}

กรุณาวิเคราะห์:
1. Sentiment ของบทความ (บวก/ลบ/กลาง)
2. Tone การเขียน (เป็นทางการ/ไม่เป็นทางการ/วิชาการ)
3. กลุ่มเป้าหมายของบทความ
4. วัตถุประสงค์ของผู้เขียน
"""
    
    response2 = call_gemini(step2_prompt)
    results["step2_analysis"] = response2
    print("✅ Step 2: Sentiment & Tone Analysis Complete")
    print(response2)
    print("-" * 50)
    
    # Step 3: สร้างสรุปและข้อเสนอแนะ
    step3_prompt = f"""
จากการวิเคราะห์:

ข้อมูลสำคัญ:
{results['step1_extraction']}

การวิเคราะห์:
{results['step2_analysis']}

กรุณาสร้าง:
1. สรุปบทความ (3-5 ประโยค)
2. ข้อเสนอแนะสำหรับผู้อ่าน
3. คำถามที่ควรพิจารณาต่อ
4. แหล่งข้อมูลเพิ่มเติมที่ควรศึกษา (แนะนำ)
"""
    
    response3 = call_gemini(step3_prompt)
    results["step3_summary"] = response3
    print("✅ Step 3: Summary & Recommendations Complete")
    print(response3)
    
    return results

# %%
# ทดสอบ Prompt Chaining
sample_article = """
กรุงเทพฯ - ธนาคารแห่งประเทศไทยประกาศคงอัตราดอกเบี้ยนโยบายไว้ที่ 2.50% 
ในการประชุมคณะกรรมการนโยบายการเงิน (กนง.) เมื่อวานนี้ โดยมีมติเอกฉันท์ 7-0 เสียง

นายเศรษฐพุฒิ สุทธิวาทนฤพุฒิ ผู้ว่าการธนาคารแห่งประเทศไทย กล่าวว่า 
การคงอัตราดอกเบี้ยครั้งนี้เพื่อประเมินผลกระทบของนโยบายการเงินที่ผ่านมา 
และติดตามสถานการณ์เศรษฐกิจโลกที่ยังมีความไม่แน่นอน

ทั้งนี้ GDP ไทยไตรมาสล่าสุดขยายตัว 2.8% สูงกว่าคาดการณ์ที่ 2.5% 
ขณะที่เงินเฟ้อทั่วไปอยู่ที่ 0.8% ซึ่งอยู่ในกรอบเป้าหมาย 1-3%

นักวิเคราะห์คาดว่า กนง. จะคงดอกเบี้ยไปจนถึงกลางปีหน้า 
ก่อนพิจารณาปรับลดหากเศรษฐกิจชะลอตัว
"""

print("🔗 Starting Prompt Chain Analysis...")
chain_results = prompt_chain_article_analysis(sample_article)
# Out:
# 🔗 Starting Prompt Chain Analysis...
# ✅ Step 1: Information Extraction Complete
# ## การวิเคราะห์บทความ: การคงอัตราดอกเบี้ยนโยบายของธนาคารแห่งประเทศไทย
#
# **1. หัวข้อหลัก (Main Topic):**
#
# การคงอัตราดอกเบี้ยนโยบายของธนาคารแห่งประเทศไทย (ธปท.) ที่ 2.50%
#
# **2. ประเด็นสำคัญ (Key Points):**
#
# *   ธนาคารแห่งประเทศไทย (ธปท.) คงอัตราดอกเบี้ยนโยบายไว้ที่ 2.50% ในการประชุม กนง.
# *   เหตุผลหลักในการคงอัตราดอกเบี้ยคือเพื่อประเมินผลกระทบของนโยบายการเงินที่ผ่านมาและติดตามสถานการณ์เศรษฐกิจโลก
# *   GDP ไทยไตรมาสล่าสุดขยายตัว 2.8% สูงกว่าที่คาดการณ์ไว้
# *   อัตราเงินเฟ้อทั่วไปอยู่ที่ 0.8% ซึ่งอยู่ในกรอบเป้าหมายของ ธปท.
# *   นักวิเคราะห์คาดการณ์ว่า กนง. จะคงอัตราดอกเบี้ยไปจนถึงกลางปีหน้า
#
# **3. ข้อมูลตัวเลข/สถิติ (Data/Statistics):**
#
# *   อัตราดอกเบี้ยนโยบาย: 2.50%
# *   มติ กนง.: 7-0 เสียง (เอกฉันท์)
# *   GDP ไตรมาสล่าสุด: 2.8% (สูงกว่าคาดการณ์ที่ 2.5%)
# *   อัตราเงินเฟ้อทั่วไป: 0.8% (อยู่ในกรอบเป้าหมาย 1-3%)
#
# **4. บุคคล/องค์กรที่เกี่ยวข้อง (People/Organizations):**
#
# *   ธนาคารแห่งประเทศไทย (ธปท.)
# *   คณะกรรมการนโยบายการเงิน (กนง.)
# *   นายเศรษฐพุฒิ สุทธิวาทนฤพุฒิ (ผู้ว่าการธนาคารแห่งประเทศไทย)
# *   นักวิเคราะห์ (ไม่ระบุชื่อ)
#
# --------------------------------------------------
# ✅ Step 2: Sentiment & Tone Analysis Complete
# จากการวิเคราะห์ข้อมูลที่สกัดมา สามารถสรุปได้ดังนี้:
#
# 1.  **Sentiment ของบทความ:** **กลาง (Neutral)** บทความนำเสนอข้อเท็จจริงและข้อมูลเชิงสถิติเกี่ยวกับการตัดสินใจของ ธปท. โดยไม่มีการแสดงความคิดเห็นส่วนตัวหรือการชี้นำไปในทิศทางบวกหรือลบ
#
# 2.  **Tone การเขียน:** **เป็นทางการ (Formal)** ภาษาที่ใช้มีความเป็นทางการ ใช้ศัพท์เฉพาะทางเศรษฐกิจและการเงิน และมีการอ้างอิงถึงองค์กรและบุคคลที่เกี่ยวข้องอย่างชัดเจน
#
# 3.  **กลุ่มเป้าหมายของบทความ:**
#     *   **นักลงทุน:** ข้อมูลเกี่ยวกับอัตราดอกเบี้ยและ GDP มีผลต่อการตัดสินใจลงทุน
#     *   **นักเศรษฐศาสตร์และนักวิเคราะห์:** ข้อมูลเหล่านี้เป็นประโยชน์ในการวิเคราะห์แนวโน้มเศรษฐกิจ
#     *   **ผู้บริหารธุรกิจ:** ข้อมูลเหล่านี้มีผลต่อการวางแผนธุรกิจและการตัดสินใจทางการเงิน
#     *   **ประชาชนทั่วไปที่สนใจเรื่องเศรษฐกิจ:** บทความให้ข้อมูลพื้นฐานเกี่ยวกับนโยบายการเงินของประเทศ
#
# 4.  **วัตถุประสงค์ของผู้เขียน:**
#     *   **ให้ข้อมูล (Inform):** แจ้งให้ทราบถึงการตัดสินใจของ ธปท. ในการคงอัตราดอกเบี้ยนโยบาย
#     *   **อธิบาย (Explain):** อธิบายเหตุผลเบื้องหลังการตัดสินใจของ ธปท. โดยอ้างอิงถึงข้อมูลเศรษฐกิจที่เกี่ยวข้อง
#     *   **รายงาน (Report):** รายงานข้อมูลทางเศรษฐกิจที่สำคัญ เช่น GDP และอัตราเงินเฟ้อ
#     *   **ให้ความเข้าใจ (Provide Understanding):** ช่วยให้ผู้อ่านเข้าใจถึงสถานการณ์เศรษฐกิจปัจจุบันและแนวโน้มในอนาคต
#
# --------------------------------------------------
# ✅ Step 3: Summary & Recommendations Complete
# ## สรุปบทความ, ข้อเสนอแนะ, คำถามที่ควรพิจารณาต่อ, และแหล่งข้อมูลเพิ่มเติม
#
# **1. สรุปบทความ (3-5 ประโยค):**
#
# ธนาคารแห่งประเทศไทย (ธปท.) คงอัตราดอกเบี้ยนโยบายไว้ที่ 2.50% โดยคณะกรรมการนโยบายการเงิน (กนง.) มีมติเป็นเอกฉันท์ เหตุผลหลักคือเพื่อประเมินผลกระทบของนโยบายการเงินที่ผ่านมาและติดตามสถานการณ์เศรษฐกิจโลก แม้ว่า GDP ไตรมาสล่าสุดจะขยายตัวสูงกว่าที่คาดการณ์ไว้ที่ 2.8% และอัตราเงินเฟ้อทั่วไปอยู่ที่ 0.8% ซึ่งอยู่ในกรอบเป้าหมาย นักวิเคราะห์คาดการณ์ว่า กนง. จะคงอัตราดอกเบี้ยไปจนถึงกลางปีหน้า บทความนี้ให้ข้อมูลเชิงสถิติและเหตุผลเบื้องหลังการตัดสินใจของ ธปท.
#
# **2. ข้อเสนอแนะสำหรับผู้อ่าน:**
#
# *   **ติดตามข่าวสารเศรษฐกิจอย่างต่อเนื่อง:** การตัดสินใจของ ธปท. มีผลกระทบต่อเศรษฐกิจในวงกว้าง การติดตามข่าวสารเศรษฐกิจอย่างสม่ำเสมอจะช่วยให้เข้าใจสถานการณ์และเตรียมพร้อมรับมือกับการเปลี่ยนแปลง
# *   **พิจารณาผลกระทบต่อการเงินส่วนบุคคล:** การคงอัตราดอกเบี้ยมีผลต่ออัตราดอกเบี้ยเงินฝากและเงินกู้ พิจารณาผลกระทบต่อการออม การลงทุน และการจัดการหนี้สิน
# *   **ศึกษาข้อมูลเพิ่มเติม:** บทความนี้เป็นเพียงภาพรวมเบื้องต้น ศึกษาข้อมูลเพิ่มเติมจากแหล่งที่น่าเชื่อถือเพื่อทำความเข้าใจสถานการณ์เศรษฐกิจอย่างลึกซึ้งยิ่งขึ้น
#
# **3. คำถามที่ควรพิจารณาต่อ:**
#
# *   **ปัจจัยเสี่ยงทางเศรษฐกิจที่ ธปท. กำลังจับตามองมีอะไรบ้าง?** (เช่น ความผันผวนของเศรษฐกิจโลก, สถานการณ์การเมืองภายในประเทศ, ภาวะหนี้ครัวเรือน)
# *   **การคงอัตราดอกเบี้ยจะส่งผลกระทบต่อภาคธุรกิจอย่างไร?** (เช่น ต้นทุนทางการเงิน, การลงทุน, การจ้างงาน)
# *   **นโยบายการเงินของ ธปท. จะเปลี่ยนแปลงไปอย่างไรหากสถานการณ์เศรษฐกิจเปลี่ยนแปลงไป?** (เช่น หากอัตราเงินเฟ้อสูงขึ้น หรือ GDP ชะลอตัวลง)
# *   **การกระตุ้นเศรษฐกิจของรัฐบาลจะมีผลต่อการตัดสินใจของ กนง. อย่างไร?**
#
# **4. แหล่งข้อมูลเพิ่มเติมที่ควรศึกษา (แนะนำ):**
#
# *   **เว็บไซต์ธนาคารแห่งประเทศไทย (ธปท.):** [https://www.bot.or.th/](https://www.bot.or.th/) (ข้อมูลนโยบายการเงิน, รายงานเศรษฐกิจ, ข่าวสาร)
# *   **รายงานการประชุมคณะกรรมการนโยบายการเงิน (กนง.):** (เผยแพร่บนเว็บไซต์ ธปท. หลังการประชุม)
# *   **สำนักงานสภาพัฒนาการเศรษฐกิจและสังคมแห่งชาติ (สศช.):** [https://www.nesdc.go.th/](https://www.nesdc.go.th/) (ข้อมูล GDP, สถิติเศรษฐกิจ)
# *   **บทวิเคราะห์จากสถาบันการเงินและบริษัทหลักทรัพย์:** (เช่น บทวิเคราะห์จากธนาคารพาณิชย์, บริษัทหลักทรัพย์ต่างๆ)
# *   **ข่าวสารเศรษฐกิจจากสำนักข่าวที่น่าเชื่อถือ:** (เช่น Reuters, Bloomberg, Bangkok Post, The Nation)

# %%
# === Lab 4.2: Complex Prompt Chaining - Business Analysis ===

def business_analysis_chain(company_data: str) -> Dict:
    """
    Chain สำหรับวิเคราะห์ธุรกิจแบบครบวงจร
    """
    results = {}
    
    # Chain 1: SWOT Analysis
    chain1 = f"""
วิเคราะห์ SWOT จากข้อมูลบริษัท:
{company_data}

ระบุ:
- Strengths (จุดแข็ง): 3-4 ข้อ
- Weaknesses (จุดอ่อน): 3-4 ข้อ
- Opportunities (โอกาส): 3-4 ข้อ
- Threats (ภัยคุกคาม): 3-4 ข้อ
"""
    
    response1 = call_gemini(chain1)
    results["swot"] = response1
    print("✅ Chain 1: SWOT Analysis Done")
    
    # Chain 2: Strategic Recommendations based on SWOT
    chain2 = f"""
จาก SWOT Analysis:
{results['swot']}

สร้างกลยุทธ์:
1. SO Strategy (ใช้จุดแข็งคว้าโอกาส)
2. WO Strategy (แก้จุดอ่อนด้วยโอกาส)
3. ST Strategy (ใช้จุดแข็งรับมือภัยคุกคาม)
4. WT Strategy (ลดจุดอ่อนและหลีกเลี่ยงภัยคุกคาม)

ระบุ action items ที่ชัดเจนสำหรับแต่ละกลยุทธ์
"""
    
    response2 = call_gemini(chain2)
    results["strategies"] = response2
    print("✅ Chain 2: Strategic Recommendations Done")
    
    # Chain 3: Implementation Roadmap
    chain3 = f"""
จากกลยุทธ์ที่วางไว้:
{results['strategies']}

สร้าง Implementation Roadmap:
1. Quick Wins (0-3 เดือน): สิ่งที่ทำได้ทันที
2. Short-term (3-6 เดือน): โปรเจกต์ระยะสั้น
3. Medium-term (6-12 เดือน): แผนระยะกลาง
4. Long-term (1-2 ปี): วิสัยทัศน์ระยะยาว

ระบุ KPIs สำหรับแต่ละช่วง
"""
    
    response3 = call_gemini(chain3)
    results["roadmap"] = response3
    print("✅ Chain 3: Implementation Roadmap Done")
    
    return results

# %%
# ทดสอบ Business Analysis Chain
company_info = """
บริษัท TechStart Co., Ltd.
- ธุรกิจ: พัฒนาแอปพลิเคชันมือถือ
- พนักงาน: 25 คน
- รายได้ปีที่แล้ว: 15 ล้านบาท
- ลูกค้าหลัก: SMEs ในประเทศไทย
- จุดเด่น: ทีมพัฒนาฝีมือดี, ราคาแข่งขันได้
- ปัญหา: การตลาดยังไม่แข็งแรง, ขาด Product Manager
- ตลาด: การแข่งขันสูงขึ้น, มี Freelancer เพิ่มขึ้น
- โอกาส: Digital Transformation กำลังโต, รัฐบาลส่งเสริม Tech Startup
"""

print("🏢 Starting Business Analysis Chain...")
business_results = business_analysis_chain(company_info)
# Out:
# 🏢 Starting Business Analysis Chain...
# ✅ Chain 1: SWOT Analysis Done
# ✅ Chain 2: Strategic Recommendations Done
# ✅ Chain 3: Implementation Roadmap Done

# %% [markdown]
# ---
# # 📘 Part 5: Reflection
# **ระดับความยาก: ⭐⭐⭐⭐ (สูง)**
#
# ---
# ## 📖 ทฤษฎีเชิงลึก
#
# **Reflection** คือเทคนิคที่ให้ LLM ทบทวนและประเมินคำตอบของตัวเอง
# แล้วปรับปรุงให้ดีขึ้น คล้ายกับการ "อ่านทวน" ก่อนส่งงาน
#
# ### 📊 Infographic: Reflection Cycle
#
# ```
# ╔══════════════════════════════════════════════════════════════════╗
# ║                 🔍 REFLECTION CYCLE                              ║
# ╠══════════════════════════════════════════════════════════════════╣
# ║                                                                  ║
# ║         ┌───────────────────┐                                    ║
# ║         │  1. GENERATE      │                                    ║
# ║         │  สร้างคำตอบแรก    │                                    ║
# ║         └────────┬──────────┘                                    ║
# ║                  │                                               ║
# ║                  ▼                                               ║
# ║         ┌───────────────────┐                                    ║
# ║         │  2. REFLECT       │                                    ║
# ║         │  วิเคราะห์จุดอ่อน  │◄──────────┐                       ║
# ║         └────────┬──────────┘           │                        ║
# ║                  │                      │                        ║
# ║                  ▼                      │  Loop until            ║
# ║         ┌───────────────────┐           │  satisfied             ║
# ║         │  3. IMPROVE       │           │  (or max               ║
# ║         │  ปรับปรุงตาม      │───────────┘   iterations)          ║
# ║         │  ผลวิเคราะห์      │                                    ║
# ║         └────────┬──────────┘                                    ║
# ║                  │                                               ║
# ║                  ▼                                               ║
# ║         ┌───────────────────┐                                    ║
# ║         │  4. FINAL OUTPUT  │                                    ║
# ║         │  คำตอบที่ปรับปรุง  │                                    ║
# ║         └───────────────────┘                                    ║
# ║                                                                  ║
# ║  Reflection vs. เทคนิคอื่น:                                     ║
# ║  ┌──────────────┬────────────────────────────────────┐          ║
# ║  │ Technique    │ Focus                               │          ║
# ║  │──────────────│────────────────────────────────────│          ║
# ║  │ Reflection   │ ทบทวนภาพรวม, ปรับปรุงทั่วไป        │          ║
# ║  │ Self-Feedback│ ประเมินตามเกณฑ์เฉพาะ               │          ║
# ║  │ Self-Critique│ วิพากษ์อย่างเข้มงวด, หาข้อผิดพลาด  │          ║
# ║  └──────────────┴────────────────────────────────────┘          ║
# ╚══════════════════════════════════════════════════════════════════╝
# ```
#
# ### 🔬 งานวิจัยที่เกี่ยวข้อง
# - **Madaan et al. (2023)** — "Self-Refine" framework
#   LLM ที่ refine output ของตัวเองซ้ำๆ ได้ผลดีกว่า single-pass 5-20%
# - **Shinn et al. (2023)** — "Reflexion: Language Agents with Verbal Reinforcement Learning"
#   ใช้ verbal reflection เป็น feedback signal แทน scalar reward

# %%
# === Lab 5.1: Basic Reflection Pattern ===

def reflection_prompt(task: str) -> Dict:
    """
    Reflection pattern: Generate -> Reflect -> Improve
    """
    results = {}
    
    # Step 1: Initial Response
    initial_prompt = f"""
{task}

ให้คำตอบที่ดีที่สุดของคุณ
"""
    
    response1 = call_gemini(initial_prompt)
    results["initial_response"] = response1
    print_section("Initial Response", response1, "📝")
    
    # Step 2: Reflection
    reflect_prompt = f"""
ทบทวนคำตอบต่อไปนี้:

คำถาม/งาน:
{task}

คำตอบที่ให้ไป:
{results['initial_response']}

กรุณาวิเคราะห์:
1. จุดแข็งของคำตอบ (2-3 ข้อ)
2. จุดอ่อนหรือสิ่งที่ขาดหาย (2-3 ข้อ)
3. ข้อผิดพลาดที่อาจมี
4. สิ่งที่ควรเพิ่มเติม
"""
    
    response2 = call_gemini(reflect_prompt)
    results["reflection"] = response2
    print_section("Reflection", response2, "🔍")
    
    # Step 3: Improved Response
    improvement_prompt = f"""
จากการทบทวน:

คำถาม/งานเดิม:
{task}

คำตอบเดิม:
{results['initial_response']}

ผลการวิเคราะห์:
{results['reflection']}

กรุณาสร้างคำตอบใหม่ที่ปรับปรุงแล้ว โดยแก้ไขจุดอ่อนและเพิ่มเติมสิ่งที่ขาดหาย
"""
    
    response3 = call_gemini(improvement_prompt)
    results["improved_response"] = response3
    print_section("Improved Response", response3, "✨")
    
    return results

# %%
# ทดสอบ Reflection
task = """
เขียนอีเมลขอโทษลูกค้าที่สินค้าส่งล่าช้า 3 วัน 
โดยให้เหตุผลและเสนอชดเชย
"""

print("🔄 Starting Reflection Process...")
reflection_results = reflection_prompt(task)
# Out:
# 🔄 Starting Reflection Process...
#
# 📝 Initial Response
# ──────────────────────────────────────────────────
# แน่นอนค่ะ นี่คือฉบับร่างอีเมลขอโทษลูกค้าที่สินค้าส่งล่าช้า 3 วัน พร้อมเหตุผลและการชดเชย:
#
# **หัวเรื่อง:** ขออภัยอย่างสูงสำหรับการจัดส่งสินค้า [หมายเลขคำสั่งซื้อ #xxxx] ล่าช้า
#
# **เรียน คุณ/ท่าน [ชื่อลูกค้า],**
#
# ดิฉัน/ผมเขียนอีเมลฉบับนี้เพื่อขออภัยอย่างสูงสำหรับความล่าช้าในการจัดส่งสินค้าหมายเลขคำสั่งซื้อ #xxxx ที่ท่านได้สั่งซื้อไว้ สินค้าของท่านมีกำหนดส่งถึงท่านภายในวันที่ [วันที่กำหนดส่งเดิม] แต่ขณะนี้คาดว่าจะจัดส่งถึงท่านภายในวันที่ [วันที่คาดว่าจะได้รับสินค้าใหม่] ซึ่งล่าช้ากว่ากำหนด 3 วัน
#
# ทางเราเข้าใจดีว่าความล่าช้าในการจัดส่งนี้อาจสร้างความไม่สะดวกและความผิดหวังให้กับท่านเป็นอย่างยิ่ง และเราต้องขออภัยเป็นอย่างสูงสำหรับผลกระทบที่เกิดขึ้น
#
# **สาเหตุของความล่าช้า:**
#
# ความล่าช้าในครั้งนี้เกิดจาก [ระบุเหตุผลที่ชัดเจนและเป็นความจริง เช่น ปริมาณคำสั่งซื้อที่เข้ามามากเกินคาดในช่วงโปรโมชั่น, ปัญหาด้านการขนส่งเนื่องจากสภาพอากาศ, สินค้าบางรายการขาดสต็อกชั่วคราว] ซึ่งส่งผลกระทบต่อกระบวนการจัดส่งสินค้าโดยรวม
#
# **การชดเชย:**
#
# เพื่อเป็นการแสดงความรับผิดชอบและขออภัยสำหรับความไม่สะดวกที่เกิดขึ้น ทางเรายินดีที่จะชดเชยให้ท่านดังนี้:
#
# *   [เลือกข้อเสนอที่เหมาะสมกับธุรกิจของคุณ]
#     *   **ส่วนลดสำหรับการสั่งซื้อครั้งถัดไป:** มอบส่วนลด [เปอร์เซ็นต์] สำหรับการสั่งซื้อครั้งถัดไปของท่าน
#     *   **จัดส่งฟรีสำหรับการสั่งซื้อครั้งถัดไป:** ยกเว้นค่าจัดส่งสำหรับการสั่งซื้อครั้งถัดไปของท่าน
#     *   **ของขวัญพิเศษ:** มอบของขวัญพิเศษ [ระบุชนิดของขวัญ] เพื่อเป็นการขอบคุณที่ท่านให้ความเข้าใจ
#     *   **คืนเงินค่าจัดส่ง:** คืนเงินค่าจัดส่งสำหรับการสั่งซื้อครั้งนี้
#
# ทางเรากำลังเร่งดำเนินการจัดส่งสินค้าของท่านโดยเร็วที่สุด และจะแจ้งหมายเลขติดตามพัสดุให้ท่านทราบทันทีที่สินค้าถูกจัดส่งออกจากคลังสินค้า
#
# หากท่านมีข้อสงสัยหรือต้องการสอบถามข้อมูลเพิ่มเติม สามารถติดต่อเราได้ตลอดเวลาที่ [เบอร์โทรศัพท์] หรือ [อีเมล]
#
# ขอขอบคุณสำหรับความเข้าใจและการสนับสนุนที่มีให้เราเสมอมา
#
# **ขอแสดงความนับถือ**
#
# [ชื่อของคุณ/ชื่อบริษัท]
# [ตำแหน่งของคุณ]
# [ข้อมูลติดต่อ]
#
# **หมายเหตุ:**
#
# *   ปรับแก้เนื้อหาใน [ ] ให้เหมาะสมกับสถานการณ์และนโยบายของบริษัทคุณ
# *   ตรวจสอบให้แน่ใจว่าข้อเสนอการชดเชยนั้นสมเหตุสมผลและสามารถทำได้จริง
# *   หากทราบหมายเลขติดตามพัสดุแล้ว ให้เพิ่มลงในอีเมลเพื่อความสะดวกของลูกค้า
# *   หากมีข้อมูลเพิ่มเติมที่เกี่ยวข้องกับคำสั่งซื้อของลูกค้า (เช่น สินค้าบางรายการอาจถูกส่งแยกกัน) ให้แจ้งให้ลูกค้าทราบด้วย
# ──────────────────────────────────────────────────
#
# 🔍 Reflection
# ──────────────────────────────────────────────────
# ## การวิเคราะห์คำตอบฉบับร่างอีเมลขอโทษลูกค้า
#
# **1. จุดแข็งของคำตอบ:**
#
# *   **สุภาพและเป็นมืออาชีพ:** อีเมลใช้ภาษาที่สุภาพ แสดงความเสียใจอย่างจริงใจ และรักษาความเป็นมืออาชีพตลอดทั้งฉบับ
# *   **ให้ข้อมูลครบถ้วน:** อีเมลระบุรายละเอียดสำคัญ เช่น หมายเลขคำสั่งซื้อ วันที่กำหนดส่งเดิม วันที่คาดว่าจะได้รับสินค้าใหม่ และสาเหตุของความล่าช้า ทำให้ลูกค้าเข้าใจสถานการณ์ได้ดีขึ้น
# *   **เสนอการชดเชย:** การเสนอการชดเชยแสดงให้เห็นถึงความรับผิดชอบและความตั้งใจที่จะแก้ไขปัญหา ทำให้ลูกค้ารู้สึกว่าได้รับการดูแล
#
# **2. จุดอ่อนหรือสิ่งที่ขาดหาย:**
#
# *   **เหตุผลอาจยังไม่เฉพาะเจาะจงพอ:** แม้จะระบุเหตุผล แต่บางครั้งอาจยังกว้างเกินไป เช่น "ปริมาณคำสั่งซื้อที่เข้ามามากเกินคาดในช่วงโปรโมชั่น" อาจจะดีกว่าถ้าเจาะจงมากขึ้น เช่น "ปริมาณคำสั่งซื้อในช่วงโปรโมชั่น X เกินกว่าที่เราคาดการณ์ไว้ถึง 30% ทำให้เกิดความล่าช้าในการจัดส่ง"
# *   **ขาดการแสดงความเข้าใจในความรู้สึกของลูกค้า:** แม้จะบอกว่าเข้าใจความไม่สะดวก แต่ยังขาดการแสดงความเข้าใจในความรู้สึกของลูกค้าอย่างแท้จริง เช่น อาจเพิ่มประโยคว่า "เราเข้าใจดีว่าการรอคอยสินค้านานกว่าที่คาดหวังอาจทำให้ท่านรู้สึกผิดหวังและเสียเวลา"
# *   **ขาดการเน้นย้ำถึงการแก้ไขปัญหาในระยะยาว:** อีเมลเน้นการแก้ไขปัญหาเฉพาะหน้า แต่ขาดการกล่าวถึงมาตรการที่บริษัทจะดำเนินการเพื่อป้องกันไม่ให้เกิดเหตุการณ์เช่นนี้อีกในอนาคต
#
# **3. ข้อผิดพลาดที่อาจมี:**
#
# *   **การใช้คำว่า "ดิฉัน/ผม":** ควรเลือกใช้คำใดคำหนึ่งให้สอดคล้องกับผู้ส่งอีเมล (ดิฉันสำหรับผู้หญิง, ผมสำหรับผู้ชาย) หรือใช้คำที่เป็นกลางกว่า เช่น "เรา"
# *   **การใช้คำว่า "ท่าน":** อาจจะดูเป็นทางการเกินไปในบางบริบท หากรู้จักชื่อลูกค้าดี อาจใช้คำว่า "คุณ" แทน
#
# **4. สิ่งที่ควรเพิ่มเติม:**
#
# *   **เพิ่มความเฉพาะเจาะจงในเหตุผล:** อธิบายสาเหตุของความล่าช้าให้ละเอียดและเฉพาะเจาะจงมากขึ้นเท่าที่จะเป็นไปได้
# *   **แสดงความเข้าใจในความรู้สึกของลูกค้า:** เพิ่มประโยคที่แสดงความเข้าใจในความรู้สึกของลูกค้าอย่างแท้จริง
# *   **กล่าวถึงมาตรการป้องกันในอนาคต:** อธิบายสั้นๆ ว่าบริษัทกำลังดำเนินการอะไรบ้างเพื่อป้องกันไม่ให้เกิดความล่าช้าในการจัดส่งอีกในอนาคต
# *   **ระบุช่องทางการติดต่อที่ชัดเจน:** ตรวจสอบให้แน่ใจว่าเบอร์โทรศัพท์และอีเมลที่ให้ไว้ถูกต้องและสามารถติดต่อได้จริง
# *   **ปรับแก้ข้อเสนอการชดเชยให้เหมาะสม:** พิจารณาข้อเสนอการชดเชยที่เหมาะสมกับมูลค่าของสินค้าและผลกระทบที่เกิดขึ้นกับลูกค้า
# *   **ตรวจสอบไวยากรณ์และการสะกดคำ:** ตรวจสอบให้แน่ใจว่าไม่มีข้อผิดพลาดทางไวยากรณ์และการสะกดคำก่อนส่งอีเมล
#
# **ตัวอย่างการปรับปรุงบางส่วน:**
#
# **สาเหตุของความล่าช้า:**
#
# "ความล่าช้าในครั้งนี้เกิดจากปริมาณคำสั่งซื้อในช่วงโปรโมชั่น X ที่เกินกว่าที่เราคาดการณ์ไว้ถึง 30% ทำให้เกิดความล่าช้าในการจัดส่ง นอกจากนี้ ยังมีปัญหาด้านการขนส่งในพื้นที่ [ระบุพื้นที่] เนื่องจากสภาพอากาศที่ไม่เอื้ออำนวย"
#
# **การแสดงความเข้าใจในความรู้สึกของลูกค้า:**
#
# "เราเข้าใจดีว่าการรอคอยสินค้านานกว่าที่คาดหวังอาจทำให้ท่านรู้สึกผิดหวังและเสียเวลา และเราต้องขออภัยอย่างยิ่งสำหรับความไม่สะดวกที่เกิดขึ้น"
#
# **มาตรการป้องกันในอนาคต:**
#
# "เพื่อป้องกันไม่ให้เกิดเหตุการณ์เช่นนี้อีกในอนาคต เรากำลังปรับปรุงระบบการจัดการคลังสินค้าและเพิ่มประสิทธิภาพในการขนส่งสินค้า"
#
# โดยรวมแล้ว คำตอบที่ให้มาเป็นฉบับร่างที่ดี แต่การปรับปรุงในรายละเอียดเล็กๆ น้อยๆ เหล่านี้จะช่วยให้ลูกค้าสัมผัสได้ถึงความจริงใจและความใส่ใจของบริษัทมากยิ่งขึ้น
#
# ──────────────────────────────────────────────────
#
# ✨ Improved Response
# ──────────────────────────────────────────────────
# แน่นอนค่ะ นี่คือฉบับร่างอีเมลขอโทษลูกค้าที่ปรับปรุงแล้ว โดยแก้ไขจุดอ่อนและเพิ่มเติมสิ่งที่ขาดหายไปจากฉบับร่างเดิม:
#
# **หัวเรื่อง:** ขออภัยอย่างสูงสำหรับการจัดส่งสินค้า [หมายเลขคำสั่งซื้อ #xxxx] ล่าช้า
#
# **เรียน คุณ [ชื่อลูกค้า],**
#
# ดิฉัน/ผมเขียนอีเมลฉบับนี้เพื่อขออภัยอย่างสูงสำหรับความล่าช้าในการจัดส่งสินค้าหมายเลขคำสั่งซื้อ #xxxx ที่ท่านได้สั่งซื้อไว้ สินค้าของท่านมีกำหนดส่งถึงท่านภายในวันที่ [วันที่กำหนดส่งเดิม] แต่ขณะนี้คาดว่าจะจัดส่งถึงท่านภายในวันที่ [วันที่คาดว่าจะได้รับสินค้าใหม่] ซึ่งล่าช้ากว่ากำหนด 3 วัน
#
# เราเข้าใจดีว่าการรอคอยสินค้านานกว่าที่คาดหวังอาจทำให้ท่านรู้สึกผิดหวังและเสียเวลา และเราต้องขออภัยอย่างยิ่งสำหรับความไม่สะดวกที่เกิดขึ้น
#
# **สาเหตุของความล่าช้า:**
#
# ความล่าช้าในครั้งนี้เกิดจากปริมาณคำสั่งซื้อในช่วงโปรโมชั่น [ชื่อโปรโมชั่น] ที่เกินกว่าที่เราคาดการณ์ไว้ถึง [เปอร์เซ็นต์]% ทำให้เกิดความล่าช้าในการจัดส่ง นอกจากนี้ ยังมีปัญหาด้านการขนส่งในพื้นที่ [ระบุพื้นที่] เนื่องจาก [ระบุเหตุผลที่เฉพาะเจาะจง เช่น สภาพอากาศเลวร้าย, การจราจรติดขัด] ซึ่งส่งผลกระทบต่อการจัดส่งสินค้าในภาพรวม
#
# **การชดเชย:**
#
# เพื่อเป็นการแสดงความรับผิดชอบและขออภัยสำหรับความไม่สะดวกที่เกิดขึ้น ทางเรายินดีที่จะชดเชยให้ท่านดังนี้:
#
# *   [เลือกข้อเสนอที่เหมาะสมกับธุรกิจของคุณ]
#     *   **ส่วนลดสำหรับการสั่งซื้อครั้งถัดไป:** มอบส่วนลด [เปอร์เซ็นต์] สำหรับการสั่งซื้อครั้งถัดไปของท่าน โดยสามารถใช้ได้ภายใน [ระยะเวลา]
#     *   **จัดส่งฟรีสำหรับการสั่งซื้อครั้งถัดไป:** ยกเว้นค่าจัดส่งสำหรับการสั่งซื้อครั้งถัดไปของท่าน (ไม่จำกัดมูลค่าสินค้า)
#     *   **ของขวัญพิเศษ:** มอบของขวัญพิเศษ [ระบุชนิดของขวัญ เช่น คูปองส่วนลดเพิ่มเติม, สินค้าตัวอย่าง] เพื่อเป็นการขอบคุณที่ท่านให้ความเข้าใจ
#     *   **คืนเงินค่าจัดส่ง:** คืนเงินค่าจัดส่งสำหรับการสั่งซื้อครั้งนี้ โดยจะดำเนินการคืนเงินภายใน [จำนวนวัน] วันทำการ
#
# ทางเรากำลังเร่งดำเนินการจัดส่งสินค้าของท่านโดยเร็วที่สุด และจะแจ้งหมายเลขติดตามพัสดุให้ท่านทราบทันทีที่สินค้าถูกจัดส่งออกจากคลังสินค้า ท่านสามารถตรวจสอบสถานะการจัดส่งได้ที่ [ลิงก์สำหรับติดตามพัสดุ]
#
# เพื่อป้องกันไม่ให้เกิดเหตุการณ์เช่นนี้อีกในอนาคต เรากำลังปรับปรุงระบบการจัดการคลังสินค้าและเพิ่มประสิทธิภาพในการขนส่งสินค้า โดยได้เพิ่มจำนวนพนักงานในส่วนของการแพ็คสินค้า และประสานงานกับบริษัทขนส่งเพื่อเพิ่มรอบการจัดส่งในพื้นที่ที่มีปัญหา
#
# หากท่านมีข้อสงสัยหรือต้องการสอบถามข้อมูลเพิ่มเติม สามารถติดต่อเราได้ตลอดเวลาที่ [เบอร์โทรศัพท์] หรือ [อีเมล]
#
# ขอขอบคุณสำหรับความเข้าใจและการสนับสนุนที่มีให้เราเสมอมา
#
# **ขอแสดงความนับถือ**
#
# [ชื่อของคุณ/ชื่อบริษัท]
# [ตำแหน่งของคุณ]
# [ข้อมูลติดต่อ]
#
# **หมายเหตุ:**
#
# *   ปรับแก้เนื้อหาใน [ ] ให้เหมาะสมกับสถานการณ์และนโยบายของบริษัทคุณ
# *   ตรวจสอบให้แน่ใจว่าข้อเสนอการชดเชยนั้นสมเหตุสมผลและสามารถทำได้จริง
# *   หากทราบหมายเลขติดตามพัสดุแล้ว ให้เพิ่มลงในอีเมลเพื่อความสะดวกของลูกค้า
# *   หากมีข้อมูลเพิ่มเติมที่เกี่ยวข้องกับคำสั่งซื้อของลูกค้า (เช่น สินค้าบางรายการอาจถูกส่งแยกกัน) ให้แจ้งให้ลูกค้าทราบด้วย
# *   ตรวจสอบให้แน่ใจว่าเบอร์โทรศัพท์และอีเมลที่ให้ไว้ถูกต้องและสามารถติดต่อได้จริง
# *   ตรวจสอบไวยากรณ์และการสะกดคำก่อนส่งอีเมล
#
# **การเปลี่ยนแปลงที่สำคัญ:**
#
# *   **เหตุผลที่เฉพาะเจาะจงมากขึ้น:** อธิบายสาเหตุของความล่าช้าให้ละเอียดและเฉพาะเจาะจงมากขึ้น
# *   **การแสดงความเข้าใจในความรู้สึกของลูกค้า:** เพิ่มประโยคที่แสดงความเข้าใจในความรู้สึกของลูกค้าอย่างแท้จริง
# *   **มาตรการป้องกันในอนาคต:** อธิบายสั้นๆ ว่าบริษัทกำลังดำเนินการอะไรบ้างเพื่อป้องกันไม่ให้เกิดความล่าช้าในการจัดส่งอีกในอนาคต
# *   **ข้อเสนอการชดเชยที่ชัดเจน:** ระบุรายละเอียดของข้อเสนอการชดเชยให้ชัดเจน เช่น ระยะเวลาในการใช้ส่วนลด หรือระยะเวลาในการคืนเงิน
# *   **ลิงก์ติดตามพัสดุ:** เพิ่มลิงก์สำหรับติดตามพัสดุเพื่อให้ลูกค้าสามารถตรวจสอบสถานะการจัดส่งได้ด้วยตนเอง
# *   **การใช้คำที่เหมาะสม:** เลือกใช้คำว่า "ดิฉัน/ผม" ให้สอดคล้องกับผู้ส่งอีเมล หรือใช้คำที่เป็นกลางกว่า เช่น "เรา" และพิจารณาการใช้คำว่า "คุณ" แทน "ท่าน" หากเหมาะสมกับความสัมพันธ์กับลูกค้า
#
# หวังว่าฉบับร่างนี้จะเป็นประโยชน์นะคะ!
#
# ──────────────────────────────────────────────────

# %%
# === Lab 5.2: Multi-round Reflection ===

def iterative_reflection(task: str, max_iterations: int = 3) -> Dict:
    """
    Reflection หลายรอบจนกว่าจะพอใจ
    """
    results = {"iterations": []}
    
    current_response = None
    
    for i in range(max_iterations):
        print(f"\n🔄 Iteration {i + 1}")
        print("=" * 50)
        
        if current_response is None:
            # First iteration: Generate initial response
            prompt = f"{task}\n\nให้คำตอบที่ดีที่สุดของคุณ"
        else:
            # Subsequent iterations: Reflect and improve
            prompt = f"""
คำถาม/งาน:
{task}

คำตอบปัจจุบัน:
{current_response}

กรุณา:
1. วิเคราะห์ว่าคำตอบนี้ดีพอหรือยัง (ตอบ YES หรือ NO)
2. ถ้า NO: ระบุจุดที่ต้องปรับปรุงและสร้างคำตอบใหม่ที่ดีกว่า
3. ถ้า YES: ยืนยันคำตอบและอธิบายว่าทำไมถึงดีแล้ว

Format:
STATUS: [YES/NO]
ANALYSIS: [การวิเคราะห์]
RESPONSE: [คำตอบ - ถ้า NO ให้คำตอบใหม่, ถ้า YES ให้คำตอบเดิม]
"""
        
        response = call_gemini(prompt, temperature=0.3)
        
        results["iterations"].append({
            "iteration": i + 1,
            "response": response
        })
        
        print(response[:500] + "..." if len(response) > 500 else response)
        
        # Check if satisfied
        if "STATUS: YES" in response.upper() or "STATUS:YES" in response.upper():
            print("\n✅ Reflection Complete - Satisfied with response")
            break
        
        current_response = response
        time.sleep(1)
    
    results["final_response"] = results["iterations"][-1]["response"]
    results["num_iterations"] = len(results["iterations"])
    return results

# %%
# ทดสอบ Iterative Reflection
complex_task = """
ออกแบบ Loyalty Program สำหรับร้านกาแฟที่มี 3 สาขา
โดยต้องคำนึงถึง:
- งบประมาณจำกัด
- ต้องการเพิ่ม repeat customers 30%
- ใช้เทคโนโลยีที่เรียบง่าย
"""

print("🔄 Starting Iterative Reflection...")
iter_results = iterative_reflection(complex_task, max_iterations=3)
print(f"\n📊 Total iterations: {iter_results['num_iterations']}")
# Out:
# 🔄 Starting Iterative Reflection...
#
# 🔄 Iteration 1
# ==================================================
# ## Loyalty Program สำหรับร้านกาแฟ 3 สาขา (งบจำกัด, เพิ่ม Repeat Customers 30%, เทคโนโลยีเรียบง่าย)
#
# **ชื่อโปรแกรม:** "Coffee Perks Club"
#
# **เป้าหมาย:**
#
# *   เพิ่มจำนวนลูกค้าประจำ (Repeat Customers) 30% ภายใน 6 เดือน
# *   สร้างความผูกพันกับแบรนด์ (Brand Loyalty)
# *   เก็บข้อมูลลูกค้าเพื่อปรับปรุงบริการ
#
# **แนวคิดหลัก:** โปรแกรมสะสมแต้มที่ใช้งานง่าย เข้าถึงได้ทุกคน และให้รางวัลที่ลูกค้าต้องการ
#
# **กลไกโปรแกรม:**
#
# 1.  **การสมัครสมาชิก:**
#     *   **ช่องทาง:**
#         *   **แบบฟอร์มกระดาษ:** ที่เคาน์เตอร...
#
# 🔄 Iteration 2
# ==================================================
# STATUS: NO
# ANALYSIS: คำตอบปัจจุบันค่อนข้างดี มีรายละเอียดครบถ้วน แต่ยังสามารถปรับปรุงให้เน้นการใช้งานจริงได้มากขึ้น และลดความซับซ้อนในการจัดการข้อมูลด้วย Spreadsheet โดยเฉพาะอย่างยิ่งเมื่อมี 3 สาขา การใช้ Spreadsheet อาจทำให้เกิดความผิดพลาดและเสียเวลาในการตรวจสอบได้ นอกจากนี้ ควรเพิ่มกลยุทธ์ในการดึงดูดลูกค้าให้สมัครสมาชิกตั้งแต่แรก และเพิ่มลูกเล่นในการสะสมแต้มให้สนุกและน่าสนใจยิ่งขึ้น
#
# RESPONSE:
#
# ## Loyalty Program สำหรับร้านกาแฟ 3 สาขา (งบจำกัด, เพิ่ม Repeat Customers 30%, เทคโนโลยีเรียบง่าย)
#
# ...
#
# 🔄 Iteration 3
# ==================================================
# STATUS: YES
# ANALYSIS: คำตอบนี้ดีมาก ครอบคลุมทุกด้านที่จำเป็นสำหรับ Loyalty Program ที่มีงบประมาณจำกัดและต้องการเพิ่ม repeat customers โดยใช้เทคโนโลยีที่เรียบง่าย
#
# *   **ครบถ้วน:** ครอบคลุมตั้งแต่การสมัครสมาชิก, การสะสมแต้ม, การแลกของรางวัล, การสื่อสาร, เทคโนโลยีที่ใช้, การตลาดและการประชาสัมพันธ์, การวัดผลและปรับปรุง, งบประมาณ, ข้อดี, และข้อควรระวัง
# *   **ใช้งานได้จริง:** มีรายละเอียดที่ชัดเจนและสามารถนำไปปฏิบัติได้จริง เช่น การใช้ Google Forms/Typeform สำหรับการสมัครสมาชิก, Loyverse POS สำหรับจั...
#
# ✅ Reflection Complete - Satisfied with response
#
# 📊 Total iterations: 3

# %% [markdown]
# ---
# # 📘 Part 6: Tree-of-Thought (ToT)
# **ระดับความยาก: ⭐⭐⭐⭐⭐ (สูงมาก)**
#
# ---
# ## 📖 ทฤษฎีเชิงลึก
#
# **Tree-of-Thought (ToT)** คือเทคนิคที่สำรวจหลายเส้นทางการคิดพร้อมกัน
# เหมือนการเล่นหมากรุกที่พิจารณาหลายๆ ตาล่วงหน้า
#
# ### 📊 Infographic: ToT Architecture
#
# ```
# ╔══════════════════════════════════════════════════════════════════════╗
# ║                 🌳 TREE-OF-THOUGHT ARCHITECTURE                     ║
# ╠══════════════════════════════════════════════════════════════════════╣
# ║                                                                      ║
# ║  CoT (Linear):     ToT (Branching):                                 ║
# ║  ●→●→●→●           ●─┬─●─┬─●──── ✅ Best                            ║
# ║  (1 path)          │  │  └─●──── ❌ Pruned                          ║
# ║                    │  └─●─┬─●──── ❌ Pruned                          ║
# ║                    │     └─●──── ❌ Pruned                           ║
# ║                    └─●─┬─●──── ❌ Pruned                             ║
# ║                       └─●──── ❌ Pruned                              ║
# ║                                                                      ║
# ║  Process:                                                            ║
# ║  ┌──────────┐  ┌──────────┐  ┌──────────┐  ┌──────────┐            ║
# ║  │1.GENERATE│─▶│2.EVALUATE│─▶│3.EXPAND  │─▶│4.SELECT  │            ║
# ║  │ Branches │  │ Score    │  │ Best     │  │ Final    │            ║
# ║  │ (BFS/DFS)│  │ each    │  │ branch   │  │ answer   │            ║
# ║  └──────────┘  └──────────┘  └──────────┘  └──────────┘            ║
# ║                                                                      ║
# ║  🔑 Search Strategies:                                               ║
# ║  ┌───────────────────────────────────────────────────────┐          ║
# ║  │ BFS (Breadth-First)     │ DFS (Depth-First)          │          ║
# ║  │ • ดูทุก branch ในระดับ   │ • ไล่ลึกทีละ branch        │          ║
# ║  │   เดียวกันก่อน           │ • ใช้ memory น้อยกว่า      │          ║
# ║  │ • เหมาะกับ decision     │ • เหมาะกับปัญหาที่มี      │          ║
# ║  │   making tasks          │   solution ลึก             │          ║
# ║  └───────────────────────────────────────────────────────┘          ║
# ║                                                                      ║
# ║  📈 Yao et al. (2023): ToT improves GPT-4 on "Game of 24"          ║
# ║     from 4% (CoT) to 74% success rate                               ║
# ╚══════════════════════════════════════════════════════════════════════╝
# ```
#
# ### ToT vs CoT vs Self-Consistency
# ```
# ┌─────────────────────────────────────────────────────────────┐
# │              🔄 TECHNIQUE COMPARISON                         │
# │                                                               │
# │ Technique          │ Paths │ Evaluation │ Best For           │
# │────────────────────│───────│────────────│────────────────────│
# │ CoT                │   1   │    No      │ Simple reasoning   │
# │ Self-Consistency   │   N   │  Voting    │ Math, factual Q&A  │
# │ Tree-of-Thought    │   N   │ Per-step   │ Complex planning,  │
# │                    │       │ scoring    │ creative problem   │
# │                    │       │            │ solving            │
# └─────────────────────────────────────────────────────────────┘
# ```

# %%
# === Lab 6.1: Tree-of-Thought Implementation ===

def tree_of_thought(problem: str, num_branches: int = 3, depth: int = 2) -> Dict:
    """
    Tree-of-Thought: สำรวจหลายเส้นทางการแก้ปัญหา
    """
    results = {
        "problem": problem,
        "tree": {}
    }
    
    # Step 1: Generate initial branches (approaches)
    generate_prompt = f"""
พิจารณาปัญหา:
{problem}

สร้าง {num_branches} แนวทางการแก้ปัญหาที่แตกต่างกัน
สำหรับแต่ละแนวทาง ให้:
1. ชื่อแนวทาง
2. แนวคิดหลัก
3. ขั้นตอนแรกที่จะทำ

Format:
APPROACH 1:
Name: [ชื่อ]
Concept: [แนวคิด]
First Step: [ขั้นตอนแรก]

APPROACH 2:
...
"""
    
    response1 = call_gemini(generate_prompt, temperature=0.7)
    results["tree"]["initial_branches"] = response1
    print_section("Initial Branches", response1, "🌳")
    
    # Step 2: Evaluate each branch
    evaluate_prompt = f"""
ประเมินแนวทางการแก้ปัญหาเหล่านี้:

ปัญหา:
{problem}

แนวทางที่เสนอ:
{results['tree']['initial_branches']}

สำหรับแต่ละแนวทาง ให้คะแนน 1-10 ในด้าน:
1. ความเป็นไปได้ (Feasibility)
2. ประสิทธิภาพ (Effectiveness)
3. ความเสี่ยง (Risk - คะแนนสูง = ความเสี่ยงต่ำ)
4. ทรัพยากรที่ต้องใช้ (Resources - คะแนนสูง = ใช้น้อย)

สรุปคะแนนรวมและจัดอันดับ
"""
    
    response2 = call_gemini(evaluate_prompt)
    results["tree"]["evaluation"] = response2
    print_section("Branch Evaluation", response2, "📊")
    
    # Step 3: Expand best branch
    expand_prompt = f"""
จากการประเมิน:
{results['tree']['evaluation']}

เลือกแนวทางที่ดีที่สุด และขยายรายละเอียด:

1. อธิบายแผนการดำเนินงานโดยละเอียด
2. ระบุ milestones สำคัญ
3. คาดการณ์อุปสรรคและวิธีรับมือ
4. ทรัพยากรที่ต้องเตรียม
5. Timeline คร่าวๆ
"""
    
    response3 = call_gemini(expand_prompt)
    results["tree"]["expanded_solution"] = response3
    print_section("Expanded Best Solution", response3, "🎯")
    
    return results

# %%
# ทดสอบ Tree-of-Thought
business_problem = """
ร้านหนังสือเล็กๆ กำลังประสบปัญหายอดขายลดลง 40% 
เนื่องจากการแข่งขันจาก e-commerce และ e-book
มีงบประมาณสำหรับปรับปรุง 500,000 บาท
ต้องการหาทางรอดภายใน 1 ปี
"""

print("🌳 Starting Tree-of-Thought Analysis...")
tot_results = tree_of_thought(business_problem)
# Out:
# 🌳 Starting Tree-of-Thought Analysis...
#
# 🌳 Initial Branches
# ──────────────────────────────────────────────────
# APPROACH 1:
# Name: **The Niche & Experience Revival**
# Concept: สร้างความแตกต่างจาก e-commerce โดยเน้นหนังสือเฉพาะกลุ่ม (Niche) และมอบประสบการณ์การอ่านที่เหนือกว่า (Experience)
# First Step: **วิเคราะห์ข้อมูลลูกค้าปัจจุบันอย่างละเอียด** (Demographics, ความสนใจ, พฤติกรรมการซื้อ) เพื่อระบุกลุ่มหนังสือเฉพาะที่ร้านมีศักยภาพในการตอบสนองความต้องการได้ดี และสำรวจความต้องการของลูกค้าเกี่ยวกับประสบการณ์ที่พวกเขาต้องการจากร้านหนังสือ (เช่น กิจกรรม, บรรยากาศ, บริการ)
#
# APPROACH 2:
# Name: **The Community Hub Transformation**
# Concept: เปลี่ยนร้านหนังสือให้เป็นศูนย์กลางของชุมชนคนรักหนังสือ โดยจัดกิจกรรมที่ส่งเสริมการอ่าน การเรียนรู้ และการพบปะสังสรรค์
# First Step: **จัดทำแบบสำรวจความคิดเห็นของคนในชุมชน** (ออนไลน์และออฟไลน์) เพื่อค้นหาความต้องการของพวกเขาเกี่ยวกับกิจกรรมที่พวกเขาอยากให้ร้านหนังสือจัด (เช่น ชมรมหนังสือ, เวิร์คช็อป, การบรรยายจากนักเขียน) และสำรวจความสนใจในประเด็นต่างๆ ที่เกี่ยวข้องกับหนังสือและการอ่าน
#
# APPROACH 3:
# Name: **The Digital Integration & Local Partnership Strategy**
# Concept: ผสานรวมช่องทางออนไลน์เข้ากับร้านหนังสือจริง และสร้างความร่วมมือกับธุรกิจท้องถิ่นอื่นๆ เพื่อขยายฐานลูกค้าและเพิ่มช่องทางรายได้
# First Step: **สร้างเว็บไซต์/เพจ Facebook ที่ใช้งานง่ายและน่าสนใจ** พร้อมรายละเอียดหนังสือ โปรโมชั่น และกิจกรรมต่างๆ ของร้าน รวมถึงช่องทางการติดต่อและสั่งซื้อสินค้าออนไลน์ และเริ่มทำการตลาดออนไลน์เบื้องต้น (เช่น โพสต์เนื้อหาที่น่าสนใจ, จัดกิจกรรมออนไลน์)
#
# ──────────────────────────────────────────────────
#
# 📊 Branch Evaluation
# ──────────────────────────────────────────────────
# แน่นอนครับ นี่คือการประเมินแนวทางการแก้ปัญหาที่เสนอมา โดยให้คะแนนในแต่ละด้าน และสรุปผล:
#
# **APPROACH 1: The Niche & Experience Revival**
#
# *   **ความเป็นไปได้ (Feasibility):** 7/10
#     *   การวิเคราะห์ข้อมูลลูกค้าและการสำรวจความต้องการเป็นสิ่งที่ทำได้จริง แต่การหาหนังสือเฉพาะกลุ่มที่ตอบโจทย์และสร้างประสบการณ์ที่โดดเด่นอาจต้องใช้เวลาและความคิดสร้างสรรค์
# *   **ประสิทธิภาพ (Effectiveness):** 8/10
#     *   การสร้างความแตกต่างจาก e-commerce เป็นกลยุทธ์ที่ฉลาด และการเน้นประสบการณ์สามารถดึงดูดลูกค้าที่ต้องการมากกว่าแค่การซื้อหนังสือ
# *   **ความเสี่ยง (Risk):** 6/10
#     *   ความเสี่ยงอยู่ที่การเลือกกลุ่มหนังสือเฉพาะที่ไม่ได้รับความนิยมเท่าที่ควร หรือการสร้างประสบการณ์ที่ไม่ตรงกับความต้องการของลูกค้า
# *   **ทรัพยากรที่ต้องใช้ (Resources):** 6/10
#     *   ต้องใช้ทรัพยากรในการวิเคราะห์ข้อมูล, จัดหาหนังสือเฉพาะกลุ่ม, ออกแบบและปรับปรุงร้านให้มีบรรยากาศที่น่าสนใจ, และฝึกอบรมพนักงาน
#
# **APPROACH 2: The Community Hub Transformation**
#
# *   **ความเป็นไปได้ (Feasibility):** 8/10
#     *   การจัดกิจกรรมต่างๆ เป็นสิ่งที่ทำได้ง่าย และการสำรวจความคิดเห็นของคนในชุมชนก็สามารถทำได้ทั้งออนไลน์และออฟไลน์
# *   **ประสิทธิภาพ (Effectiveness):** 7/10
#     *   การสร้างชุมชนคนรักหนังสือสามารถสร้างความผูกพันกับลูกค้าและดึงดูดลูกค้าใหม่ๆ ได้ แต่ต้องมีกิจกรรมที่น่าสนใจและต่อเนื่อง
# *   **ความเสี่ยง (Risk):** 7/10
#     *   ความเสี่ยงอยู่ที่การจัดกิจกรรมที่ไม่ได้รับความสนใจ หรือการไม่สามารถสร้างชุมชนที่เข้มแข็งได้
# *   **ทรัพยากรที่ต้องใช้ (Resources):** 7/10
#     *   ต้องใช้ทรัพยากรในการจัดกิจกรรม, ประชาสัมพันธ์, และอาจต้องปรับปรุงพื้นที่ในร้านให้เหมาะสมกับการจัดกิจกรรม
#
# **APPROACH 3: The Digital Integration & Local Partnership Strategy**
#
# *   **ความเป็นไปได้ (Feasibility):** 9/10
#     *   การสร้างเว็บไซต์/เพจ Facebook และการทำการตลาดออนไลน์เป็นสิ่งที่ทำได้ง่าย และการสร้างความร่วมมือกับธุรกิจท้องถิ่นก็สามารถทำได้โดยการเจรจา
# *   **ประสิทธิภาพ (Effectiveness):** 6/10
#     *   การมีช่องทางออนไลน์ช่วยเพิ่มโอกาสในการขายและเข้าถึงลูกค้า แต่ต้องมีการจัดการที่ดี และการสร้างความร่วมมือกับธุรกิจท้องถิ่นอาจไม่ได้ผลเสมอไป
# *   **ความเสี่ยง (Risk):** 8/10
#     *   ความเสี่ยงอยู่ที่การทำการตลาดออนไลน์ที่ไม่ประสบความสำเร็จ หรือการสร้างความร่วมมือที่ไม่เป็นประโยชน์
# *   **ทรัพยากรที่ต้องใช้ (Resources):** 8/10
#     *   ต้องใช้ทรัพยากรในการสร้างและดูแลเว็บไซต์/เพจ Facebook, ทำการตลาดออนไลน์, และเจรจาความร่วมมือกับธุรกิจท้องถิ่น
#
# **สรุปคะแนนรวมและจัดอันดับ:**
#
# | Approach                                  | ความเป็นไปได้ | ประสิทธิภาพ | ความเสี่ยง | ทรัพยากร | รวม   |
# | ----------------------------------------- | ------------- | ------------- | ----------- | ----------- | ----- |
# | 1: The Niche & Experience Revival        | 7             | 8             | 6           | 6           | **27** |
# | 2: The Community Hub Transformation       | 8             | 7             | 7           | 7           | **29** |
# | 3: The Digital Integration & Local Partnership | 9             | 6             | 8           | 8           | **31** |
#
# **อันดับ:**
#
# 1.  **APPROACH 3: The Digital Integration & Local Partnership Strategy (31 คะแนน)**
# 2.  **APPROACH 2: The Community Hub Transformation (29 คะแนน)**
# 3.  **APPROACH 1: The Niche & Experience Revival (27 คะแนน)**
#
# **คำแนะนำเพิ่มเติม:**
#
# *   **APPROACH 3** ดูเหมือนจะเป็นแนวทางที่น่าสนใจที่สุด เนื่องจากมีความเป็นไปได้สูง ใช้ทรัพยากรน้อย และมีความเสี่ยงต่ำ อย่างไรก็ตาม ประสิทธิภาพอาจไม่สูงเท่า APPROACH 1 ดังนั้นควรพิจารณาปรับปรุง APPROACH 3 โดยเพิ่มองค์ประกอบของการสร้างประสบการณ์ที่น่าสนใจเข้าไปด้วย
# *   **APPROACH 2** ก็เป็นแนวทางที่ดี แต่ต้องระมัดระวังเรื่องการจัดกิจกรรมที่ไม่ได้รับความสนใจ
# *   **APPROACH 1** เป็นแนวทางที่เน้นคุณภาพ แต่ต้องใช้ทรัพยากรมากและมีความเสี่ยงสูง ดังนั้นควรพิจารณาทำควบคู่ไปกับ APPROACH 3 โดยเริ่มจากกลุ่มหนังสือเฉพาะที่ได้รับความนิยมก่อน
#
# **ข้อควรพิจารณาเพิ่มเติม:**
#
# *   **งบประมาณ:** ควรจัดสรรงบประมาณให้เหมาะสมกับแต่ละแนวทาง โดยเน้นไปที่แนวทางที่มีศักยภาพมากที่สุด
# *   **ระยะเวลา:** ควรมีแผนการดำเนินงานที่ชัดเจนและติดตามผลอย่างสม่ำเสมอ เพื่อให้บรรลุเป้าหมายภายใน 1 ปี
# *   **ความยืดหยุ่น:** ควรมีความยืดหยุ่นในการปรับเปลี่ยนแผน หากพบว่าแนวทางใดไม่ได้ผลตามที่คาดหวัง
#
# หวังว่าการประเมินนี้จะเป็นประโยชน์ในการตัดสินใจเลือกแนวทางการแก้ปัญหาที่เหมาะสมที่สุดสำหรับร้านหนังสือของคุณนะครับ!
#
# ──────────────────────────────────────────────────
#
# 🎯 Expanded Best Solution
# ──────────────────────────────────────────────────
# แน่นอนครับ จากการประเมินก่อนหน้า APPROACH 3: The Digital Integration & Local Partnership Strategy ได้คะแนนสูงสุด ผมจะขยายรายละเอียดของแนวทางนี้ โดยอิงตามคำแนะนำของคุณ:
#
# **APPROACH 3: The Digital Integration & Local Partnership Strategy (ขยายรายละเอียด)**
#
# **ภาพรวม:**
#
# แนวทางนี้มุ่งเน้นการขยายช่องทางการขายและการเข้าถึงลูกค้าผ่านช่องทางดิจิทัล ควบคู่ไปกับการสร้างความร่วมมือกับธุรกิจท้องถิ่น เพื่อสร้างเครือข่ายและเพิ่มโอกาสในการขาย
#
# **1. แผนการดำเนินงานโดยละเอียด:**
#
# *   **1.1 สร้างและพัฒนาช่องทางออนไลน์:**
#     *   **เว็บไซต์ (Website):**
#         *   **วัตถุประสงค์:** เป็นหน้าร้านออนไลน์ที่ลูกค้าสามารถเลือกดูและสั่งซื้อหนังสือได้
#         *   **รายละเอียด:**
#             *   ออกแบบเว็บไซต์ให้ใช้งานง่าย (User-friendly) และตอบสนองบนมือถือ (Responsive)
#             *   มีระบบค้นหาหนังสือที่แม่นยำและหลากหลาย (ตามชื่อหนังสือ, ผู้แต่ง, สำนักพิมพ์, หมวดหมู่)
#             *   มีระบบตะกร้าสินค้าและการชำระเงินที่ปลอดภัย (Payment Gateway)
#             *   มีระบบจัดการสต็อกสินค้า (Inventory Management)
#             *   มีระบบรีวิวและให้คะแนนหนังสือ (Review & Rating)
#             *   มีบล็อก (Blog) หรือบทความเกี่ยวกับหนังสือและนักเขียน
#         *   **เครื่องมือ:** WordPress, Shopify, หรือแพลตฟอร์ม e-commerce อื่นๆ
#     *   **เพจ Facebook (Facebook Page):**
#         *   **วัตถุประสงค์:** สร้างการรับรู้ (Awareness), สร้างปฏิสัมพันธ์ (Engagement), และโปรโมทสินค้า
#         *   **รายละเอียด:**
#             *   โพสต์เนื้อหาที่น่าสนใจเกี่ยวกับหนังสือ, นักเขียน, และกิจกรรมต่างๆ
#             *   จัดกิจกรรมออนไลน์ เช่น ไลฟ์สดแนะนำหนังสือ, ตอบคำถามเกี่ยวกับหนังสือ, แจกของรางวัล
#             *   ใช้ Facebook Ads เพื่อโปรโมทสินค้าและเข้าถึงกลุ่มเป้าหมาย
#             *   ตอบคำถามและข้อความจากลูกค้าอย่างรวดเร็ว
#         *   **เครื่องมือ:** Facebook Business Suite, Canva (สำหรับออกแบบภาพ)
# *   **1.2 การตลาดออนไลน์ (Online Marketing):**
#     *   **SEO (Search Engine Optimization):** ปรับปรุงเว็บไซต์ให้ติดอันดับต้นๆ ในผลการค้นหาของ Google
#     *   **SEM (Search Engine Marketing):** ลงโฆษณาบน Google Ads เพื่อเพิ่มการเข้าชมเว็บไซต์
#     *   **Social Media Marketing:** โปรโมทสินค้าและกิจกรรมบน Facebook, Instagram, และแพลตฟอร์มอื่นๆ
#     *   **Email Marketing:** ส่งอีเมลข่าวสารและโปรโมชั่นให้กับลูกค้า
# *   **1.3 สร้างความร่วมมือกับธุรกิจท้องถิ่น (Local Partnership):**
#     *   **ร้านกาแฟ:** วางหนังสือขายในร้านกาแฟ หรือจัดกิจกรรมอ่านหนังสือในร้านกาแฟ
#     *   **โรงเรียน/มหาวิทยาลัย:** จัดกิจกรรมส่งเสริมการอ่านในโรงเรียน/มหาวิทยาลัย หรือให้ส่วนลดพิเศษสำหรับนักเรียน/นักศึกษา
#     *   **โรงแรม/เกสต์เฮาส์:** วางหนังสือในห้องพัก หรือให้ส่วนลดพิเศษสำหรับแขกที่มาพัก
#     *   **ร้านอาหาร:** จัดกิจกรรมแลกเปลี่ยนหนังสือ หรือให้ส่วนลดพิเศษสำหรับลูกค้าที่นำหนังสือมาด้วย
#     *   **ห้องสมุด:** ร่วมกันจัดกิจกรรมส่งเสริมการอ่าน หรือแลกเปลี่ยนหนังสือ
# *   **1.4 การจัดการลูกค้าสัมพันธ์ (Customer Relationship Management - CRM):**
#     *   เก็บข้อมูลลูกค้า (ชื่อ, ที่อยู่, อีเมล, เบอร์โทรศัพท์, ประวัติการซื้อ)
#     *   ใช้ข้อมูลลูกค้าเพื่อปรับปรุงการบริการและนำเสนอสินค้าที่ตรงกับความต้องการ
#     *   สร้างระบบสมาชิก (Membership Program) เพื่อให้สิทธิพิเศษแก่ลูกค้าประจำ
#
# **2. Milestones สำคัญ:**
#
# *   **เดือนที่ 1:**
#     *   สร้างเว็บไซต์และเพจ Facebook
#     *   เริ่มทำการตลาดออนไลน์เบื้องต้น (SEO, SEM, Social Media Marketing)
#     *   ติดต่อธุรกิจท้องถิ่นเพื่อสร้างความร่วมมือ
# *   **เดือนที่ 3:**
#     *   เปิดตัวเว็บไซต์และเพจ Facebook อย่างเป็นทางการ
#     *   จัดกิจกรรมออนไลน์ครั้งแรก (เช่น ไลฟ์สดแนะนำหนังสือ)
#     *   เริ่มวางหนังสือขายในร้านกาแฟ
# *   **เดือนที่ 6:**
#     *   ประเมินผลการดำเนินงานในช่วง 3 เดือนแรก
#     *   ปรับปรุงเว็บไซต์และเพจ Facebook ตามผลการประเมิน
#     *   ขยายความร่วมมือกับธุรกิจท้องถิ่น
# *   **เดือนที่ 9:**
#     *   จัดกิจกรรมส่งเสริมการอ่านในโรงเรียน/มหาวิทยาลัย
#     *   เริ่มใช้ระบบ CRM
# *   **เดือนที่ 12:**
#     *   ประเมินผลการดำเนินงานตลอดทั้งปี
#     *   วางแผนการดำเนินงานสำหรับปีต่อไป
#
# **3. คาดการณ์อุปสรรคและวิธีรับมือ:**
#
# *   **อุปสรรค:**
#     *   การแข่งขันสูงในตลาดออนไลน์
#     *   การเปลี่ยนแปลงพฤติกรรมของผู้บริโภค
#     *   การขาดแคลนทรัพยากร (เงินทุน, บุคลากร)
#     *   การเปลี่ยนแปลงนโยบายของแพลตฟอร์มออนไลน์ (Facebook, Google)
# *   **วิธีรับมือ:**
#     *   สร้างความแตกต่างจากคู่แข่ง (เช่น นำเสนอหนังสือหายาก, ให้บริการที่ดีกว่า)
#     *   ติดตามและปรับตัวให้เข้ากับการเปลี่ยนแปลงพฤติกรรมของผู้บริโภค
#     *   หาแหล่งเงินทุนเพิ่มเติม (เช่น เงินกู้, นักลงทุน)
#     *   พัฒนาทักษะของบุคลากร (เช่น การตลาดออนไลน์, การบริการลูกค้า)
#     *   ติดตามข่าวสารและปรับตัวให้เข้ากับการเปลี่ยนแปลงนโยบายของแพลตฟอร์มออนไลน์
#
# **4. ทรัพยากรที่ต้องเตรียม:**
#
# *   **เงินทุน:**
#     *   ค่าสร้างและดูแลเว็บไซต์
#     *   ค่าทำการตลาดออนไลน์
#     *   ค่าจัดกิจกรรม
#     *   ค่าจ้างบุคลากร
# *   **บุคลากร:**
#     *   นักพัฒนาเว็บไซต์ (Web Developer)
#     *   นักการตลาดออนไลน์ (Digital Marketer)
#     *   นักออกแบบกราฟิก (Graphic Designer)
#     *   พนักงานขาย (Salesperson)
#     *   พนักงานบริการลูกค้า (Customer Service)
# *   **เครื่องมือ:**
#     *   คอมพิวเตอร์
#     *   อินเทอร์เน็ต
#     *   ซอฟต์แวร์ (เช่น WordPress, Shopify, Facebook Business Suite, Canva)
#
# **5. Timeline คร่าวๆ:**
#
# *   **เดือนที่ 1-3:** เตรียมความพร้อม (สร้างเว็บไซต์, เพจ Facebook, ติดต่อธุรกิจท้องถิ่น)
# *   **เดือนที่ 3-6:** เปิดตัวและโปรโมท (จัดกิจกรรมออนไลน์, วางหนังสือขายในร้านกาแฟ)
# *   **เดือนที่ 6-9:** ขยายความร่วมมือ (จัดกิจกรรมในโรงเรียน/มหาวิทยาลัย, เริ่มใช้ระบบ CRM)
# *   **เดือนที่ 9-12:** ประเมินผลและปรับปรุง (วางแผนสำหรับปีต่อไป)
#
# **ข้อควรพิจารณาเพิ่มเติม:**
#
# *   **การวัดผล:** กำหนดตัวชี้วัดความสำเร็จ (Key Performance Indicators - KPIs) เช่น จำนวนผู้เข้าชมเว็บไซต์, จำนวนผู้ติดตามเพจ Facebook, ยอดขาย, ความพึงพอใจของลูกค้า
# *   **การปรับปรุง:** ปรับปรุงแผนการดำเนินงานอย่างสม่ำเสมอตามผลการวัดผล
# *   **ความยืดหยุ่น:** พร้อมที่จะปรับเปลี่ยนแผนหากพบว่าแนวทางใดไม่ได้ผลตามที่คาดหวัง
#
# หวังว่าแผนการดำเนินงานนี้จะเป็นประโยชน์ในการนำไปปรับใช้กับร้านหนังสือของคุณนะครับ! หากมีคำถามเพิ่มเติม สามารถสอบถามได้เลยครับ
#
# ──────────────────────────────────────────────────

# %% [markdown]
# ---
# # 📘 Part 7: Self-Feedback
# **ระดับความยาก: ⭐⭐⭐⭐ (สูง)**
#
# ---
# ## 📖 ทฤษฎีเชิงลึก
#
# **Self-Feedback** คือเทคนิคที่ให้ LLM สร้าง feedback ให้ตัวเองตามเกณฑ์ที่กำหนด
# แล้วใช้ feedback นั้นปรับปรุงคำตอบ
#
# ### ความแตกต่างจาก Reflection:
# ```
# ┌────────────────────────────────────────────────────────┐
# │           🔍 REFLECTION vs SELF-FEEDBACK                │
# │                                                          │
# │  Reflection:                                             │
# │  • ทบทวนภาพรวมทั่วไป                                    │
# │  • ไม่มีเกณฑ์ตายตัว                                     │
# │  • เหมือน "อ่านทวน"                                     │
# │                                                          │
# │  Self-Feedback:                                          │
# │  • ใช้ rubric/criteria เฉพาะ                             │
# │  • ให้คะแนนตามเกณฑ์                                     │
# │  • เหมือน "ตรวจตาม marking scheme"                      │
# │                                                          │
# │  Example Criteria:                                       │
# │  ┌──────────────────────────┐                           │
# │  │ Accuracy     ████████░░ 8/10  │                      │
# │  │ Completeness █████████░ 9/10  │                      │
# │  │ Clarity      ███████░░░ 7/10  │  ← ต้องปรับปรุง    │
# │  │ Engagement   ██████░░░░ 6/10  │  ← ต้องปรับปรุง    │
# │  │ Objectivity  █████████░ 9/10  │                      │
# │  └──────────────────────────┘                           │
# └────────────────────────────────────────────────────────┘
# ```

# %%
# === Lab 7.1: Self-Feedback with Criteria ===

def self_feedback_with_criteria(task: str, criteria: List[str]) -> Dict:
    """
    Self-Feedback ด้วยเกณฑ์ที่กำหนด
    """
    results = {}
    
    # Step 1: Generate initial response
    response1 = call_gemini(task)
    results["initial_response"] = response1
    print_section("Initial Response", response1, "📝")
    
    # Step 2: Self-Feedback based on criteria
    criteria_text = "\n".join([f"- {c}" for c in criteria])
    feedback_prompt = f"""
ประเมินคำตอบต่อไปนี้ตามเกณฑ์ที่กำหนด:

งาน:
{task}

คำตอบ:
{results['initial_response']}

เกณฑ์การประเมิน:
{criteria_text}

สำหรับแต่ละเกณฑ์:
1. ให้คะแนน 1-10
2. อธิบายเหตุผล
3. เสนอการปรับปรุง

Format:
[เกณฑ์ 1]: [คะแนน]/10
- เหตุผล: ...
- การปรับปรุง: ...
"""
    
    response2 = call_gemini(feedback_prompt)
    results["self_feedback"] = response2
    print_section("Self-Feedback", response2, "🔍")
    
    # Step 3: Improve based on feedback
    improve_prompt = f"""
ปรับปรุงคำตอบตาม feedback:

งานเดิม:
{task}

คำตอบเดิม:
{results['initial_response']}

Feedback:
{results['self_feedback']}

สร้างคำตอบใหม่ที่ปรับปรุงตาม feedback ทุกข้อ
"""
    
    response3 = call_gemini(improve_prompt)
    results["improved_response"] = response3
    print_section("Improved Response", response3, "✨")
    
    return results

# %%
# ทดสอบ Self-Feedback
writing_task = """
เขียนบทความสั้น (200-300 คำ) เกี่ยวกับ "ผลกระทบของ AI ต่อตลาดแรงงานไทย"
"""

criteria = [
    "ความถูกต้องของข้อมูล (Accuracy)",
    "ความครบถ้วนของเนื้อหา (Completeness)",
    "ความชัดเจนในการสื่อสาร (Clarity)",
    "ความน่าสนใจ (Engagement)",
    "ความเป็นกลาง (Objectivity)"
]

print("🔄 Starting Self-Feedback Process...")
sf_results = self_feedback_with_criteria(writing_task, criteria)
# Out:
# 🔄 Starting Self-Feedback Process...
#
# 📝 Initial Response
# ──────────────────────────────────────────────────
# ## AI เขย่าตลาดแรงงานไทย: โอกาสและความท้าทายที่ต้องรับมือ
#
# ปัญญาประดิษฐ์ (AI) กำลังเข้ามามีบทบาทสำคัญในตลาดแรงงานไทยอย่างหลีกเลี่ยงไม่ได้ การเปลี่ยนแปลงนี้มาพร้อมทั้งโอกาสและภัยคุกคามที่ต้องทำความเข้าใจและเตรียมพร้อมรับมือ
#
# ในด้านบวก AI สามารถเพิ่มประสิทธิภาพการทำงาน ลดต้นทุน และสร้างโอกาสทางธุรกิจใหม่ๆ งานที่ซ้ำซากและใช้แรงงานคนจำนวนมาก เช่น งานในสายการผลิต หรืองานบริการลูกค้าเบื้องต้น อาจถูกแทนที่ด้วยระบบอัตโนมัติ ทำให้แรงงานสามารถพัฒนาทักษะไปสู่ตำแหน่งที่ต้องใช้ความคิดสร้างสรรค์ การวิเคราะห์ และการตัดสินใจที่ซับซ้อนมากขึ้น นอกจากนี้ AI ยังสามารถสร้างงานใหม่ๆ ในสาขาที่เกี่ยวข้องกับการพัฒนา ดูแล และใช้งานระบบ AI เอง
#
# อย่างไรก็ตาม การเข้ามาของ AI ก็ก่อให้เกิดความกังวลเกี่ยวกับการว่างงาน โดยเฉพาะในกลุ่มแรงงานทักษะต่ำที่อาจไม่สามารถปรับตัวได้ทันต่อการเปลี่ยนแปลง นอกจากนี้ ยังมีความเสี่ยงที่ความเหลื่อมล้ำทางรายได้จะเพิ่มสูงขึ้น เนื่องจากผู้ที่มีทักษะด้าน AI จะได้รับค่าตอบแทนที่สูงกว่า
#
# เพื่อรับมือกับผลกระทบเหล่านี้ ประเทศไทยจำเป็นต้องลงทุนในการพัฒนาทักษะของแรงงาน โดยเฉพาะทักษะด้านดิจิทัล การคิดเชิงวิพากษ์ และการแก้ปัญหา นอกจากนี้ ภาครัฐและเอกชนควรทำงานร่วมกันเพื่อสร้างระบบการศึกษาและการฝึกอบรมที่ตอบสนองต่อความต้องการของตลาดแรงงานในยุค AI รวมถึงการสร้างหลักประกันทางสังคมที่เข้มแข็งเพื่อรองรับผู้ที่ได้รับผลกระทบจากการเปลี่ยนแปลงนี้
#
# การปรับตัวและเตรียมพร้อมรับมือกับ AI อย่างชาญฉลาด จะช่วยให้ประเทศไทยสามารถคว้าโอกาสและลดผลกระทบเชิงลบ เพื่อสร้างตลาดแรงงานที่ยั่งยืนและเป็นประโยชน์ต่อทุกคน
#
# ──────────────────────────────────────────────────
#
# 🔍 Self-Feedback
# ──────────────────────────────────────────────────
# ## การประเมินบทความ "AI เขย่าตลาดแรงงานไทย: โอกาสและความท้าทายที่ต้องรับมือ"
#
# **ความถูกต้องของข้อมูล (Accuracy): 8/10**
#
# - เหตุผล: บทความนำเสนอข้อมูลที่ถูกต้องเกี่ยวกับผลกระทบของ AI ต่อตลาดแรงงานไทย โดยกล่าวถึงทั้งโอกาสและความท้าทาย อย่างไรก็ตาม อาจขาดการอ้างอิงถึงแหล่งข้อมูลที่น่าเชื่อถือ หรือสถิติที่สนับสนุนข้อโต้แย้งบางประการ เช่น ตัวเลขคาดการณ์การว่างงาน หรือการเติบโตของงานในสาขา AI
# - การปรับปรุง: เพิ่มการอ้างอิงถึงแหล่งข้อมูลที่น่าเชื่อถือ เช่น รายงานจากธนาคารโลก, สถาบันวิจัยเพื่อการพัฒนาประเทศไทย (TDRI), หรือหน่วยงานภาครัฐที่เกี่ยวข้อง เพื่อเพิ่มความน่าเชื่อถือของข้อมูล
#
# **ความครบถ้วนของเนื้อหา (Completeness): 9/10**
#
# - เหตุผล: บทความครอบคลุมประเด็นสำคัญเกี่ยวกับผลกระทบของ AI ต่อตลาดแรงงานไทย ทั้งในด้านบวก (ประสิทธิภาพ, โอกาสทางธุรกิจ, งานใหม่) และด้านลบ (การว่างงาน, ความเหลื่อมล้ำ) รวมถึงข้อเสนอแนะในการรับมือกับการเปลี่ยนแปลง
# - การปรับปรุง: อาจเพิ่มรายละเอียดเกี่ยวกับประเภทของทักษะที่จำเป็นในยุค AI ให้ชัดเจนยิ่งขึ้น เช่น ทักษะด้านการวิเคราะห์ข้อมูล, การเขียนโปรแกรม, หรือการจัดการโครงการที่เกี่ยวข้องกับ AI
#
# **ความชัดเจนในการสื่อสาร (Clarity): 10/10**
#
# - เหตุผล: บทความเขียนด้วยภาษาที่เข้าใจง่าย กระชับ และตรงประเด็น มีการจัดเรียงเนื้อหาอย่างเป็นระบบ ทำให้ผู้อ่านสามารถเข้าใจประเด็นหลักได้อย่างชัดเจน
# - การปรับปรุง: ไม่จำเป็นต้องปรับปรุงในส่วนนี้
#
# **ความน่าสนใจ (Engagement): 7/10**
#
# - เหตุผล: บทความนำเสนอหัวข้อที่น่าสนใจและมีความเกี่ยวข้องกับสถานการณ์ปัจจุบัน อย่างไรก็ตาม อาจขาดการยกตัวอย่างที่เป็นรูปธรรม หรือกรณีศึกษาที่น่าสนใจ เพื่อดึงดูดความสนใจของผู้อ่านมากยิ่งขึ้น
# - การปรับปรุง: เพิ่มตัวอย่างที่เป็นรูปธรรม เช่น บริษัทที่นำ AI มาใช้แล้วประสบความสำเร็จ หรือตัวอย่างของแรงงานที่ปรับตัวเข้ากับยุค AI ได้ดี เพื่อให้บทความมีความน่าสนใจและเข้าถึงได้ง่ายยิ่งขึ้น
#
# **ความเป็นกลาง (Objectivity): 9/10**
#
# - เหตุผล: บทความนำเสนอทั้งด้านบวกและด้านลบของผลกระทบของ AI อย่างสมดุล ไม่ได้เน้นไปที่ด้านใดด้านหนึ่งมากเกินไป
# - การปรับปรุง: ไม่จำเป็นต้องปรับปรุงในส่วนนี้
#
# **สรุป:**
#
# บทความนี้เป็นบทความที่ดีที่ให้ภาพรวมที่ครอบคลุมเกี่ยวกับผลกระทบของ AI ต่อตลาดแรงงานไทย โดยเน้นทั้งโอกาสและความท้าทาย การปรับปรุงเล็กน้อยในเรื่องของความถูกต้องของข้อมูลและความน่าสนใจจะทำให้บทความนี้ดียิ่งขึ้น
#
# ──────────────────────────────────────────────────
#
# ✨ Improved Response
# ──────────────────────────────────────────────────
# ## AI เขย่าตลาดแรงงานไทย: โอกาสและความท้าทายที่ต้องรับมือ
#
# ปัญญาประดิษฐ์ (AI) กำลังเข้ามามีบทบาทสำคัญในตลาดแรงงานไทยอย่างหลีกเลี่ยงไม่ได้ การเปลี่ยนแปลงนี้มาพร้อมทั้งโอกาสและภัยคุกคามที่ต้องทำความเข้าใจและเตรียมพร้อมรับมือ
#
# ในด้านบวก AI สามารถเพิ่มประสิทธิภาพการทำงาน ลดต้นทุน และสร้างโอกาสทางธุรกิจใหม่ๆ งานที่ซ้ำซากและใช้แรงงานคนจำนวนมาก เช่น งานในสายการผลิต หรืองานบริการลูกค้าเบื้องต้น อาจถูกแทนที่ด้วยระบบอัตโนมัติ ทำให้แรงงานสามารถพัฒนาทักษะไปสู่ตำแหน่งที่ต้องใช้ความคิดสร้างสรรค์ การวิเคราะห์ และการตัดสินใจที่ซับซ้อนมากขึ้น ตัวอย่างเช่น โรงงานผลิตรถยนต์หลายแห่งในประเทศไทยเริ่มนำหุ่นยนต์และระบบอัตโนมัติมาใช้ในสายการผลิต ทำให้สามารถผลิตรถยนต์ได้รวดเร็วและแม่นยำยิ่งขึ้น (อ้างอิง: รายงาน "อนาคตของงาน" โดยธนาคารโลก) นอกจากนี้ AI ยังสามารถสร้างงานใหม่ๆ ในสาขาที่เกี่ยวข้องกับการพัฒนา ดูแล และใช้งานระบบ AI เอง เช่น นักวิทยาศาสตร์ข้อมูล (Data Scientist), วิศวกร AI (AI Engineer) และผู้เชี่ยวชาญด้านจริยธรรม AI (AI Ethics Specialist)
#
# อย่างไรก็ตาม การเข้ามาของ AI ก็ก่อให้เกิดความกังวลเกี่ยวกับการว่างงาน โดยเฉพาะในกลุ่มแรงงานทักษะต่ำที่อาจไม่สามารถปรับตัวได้ทันต่อการเปลี่ยนแปลง สถาบันวิจัยเพื่อการพัฒนาประเทศไทย (TDRI) คาดการณ์ว่า AI อาจส่งผลกระทบต่อตำแหน่งงานในภาคอุตสาหกรรมและบริการมากที่สุด (อ้างอิง: บทวิเคราะห์ "ผลกระทบของ AI ต่อตลาดแรงงานไทย" โดย TDRI) นอกจากนี้ ยังมีความเสี่ยงที่ความเหลื่อมล้ำทางรายได้จะเพิ่มสูงขึ้น เนื่องจากผู้ที่มีทักษะด้าน AI จะได้รับค่าตอบแทนที่สูงกว่า
#
# เพื่อรับมือกับผลกระทบเหล่านี้ ประเทศไทยจำเป็นต้องลงทุนในการพัฒนาทักษะของแรงงาน โดยเฉพาะทักษะด้านดิจิทัล เช่น การวิเคราะห์ข้อมูล (Data Analytics), การเขียนโปรแกรม (Programming), และการจัดการโครงการที่เกี่ยวข้องกับ AI (AI Project Management) นอกจากนี้ ทักษะด้านการคิดเชิงวิพากษ์ (Critical Thinking) และการแก้ปัญหา (Problem Solving) ก็มีความสำคัญอย่างยิ่ง ภาครัฐและเอกชนควรทำงานร่วมกันเพื่อสร้างระบบการศึกษาและการฝึกอบรมที่ตอบสนองต่อความต้องการของตลาดแรงงานในยุค AI รวมถึงการสร้างหลักประกันทางสังคมที่เข้มแข็งเพื่อรองรับผู้ที่ได้รับผลกระทบจากการเปลี่ยนแปลงนี้ ตัวอย่างเช่น โครงการฝึกอบรมทักษะดิจิทัลของกระทรวงดิจิทัลเพื่อเศรษฐกิจและสังคม (MDES) เป็นหนึ่งในความพยายามที่จะช่วยให้แรงงานไทยปรับตัวเข้ากับยุคดิจิทัลได้
#
# การปรับตัวและเตรียมพร้อมรับมือกับ AI อย่างชาญฉลาด จะช่วยให้ประเทศไทยสามารถคว้าโอกาสและลดผลกระทบเชิงลบ เพื่อสร้างตลาดแรงงานที่ยั่งยืนและเป็นประโยชน์ต่อทุกคน
#
# ──────────────────────────────────────────────────

# %% [markdown]
# ---
# # 📘 Part 8: Self-Critique
# **ระดับความยาก: ⭐⭐⭐⭐⭐ (สูงมาก)**
#
# ---
# ## 📖 ทฤษฎีเชิงลึก
#
# **Self-Critique** เป็นเทคนิคที่ LLM วิพากษ์คำตอบของตัวเองอย่างเข้มงวด
# โดยพยายามหาข้อผิดพลาด จุดอ่อน และสมมติฐานที่ผิดพลาด
#
# ### 📊 Infographic: Self-Critique Intensity Spectrum
#
# ```
# ╔══════════════════════════════════════════════════════════════════╗
# ║            ⚔️ CRITIQUE INTENSITY SPECTRUM                       ║
# ╠══════════════════════════════════════════════════════════════════╣
# ║                                                                  ║
# ║  Gentle                                           Adversarial   ║
# ║  ←───────────────────────────────────────────────────────────→  ║
# ║                                                                  ║
# ║  Reflection    Self-Feedback    Self-Critique    Adversarial    ║
# ║  "ดีแล้ว       "ตรงนี้ได้ 7/10  "ข้อนี้ผิดเพราะ  "พิสูจน์ว่า  ║
# ║   แต่เพิ่ม     ควรปรับปรุง       สมมติฐานไม่มี    คำตอบนี้ผิด  ║
# ║   อีกนิด"      เรื่อง..."       หลักฐานรองรับ"   ทุกประเด็น"  ║
# ║                                                                  ║
# ║  ✅ Best Uses:                                                   ║
# ║  • Controversial topics     → ใช้ Adversarial Critique          ║
# ║  • Factual writing          → ใช้ Self-Critique                 ║
# ║  • Creative writing         → ใช้ Self-Feedback                 ║
# ║  • Quick iteration          → ใช้ Reflection                    ║
# ║                                                                  ║
# ║  Checklist สิ่งที่ Self-Critique ตรวจ:                           ║
# ║  □ Logical Fallacies (ตรรกะผิดพลาด)                             ║
# ║  □ Unsupported Assumptions (สมมติฐานไร้หลักฐาน)                 ║
# ║  □ Factual Errors (ข้อมูลผิด)                                   ║
# ║  □ Weak Arguments (ข้อโต้แย้งอ่อน)                              ║
# ║  □ Missing Perspectives (มุมมองที่ขาด)                          ║
# ║  □ Cognitive Biases (อคติทางความคิด)                            ║
# ║  □ Over-generalizations (เหมารวมเกินไป)                        ║
# ║  □ Cherry-picking evidence (เลือกหลักฐานเฉพาะที่สนับสนุน)     ║
# ╚══════════════════════════════════════════════════════════════════╝
# ```

# %%
# === Lab 8.1: Adversarial Self-Critique ===

def adversarial_self_critique(task: str, num_rounds: int = 2) -> Dict:
    """
    Self-Critique แบบ Adversarial: พยายามหักล้างคำตอบตัวเอง
    """
    results = {"rounds": []}
    current_response = None
    current_critique = None
    
    for round_num in range(num_rounds):
        print(f"\n🔄 Round {round_num + 1}")
        print("=" * 50)
        
        # Generate/Improve response
        if current_response is None:
            gen_prompt = f"{task}\n\nให้คำตอบที่ดีที่สุดของคุณ"
        else:
            gen_prompt = f"""
จากการวิพากษ์:
{current_critique}

งานเดิม:
{task}

คำตอบก่อนหน้า:
{current_response}

สร้างคำตอบใหม่ที่แก้ไขปัญหาทั้งหมดที่วิพากษ์ไว้
"""
        
        response = call_gemini(gen_prompt)
        current_response = response
        print_section("Response", current_response[:500], "📝")
        
        # Adversarial Critique
        critique_prompt = f"""
ในฐานะนักวิจารณ์ที่เข้มงวด (Harsh Critic) วิพากษ์คำตอบนี้:

งาน:
{task}

คำตอบ:
{current_response}

พยายามหา:
1. ข้อผิดพลาดทางตรรกะ (Logical Fallacies)
2. สมมติฐานที่ไม่มีหลักฐาน (Unsupported Assumptions)
3. ข้อมูลที่อาจไม่ถูกต้อง (Potentially Incorrect Information)
4. จุดอ่อนในการโต้แย้ง (Weak Arguments)
5. สิ่งที่ขาดหายไป (Missing Elements)
6. Bias ที่อาจมี (Potential Biases)

เป็นนักวิจารณ์ที่เข้มงวด - อย่าประนีประนอม!
"""
        
        critique_response = call_gemini(critique_prompt)
        current_critique = critique_response
        print_section("Critique", current_critique[:500], "⚔️")
        
        results["rounds"].append({
            "round": round_num + 1,
            "response": current_response,
            "critique": current_critique
        })
        
        time.sleep(1)
    
    # Final synthesis
    synthesis_prompt = f"""
หลังจากผ่าน {num_rounds} รอบของการวิพากษ์และปรับปรุง

งาน:
{task}

สร้างคำตอบสุดท้ายที่:
1. รวมจุดแข็งจากทุกรอบ
2. หลีกเลี่ยงจุดอ่อนที่ถูกวิพากษ์
3. มีความสมดุลและรอบคอบ

คำตอบรอบ 1:
{results['rounds'][0]['response'][:500]}

วิพากษ์รอบ 1:
{results['rounds'][0]['critique'][:500]}

คำตอบรอบ 2:
{results['rounds'][-1]['response'][:500]}
"""
    
    final_response = call_gemini(synthesis_prompt)
    results["final_response"] = final_response
    print_section("Final Response", final_response, "🏆")
    
    return results

# %%
# ทดสอบ Self-Critique
controversial_task = """
วิเคราะห์: "บริษัทควรบังคับให้พนักงานกลับมาทำงานที่ออฟฟิศ 100% หรือไม่?"
พิจารณาทั้งมุมมองของนายจ้างและลูกจ้าง
"""

print("⚔️ Starting Adversarial Self-Critique...")
critique_results = adversarial_self_critique(controversial_task, num_rounds=2)
# Out:
# ⚔️ Starting Adversarial Self-Critique...
#
# 🔄 Round 1
# ==================================================
#
# 📝 Response
# ──────────────────────────────────────────────────
# การบังคับให้พนักงานกลับมาทำงานที่ออฟฟิศ 100% เป็นประเด็นที่ซับซ้อนและไม่มีคำตอบที่ถูกต้องตายตัว ขึ้นอยู่กับปัจจัยหลายอย่าง ทั้งลักษณะธุรกิจ วัฒนธรรมองค์กร ความต้องการของพนักงาน และสถานการณ์ทางเศรษฐกิจ
#
# **มุมมองของนายจ้าง:**
#
# **ข้อดี:**
#
# *   **การทำงานร่วมกันและการสื่อสารที่ดีขึ้น:** การทำงานในออฟฟิศช่วยให้เกิดการสื่อสารแบบเห็นหน้า (face-to-face) ที่มีประสิทธิภาพมากขึ้น ส่งเสริมการทำงานเป็นทีม การระดมความคิด และการแก้ปัญหาร่วมกันได้รวดเร็ว
# *   **การควบคุมและการกำกับดูแลที่ง่ายขึ้น:** นายจ้างสามาร
# ──────────────────────────────────────────────────
#
# ⚔️ Critique
# ──────────────────────────────────────────────────
# เอาล่ะ มาดูกันว่าคำตอบนี้มีจุดอ่อนตรงไหนบ้าง ในฐานะนักวิจารณ์ที่เข้มงวด ผมจะไม่ปล่อยผ่านอะไรไปง่ายๆ แน่นอน
#
# **1. ข้อผิดพลาดทางตรรกะ (Logical Fallacies):**
#
# *   **False Dichotomy (ทางเลือกผิด):** คำตอบนี้เสนอว่าทางออกที่ดีที่สุดคือ Hybrid Work Model ซึ่งอาจเป็นจริง แต่ไม่ได้พิสูจน์ว่าทางเลือกอื่น (เช่น ทำงานที่ออฟฟิศ 100% หรือทำงานจากที่บ้าน 100%) เป็นไปไม่ได้หรือด้อยกว่าเสมอไป มันเหมือนกับการบอกว่า "ทางออกที่ดีที่สุดคือการกินทั้งผักและเนื้อ" โดยไม่ได้พิจารณาว่าบางคนอาจกินมังสวิรัติหรือกินแต่เนื้
# ──────────────────────────────────────────────────
#
# 🔄 Round 2
# ==================================================
#
# 📝 Response
# ──────────────────────────────────────────────────
# แน่นอน นี่คือคำตอบใหม่ที่ปรับปรุงแก้ไขตามข้อวิพากษ์วิจารณ์ โดยเน้นความชัดเจน หลักฐานเชิงประจักษ์ และการพิจารณาปัจจัยที่หลากหลายมากขึ้น:
#
# **วิเคราะห์: "บริษัทควรบังคับให้พนักงานกลับมาทำงานที่ออฟฟิศ 100% หรือไม่?" พิจารณาทั้งมุมมองของนายจ้างและลูกจ้าง**
#
# **คำตอบ:**
#
# การตัดสินใจว่าบริษัทควรบังคับให้พนักงานกลับมาทำงานที่ออฟฟิศ 100% หรือไม่ เป็นการตัดสินใจเชิงกลยุทธ์ที่ซับซ้อน ซึ่งต้องพิจารณาปัจจัยหลายด้านอย่างรอบคอบ โดยคำนึงถึงผลกระทบต่อทั้งนายจ้างและลูกจ้าง รวมถึงบริบทของอุตสาหกรรมและเป้าหมายทางธุร
# ──────────────────────────────────────────────────
#
# ⚔️ Critique
# ──────────────────────────────────────────────────
# เอาล่ะ มาวิจารณ์คำตอบนี้อย่างเข้มงวดกัน:
#
# **โดยรวม:** คำตอบนี้ดีขึ้นกว่าเดิมมาก มีการพยายามใส่ข้อมูลและมุมมองที่หลากหลาย แต่ก็ยังมีจุดอ่อนที่ต้องแก้ไขอีกมาก
#
# **1. ข้อผิดพลาดทางตรรกะ (Logical Fallacies):**
#
# *   **False Dichotomy (ทางเลือกที่ผิด):** คำตอบนี้มักจะนำเสนอทางเลือกแค่สองทาง (ทำงานที่ออฟฟิศ 100% vs. ทำงานจากที่บ้าน 100%) ทั้งที่ในความเป็นจริงมีรูปแบบการทำงานที่หลากหลายกว่านั้นมาก เช่น Hybrid model ที่มีความยืดหยุ่นสูงกว่า หรือการทำงานแบบ Remote-first ที่เน้นการทำงานจากระยะไกลเป็นหลัก
# *
# ──────────────────────────────────────────────────
#
# 🏆 Final Response
# ──────────────────────────────────────────────────
# ## คำตอบสุดท้าย: การวิเคราะห์นโยบายการกลับเข้าทำงานที่ออฟฟิศ 100%
#
# การตัดสินใจว่าบริษัทควรบังคับให้พนักงานกลับมาทำงานที่ออฟฟิศ 100% หรือไม่ เป็นการตัดสินใจเชิงกลยุทธ์ที่ซับซ้อน ซึ่งต้องพิจารณาปัจจัยหลายด้านอย่างรอบคอบ โดยคำนึงถึงผลกระทบต่อทั้งนายจ้างและลูกจ้าง รวมถึงบริบทของอุตสาหกรรม, วัฒนธรรมองค์กร, ลักษณะงาน, และเป้าหมายทางธุรกิจ การตัดสินใจที่เหมาะสมที่สุดไม่ใช่การเลือกทางใดทางหนึ่งอย่างสุดโต่ง แต่เป็นการประเมินอย่างละเอียดเพื่อหาจุดสมดุลที่เหมาะสมกับสถานการณ์เฉพาะของแต่ละองค์กร
#
# **มุมมองของนายจ้าง:**
#
# *   **ข้อดีของการกลับเข้าทำงานที่ออฟฟิศ 100%:**
#     *   **การเสริมสร้างวัฒนธรรมองค์กรและความรู้สึกเป็นเจ้าของ:** การทำงานร่วมกันในสถานที่เดียวกันช่วยสร้างความสัมพันธ์ระหว่างเพื่อนร่วมงาน, ส่งเสริมการเรียนรู้จากกันและกัน, และสร้างความรู้สึกเป็นส่วนหนึ่งขององค์กรที่แข็งแกร่งขึ้น ซึ่งอาจนำไปสู่ความผูกพันและความภักดีของพนักงานที่เพิ่มขึ้น
#     *   **การควบคุมคุณภาพและการกำกับดูแลที่เข้มงวดขึ้น:** ในบางอุตสาหกรรมหรือลักษณะงานที่ต้องการการควบคุมคุณภาพอย่างเข้มงวด หรือมีการจัดการข้อมูลที่เป็นความลับ การทำงานในออฟฟิศช่วยให้การกำกับดูแลและการตรวจสอบเป็นไปได้ง่ายขึ้น ลดความเสี่ยงด้านความปลอดภัยของข้อมูลและการละเมิดกฎระเบียบ
#     *   **การพัฒนาทักษะและการฝึกอบรมที่มีประสิทธิภาพ:** การฝึกอบรมแบบตัวต่อตัวและการเรียนรู้จากเพื่อนร่วมงานที่มีประสบการณ์สามารถทำได้ง่ายและมีประสิทธิภาพมากขึ้นในสภาพแวดล้อมของออฟฟิศ
# *   **ข้อเสียของการกลับเข้าทำงานที่ออฟฟิศ 100%:**
#     *   **ค่าใช้จ่ายที่เพิ่มขึ้น:** บริษัทต้องแบกรับค่าใช้จ่ายด้านสถานที่, สาธารณูปโภค, และอุปกรณ์สำนักงานที่เพิ่มขึ้น
#     *   **ความยากลำบากในการดึงดูดและรักษาบุคลากร:** พนักงานจำนวนมากให้ความสำคัญกับความยืดหยุ่นในการทำงาน การบังคับให้กลับเข้าทำงานที่ออฟฟิศ 100% อาจทำให้บริษัทเสียเปรียบในการแข่งขันเพื่อดึงดูดและรักษาบุคลากรที่มีความสามารถ
#     *   **ผลกระทบต่อขวัญและกำลังใจของพนักงาน:** การเดินทาง, การจราจร, และการขาดความยืดหยุ่นอาจส่งผลเสียต่อขวัญและกำลังใจของพนักงาน ลดประสิทธิภาพการทำงานโดยรวม
#
# **มุมมองของลูกจ้าง:**
#
# *   **ข้อดีของการกลับเข้าทำงานที่ออฟฟิศ 100%:**
#     *   **การสร้างความสัมพันธ์ทางสังคมและการทำงานเป็นทีม:** การทำงานในออฟฟิศช่วยให้พนักงานสร้างความสัมพันธ์กับเพื่อนร่วมงาน, เรียนรู้จากกันและกัน, และทำงานเป็นทีมได้อย่างมีประสิทธิภาพมากขึ้น
#     *   **การแบ่งแยกชีวิตการทำงานและชีวิตส่วนตัว:** การทำงานในออฟฟิศช่วยให้พนักงานสามารถแบ่งแยกชีวิตการทำงานและชีวิตส่วนตัวได้อย่างชัดเจน ลดความเครียดและความเหนื่อยล้า
#     *   **การเข้าถึงทรัพยากรและอุปกรณ์:** พนักงานสามารถเข้าถึงทรัพยากรและอุปกรณ์ที่จำเป็นสำหรับการทำงานได้อย่างง่ายดาย
# *   **ข้อเสียของการกลับเข้าทำงานที่ออฟฟิศ 100%:**
#     *   **การสูญเสียความยืดหยุ่น:** พนักงานสูญเสียความยืดหยุ่นในการจัดการเวลาและสถานที่ทำงาน ซึ่งอาจส่งผลกระทบต่อความสมดุลระหว่างชีวิตการทำงานและชีวิตส่วนตัว
#     *   **ค่าใช้จ่ายที่เพิ่มขึ้น:** พนักงานต้องเสียค่าใช้จ่ายในการเดินทาง, อาหาร, และเครื่องแต่งกายที่เพิ่มขึ้น
#     *   **ความเครียดและความเหนื่อยล้า:** การเดินทาง, การจราจร, และการทำงานในสภาพแวดล้อมที่อาจไม่สะดวกสบายอาจส่งผลเสียต่อสุขภาพและความเป็นอยู่ที่ดีของพนักงาน
#
# **ทางเลือกอื่น:**
#
# *   **Hybrid Work Model:** การผสมผสานระหว่างการทำงานที่ออฟฟิศและการทำงานจากที่บ้าน เป็นทางเลือกที่ได้รับความนิยมมากขึ้นเรื่อยๆ เนื่องจากสามารถตอบสนองความต้องการของทั้งนายจ้างและลูกจ้างได้
# *   **การทำงานจากที่บ้าน 100%:** เหมาะสำหรับบริษัทที่สามารถจัดการการทำงานทางไกลได้อย่างมีประสิทธิภาพ และพนักงานสามารถทำงานได้อย่างมีประสิทธิภาพโดยไม่ต้องอยู่ในออฟฟิศ
#
# **สรุป:**
#
# การตัดสินใจว่าบริษัทควรบังคับให้พนักงานกลับมาทำงานที่ออฟฟิศ 100% หรือไม่ ควรพิจารณาจากปัจจัยที่กล่าวมาข้างต้นอย่างรอบคอบ โดยคำนึงถึงผลกระทบต่อทั้งนายจ้างและลูกจ้าง การตัดสินใจที่เหมาะสมที่สุดไม่ใช่การเลือกทางใดทางหนึ่งอย่างสุดโต่ง แต่เป็นการประเมินอย่างละเอียดเพื่อหาจุดสมดุลที่เหมาะสมกับสถานการณ์เฉพาะของแต่ละองค์กร การสื่อสารอย่างเปิดเผยและโปร่งใสกับพนักงานเป็นสิ่งสำคัญเพื่อให้มั่นใจว่าการตัดสินใจนั้นได้รับการยอมรับและสนับสนุนจากทุกฝ่าย
#
# **สิ่งที่เพิ่มเข้ามาจากรอบก่อน:**
#
# *   **เน้นย้ำความซับซ้อนและบริบท:** เน้นว่าไม่มีคำตอบเดียวที่ใช้ได้กับทุกบริษัท และการตัดสินใจต้องพิจารณาบริบทเฉพาะของแต่ละองค์กร
# *   **หลีกเลี่ยง False Dichotomy:** ไม่ได้เสนอ Hybrid Work Model เป็นทางออกที่ดีที่สุด แต่เสนอเป็นทางเลือกหนึ่งที่ควรพิจารณา
# *   **เพิ่มรายละเอียดเกี่ยวกับข้อดีข้อเสีย:** ขยายความในแต่ละข้อดีข้อเสียให้ชัดเจนและมีเหตุผลมากขึ้น
# *   **เน้นการสื่อสาร:** เพิ่มความสำคัญของการสื่อสารกับพนักงานเพื่อให้มั่นใจว่าการตัดสินใจได้รับการยอมรับ
# *   **ความสมดุล:** พยายามนำเสนอทั้งมุมมองของนายจ้างและลูกจ้างอย่างเท่าเทียมกัน
#
# คำตอบนี้พยายามที่จะเป็นกลาง, รอบคอบ, และให้ข้อมูลที่ครบถ้วน เพื่อให้ผู้ที่กำลังพิจารณาประเด็นนี้สามารถนำไปใช้ในการตัดสินใจได้อย่างมีข้อมูลและเหตุผล
#
# ──────────────────────────────────────────────────

# %% [markdown]
# ---
# # 📊 Part 9: Evaluation Methods (Extended)
# **LLM-as-a-Judge, Reference-free, Automated Metrics & More**
#
# ---
# ## 📖 ทฤษฎีเชิงลึก: ทำไมต้อง Evaluate?
#
# ```
# ╔══════════════════════════════════════════════════════════════════════╗
# ║              📊 WHY EVALUATION MATTERS                              ║
# ╠══════════════════════════════════════════════════════════════════════╣
# ║                                                                      ║
# ║  "If you can't measure it, you can't improve it."                   ║
# ║  — Peter Drucker                                                     ║
# ║                                                                      ║
# ║  ❌ Without Evaluation:      ✅ With Evaluation:                     ║
# ║  • ไม่รู้ว่าดีพอหรือยัง      • วัดคุณภาพเป็นตัวเลข                  ║
# ║  • ไม่รู้ว่า prompt ไหนดีกว่า  • เปรียบเทียบเทคนิคได้                ║
# ║  • ไม่รู้ว่า model ไหนดีกว่า  • ปรับปรุงอย่างเป็นระบบ               ║
# ║  • ไม่รู้จุดอ่อนที่แท้จริง    • ค้นพบ failure modes                  ║
# ║  • ไม่สามารถ scale ได้       • Automate quality assurance          ║
# ║                                                                      ║
# ╚══════════════════════════════════════════════════════════════════════╝
# ```
#
# ### 📊 Evaluation Method Taxonomy
#
# ```
# ┌──────────────────────────────────────────────────────────────────┐
# │                  📊 EVALUATION TAXONOMY                          │
# │                                                                   │
# │  ┌─────────────────────────────────────────────────────────────┐ │
# │  │  1. HUMAN EVALUATION (Gold Standard)                        │ │
# │  │     • Expert review          • Crowdsourcing                │ │
# │  │     • A/B testing            • User studies                 │ │
# │  │     ✅ Most reliable  ❌ Expensive, slow, not scalable      │ │
# │  └─────────────────────────────────────────────────────────────┘ │
# │                                                                   │
# │  ┌─────────────────────────────────────────────────────────────┐ │
# │  │  2. LLM-BASED EVALUATION (Semi-automated)                  │ │
# │  │     • LLM-as-a-Judge         • Pairwise Comparison          │ │
# │  │     • Reference-free         • Rubric-based Scoring         │ │
# │  │     • Multi-agent Debate     • Hallucination Detection      │ │
# │  │     ✅ Scalable, consistent  ❌ May have biases             │ │
# │  └─────────────────────────────────────────────────────────────┘ │
# │                                                                   │
# │  ┌─────────────────────────────────────────────────────────────┐ │
# │  │  3. AUTOMATED METRICS (Fully automated)                     │ │
# │  │     • BLEU, ROUGE, METEOR    • Semantic Similarity          │ │
# │  │     • Perplexity             • F1 / Exact Match             │ │
# │  │     • BERTScore              • Factual Consistency          │ │
# │  │     ✅ Fast, cheap, reproducible  ❌ Limited aspects        │ │
# │  └─────────────────────────────────────────────────────────────┘ │
# │                                                                   │
# │  ┌─────────────────────────────────────────────────────────────┐ │
# │  │  4. TASK-SPECIFIC EVALUATION                                │ │
# │  │     • Code: pass@k, execution accuracy                     │ │
# │  │     • Math: exact match with ground truth                   │ │
# │  │     • Classification: precision, recall, F1                 │ │
# │  │     • Summarization: ROUGE-L, factual consistency           │ │
# │  │     ✅ Most relevant  ❌ Need task-specific implementation  │ │
# │  └─────────────────────────────────────────────────────────────┘ │
# └──────────────────────────────────────────────────────────────────┘
# ```
#
# ### 🔑 LLM-as-a-Judge: Known Biases
#
# ```
# ╔══════════════════════════════════════════════════════════════╗
# ║          ⚠️ LLM-AS-A-JUDGE KNOWN BIASES                    ║
# ╠══════════════════════════════════════════════════════════════╣
# ║                                                              ║
# ║  1. 📐 Verbosity Bias                                       ║
# ║     LLM มักให้คะแนนคำตอบที่ยาวกว่าดีกว่า                   ║
# ║     → แก้: กำหนด "ความยาวไม่ใช่เกณฑ์"                      ║
# ║                                                              ║
# ║  2. 🔢 Position Bias                                        ║
# ║     ใน pairwise comparison มักเลือกตัวเลือกแรก             ║
# ║     → แก้: สลับตำแหน่ง A/B แล้วเฉลี่ย                     ║
# ║                                                              ║
# ║  3. 🪞 Self-enhancement Bias                                ║
# ║     LLM มักให้คะแนน output ของตัวเองสูง                    ║
# ║     → แก้: ใช้ model อื่นเป็น judge                         ║
# ║                                                              ║
# ║  4. 📊 Anchoring Bias                                       ║
# ║     คะแนนขึ้นกับ rubric/scale ที่ให้                        ║
# ║     → แก้: ใช้ detailed rubric พร้อมตัวอย่าง               ║
# ║                                                              ║
# ║  5. 🎭 Sycophancy                                           ║
# ║     LLM อาจ "เอาใจ" ผู้ถามมากเกินไป                       ║
# ║     → แก้: บอกให้ "be critical and honest"                  ║
# ║                                                              ║
# ║  Mitigation Strategies:                                      ║
# ║  ✅ ใช้ detailed rubric + ตัวอย่างคะแนน                     ║
# ║  ✅ สลับตำแหน่งใน pairwise comparison                       ║
# ║  ✅ ใช้หลาย judges แล้วเฉลี่ย                               ║
# ║  ✅ เปรียบเทียบกับ human evaluation                          ║
# ╚══════════════════════════════════════════════════════════════╝
# ```

# %%
# === Lab 9.1: LLM-as-a-Judge (Enhanced) ===

def llm_as_judge(task: str, response: str, rubric: Dict[str, str] = None) -> Dict:
    """
    ใช้ LLM เป็นผู้ตัดสินคุณภาพของ response (Enhanced version)
    """
    
    if rubric is None:
        rubric = {
            "relevance": "คำตอบตรงประเด็นกับคำถามมากน้อยเพียงใด",
            "accuracy": "ข้อมูลในคำตอบถูกต้องมากน้อยเพียงใด",
            "completeness": "คำตอบครบถ้วนสมบูรณ์มากน้อยเพียงใด",
            "clarity": "คำตอบชัดเจน เข้าใจง่ายมากน้อยเพียงใด",
            "helpfulness": "คำตอบมีประโยชน์ต่อผู้ถามมากน้อยเพียงใด"
        }
    
    rubric_text = "\n".join([f"- {k}: {v}" for k, v in rubric.items()])
    
    judge_prompt = f"""
คุณเป็นผู้ตัดสินที่เป็นกลางและเข้มงวด ประเมินคำตอบต่อไปนี้:

=== คำถาม/งาน ===
{task}

=== คำตอบที่ต้องประเมิน ===
{response}

=== เกณฑ์การประเมิน ===
{rubric_text}

กรุณาประเมินโดย:
1. ให้คะแนนแต่ละเกณฑ์ (1-10)
2. อธิบายเหตุผลของคะแนน
3. ให้คะแนนรวม (1-10)
4. สรุปจุดแข็งและจุดอ่อน
5. ให้ข้อเสนอแนะในการปรับปรุง

⚠️ สำคัญ: ความยาวของคำตอบไม่ใช่ตัวชี้วัดคุณภาพ
ให้ประเมินจากเนื้อหาจริงเท่านั้น

Format:
SCORES:
- relevance: [score]/10 - [reason]
- accuracy: [score]/10 - [reason]
- completeness: [score]/10 - [reason]
- clarity: [score]/10 - [reason]
- helpfulness: [score]/10 - [reason]

OVERALL: [score]/10

STRENGTHS:
- ...

WEAKNESSES:
- ...

SUGGESTIONS:
- ...
"""
    
    judge_response = call_gemini(judge_prompt)
    
    # Parse scores
    result = {
        "task": task,
        "response": response,
        "evaluation": judge_response,
        "scores": {}
    }
    
    # Extract individual scores
    for key in rubric.keys():
        score_match = re.search(rf'{key}:\s*(\d+(?:\.\d+)?)/10', judge_response)
        if score_match:
            result["scores"][key] = float(score_match.group(1))
    
    # Extract overall score
    overall_match = re.search(r'OVERALL:\s*(\d+(?:\.\d+)?)/10', judge_response)
    if overall_match:
        result["overall_score"] = float(overall_match.group(1))
    elif result["scores"]:
        result["overall_score"] = sum(result["scores"].values()) / len(result["scores"])
    
    return result

# %%
# ทดสอบ LLM-as-a-Judge

test_task = "อธิบายหลักการทำงานของ Blockchain แบบเข้าใจง่าย"

test_response = """
Blockchain คือระบบบันทึกข้อมูลแบบกระจายศูนย์ เปรียบเหมือนสมุดบัญชีที่ทุกคนถือสำเนาเหมือนกัน

หลักการทำงาน:
1. เมื่อมี transaction ใหม่ ข้อมูลจะถูกรวมเป็น "block"
2. Block จะถูกส่งให้ทุกคนในเครือข่ายตรวจสอบ
3. เมื่อตรวจสอบผ่าน block จะถูกเชื่อมต่อกับ block ก่อนหน้า
4. การแก้ไขข้อมูลเดิมแทบเป็นไปไม่ได้ เพราะต้องแก้ทุก block ที่ตามมา

ข้อดี: โปร่งใส ปลอดภัย ไม่มีตัวกลาง
ข้อเสีย: ใช้พลังงานมาก ช้ากว่าระบบทั่วไป
"""

print("⚖️ LLM-as-a-Judge Evaluation:")
judge_result = llm_as_judge(test_task, test_response)
print(judge_result["evaluation"])
if judge_result.get("scores"):
    print(f"\n📊 Parsed Scores: {judge_result['scores']}")
if judge_result.get("overall_score"):
    print(f"📊 Overall Score: {judge_result['overall_score']}/10")
# Out:
# ⚖️ LLM-as-a-Judge Evaluation:
# SCORES:
# - relevance: 10/10 - คำตอบตรงประเด็น อธิบายหลักการทำงานของ Blockchain ได้ตรงตามที่โจทย์ต้องการ
# - accuracy: 9/10 - ข้อมูลโดยรวมถูกต้อง แต่สามารถเพิ่มความแม่นยำในส่วนของการตรวจสอบ Block ได้ (เช่น กลไก Consensus)
# - completeness: 8/10 - อธิบายหลักการทำงานได้ครบถ้วนในระดับพื้นฐาน แต่สามารถเพิ่มรายละเอียดเกี่ยวกับกลไก Consensus และ Hash Function ได้
# - clarity: 10/10 - คำอธิบายชัดเจน เข้าใจง่าย ใช้ภาษาที่เหมาะสม
# - helpfulness: 9/10 - คำตอบมีประโยชน์สำหรับผู้ที่ต้องการทำความเข้าใจ Blockchain ในเบื้องต้น
#
# OVERALL: 9/10
#
# STRENGTHS:
# - อธิบายหลักการทำงานของ Blockchain ได้อย่างกระชับ ชัดเจน และเข้าใจง่าย
# - เปรียบเทียบ Blockchain กับสมุดบัญชี ทำให้เห็นภาพได้ชัดเจน
# - สรุปข้อดีข้อเสียได้ตรงประเด็น
#
# WEAKNESSES:
# - ขาดรายละเอียดเกี่ยวกับกลไก Consensus (เช่น Proof-of-Work, Proof-of-Stake) ซึ่งเป็นหัวใจสำคัญของการทำงานของ Blockchain
# - ไม่ได้กล่าวถึง Hash Function ซึ่งเป็นส่วนสำคัญในการรักษาความปลอดภัยของ Blockchain
#
# SUGGESTIONS:
# - เพิ่มคำอธิบายเกี่ยวกับกลไก Consensus อย่างง่าย เพื่อให้ผู้รับสารเข้าใจวิธีการตรวจสอบและยืนยัน Block
# - เพิ่มคำอธิบายเกี่ยวกับ Hash Function และบทบาทในการรักษาความปลอดภัยของข้อมูลใน Blockchain
# - อาจยกตัวอย่าง Transaction จริง เพื่อให้เห็นภาพการทำงานของ Blockchain ได้ชัดเจนยิ่งขึ้น
#
#
# 📊 Parsed Scores: {'relevance': 10.0, 'accuracy': 9.0, 'completeness': 8.0, 'clarity': 10.0, 'helpfulness': 9.0}
# 📊 Overall Score: 9.0/10

# %%
# === Lab 9.2: Pairwise Comparison with Position Debiasing ===

def pairwise_comparison_debiased(task: str, response_a: str, response_b: str) -> Dict:
    """
    เปรียบเทียบ 2 คำตอบ พร้อม position bias mitigation
    โดยสลับตำแหน่ง A/B แล้วเฉลี่ยผล
    """
    
    def run_comparison(first: str, second: str, first_label: str, second_label: str) -> str:
        compare_prompt = f"""
คุณเป็นผู้ตัดสินที่เป็นกลาง เปรียบเทียบ 2 คำตอบต่อไปนี้:

=== คำถาม/งาน ===
{task}

=== คำตอบ {first_label} ===
{first}

=== คำตอบ {second_label} ===
{second}

กรุณา:
1. วิเคราะห์จุดแข็งและจุดอ่อนของแต่ละคำตอบ
2. เปรียบเทียบในด้าน:
   - ความถูกต้อง
   - ความครบถ้วน
   - ความชัดเจน
   - ความเป็นประโยชน์
3. ตัดสินว่าคำตอบไหนดีกว่า

⚠️ ตัดสินจากคุณภาพเนื้อหา ไม่ใช่ตำแหน่ง
ความยาวไม่ใช่ตัวชี้วัดคุณภาพ

WINNER: [{first_label}/{second_label}/Tie]
REASON: [explanation]
"""
        return call_gemini(compare_prompt)
    
    # Run 1: A first, B second
    result_ab = run_comparison(response_a, response_b, "A", "B")
    
    time.sleep(1)
    
    # Run 2: B first, A second (swapped positions)
    result_ba = run_comparison(response_b, response_a, "B", "A")
    
    # Extract winners
    winner_ab = "A" if "WINNER: A" in result_ab.upper() or "WINNER:A" in result_ab.upper() else \
                "B" if "WINNER: B" in result_ab.upper() or "WINNER:B" in result_ab.upper() else "Tie"
    
    winner_ba = "B" if "WINNER: B" in result_ba.upper() or "WINNER:B" in result_ba.upper() else \
                "A" if "WINNER: A" in result_ba.upper() or "WINNER:A" in result_ba.upper() else "Tie"
    
    # Determine final winner (consistent across both orderings)
    if winner_ab == winner_ba:
        final_winner = winner_ab
        confidence = "HIGH (consistent across both orderings)"
    else:
        final_winner = "Tie (inconsistent)"
        confidence = "LOW (position bias detected)"
    
    return {
        "task": task,
        "run1_result": result_ab,
        "run1_winner": winner_ab,
        "run2_result": result_ba,
        "run2_winner": winner_ba,
        "final_winner": final_winner,
        "confidence": confidence
    }

# %%
# ทดสอบ Pairwise Comparison (Debiased)
comparison_task = "แนะนำวิธีประหยัดเงินสำหรับคนเริ่มต้นทำงาน"

response_a = """
วิธีประหยัดเงิน:
1. ทำบัญชีรายรับรายจ่าย
2. ตั้งเป้าออมเงิน 10-20% ของรายได้
3. หลีกเลี่ยงซื้อของไม่จำเป็น
4. ทำอาหารกินเองแทนซื้อข้าวนอกบ้าน
5. ใช้ระบบขนส่งสาธารณะ
"""

response_b = """
สำหรับคนเริ่มต้นทำงาน แนะนำหลัก 50/30/20:
- 50% สำหรับค่าใช้จ่ายจำเป็น (ค่าเช่า อาหาร เดินทาง)
- 30% สำหรับ lifestyle (ท่องเที่ยว entertainment)
- 20% สำหรับออม/ลงทุน

Tips เพิ่มเติม:
1. เปิดบัญชีออมเงินแยกต่างหาก - ตั้ง auto transfer ทุกเดือน
2. ใช้แอป track ค่าใช้จ่าย เช่น Money Lover
3. รอ 24 ชั่วโมงก่อนซื้อของราคาแพง
4. หา side income เพิ่ม
5. ศึกษาเรื่องการลงทุนพื้นฐาน

เป้าหมาย: มี Emergency Fund 3-6 เดือนภายใน 1 ปี
"""

print("🔄 Debiased Pairwise Comparison:")
comparison_result = pairwise_comparison_debiased(comparison_task, response_a, response_b)
print(f"\n📊 Run 1 Winner: {comparison_result['run1_winner']}")
print(f"📊 Run 2 Winner: {comparison_result['run2_winner']}")
print(f"🏆 Final Winner: {comparison_result['final_winner']}")
print(f"🎯 Confidence: {comparison_result['confidence']}")
# Out:
# 🔄 Debiased Pairwise Comparison:
#
# 📊 Run 1 Winner: B
# 📊 Run 2 Winner: B
# 🏆 Final Winner: B
# 🎯 Confidence: HIGH (consistent across both orderings)

# %%
# === Lab 9.3: Reference-free Evaluation ===

def reference_free_evaluation(task: str, response: str, evaluation_aspects: List[str] = None) -> Dict:
    """
    ประเมินคุณภาพโดยไม่ต้องมีคำตอบอ้างอิง
    """
    
    if evaluation_aspects is None:
        evaluation_aspects = [
            "Fluency (ความลื่นไหลของภาษา)",
            "Coherence (ความเชื่อมโยงของเนื้อหา)",
            "Informativeness (ความให้ข้อมูล)",
            "Factual Consistency (ความสอดคล้องของข้อเท็จจริง — ไม่ขัดแย้งกันเอง)",
            "No Hallucination (ไม่มีการสร้างข้อมูลเท็จ)"
        ]
    
    aspects_text = "\n".join([f"- {a}" for a in evaluation_aspects])
    
    eval_prompt = f"""
ประเมินคุณภาพของ text ต่อไปนี้โดยไม่ต้องมีคำตอบอ้างอิง:

=== Task/Context ===
{task}

=== Text to Evaluate ===
{response}

=== Evaluation Aspects ===
{aspects_text}

สำหรับแต่ละ aspect:
1. ให้คะแนน 1-10
2. ยกตัวอย่างประกอบจาก text
3. ระบุปัญหาที่พบ (ถ้ามี)

เพิ่มเติม:
- ตรวจสอบ potential hallucinations (ข้อมูลที่อาจไม่จริง)
- ระบุ claims ที่ต้องการ verification
- ตรวจสอบ internal consistency (ข้อมูลไม่ขัดแย้งกันเอง)

Format:
[Aspect 1]: [score]/10
- Evidence: [quote from text]
- Issues: [problems found]

...

POTENTIAL HALLUCINATIONS:
- [list suspicious claims]

CLAIMS NEEDING VERIFICATION:
- [list claims that should be fact-checked]

INTERNAL CONSISTENCY: [PASS/FAIL] — [explanation]

OVERALL QUALITY: [score]/10
SUMMARY: [brief summary]
"""
    
    response_eval = call_gemini(eval_prompt)
    
    return {
        "task": task,
        "response": response,
        "reference_free_evaluation": response_eval
    }

# %%
# ทดสอบ Reference-free Evaluation
test_text_task = "เขียนบทความเกี่ยวกับประวัติศาสตร์ของ Bitcoin"

test_text = """
Bitcoin ถูกสร้างขึ้นในปี 2009 โดย Satoshi Nakamoto ซึ่งเป็นนามแฝง 
ไม่มีใครรู้ตัวตนที่แท้จริง

ประวัติสำคัญ:
- 2008: เผยแพร่ whitepaper
- 2009: ขุด block แรก (Genesis Block) 
- 2010: มีการซื้อพิซซ่า 2 ถาดด้วย 10,000 BTC (มูลค่าปัจจุบันหลายพันล้าน)
- 2017: ราคาพุ่งแตะ $20,000 ครั้งแรก
- 2021: ราคาทำ all-time high ที่ $69,000
- 2024: มีการอนุมัติ Bitcoin ETF ในสหรัฐฯ

Bitcoin ใช้เทคโนโลยี Blockchain และมี supply จำกัดที่ 21 ล้านเหรียญ
ทำให้หลายคนมองว่าเป็น "digital gold"
"""

print("📋 Reference-free Evaluation:")
ref_free_result = reference_free_evaluation(test_text_task, test_text)
print(ref_free_result["reference_free_evaluation"])
# Out:
# 📋 Reference-free Evaluation:
# Okay, here's an evaluation of the provided text based on the given criteria:
#
# **Fluency:** 7/10
# - Evidence: "Bitcoin ถูกสร้างขึ้นในปี 2009 โดย Satoshi Nakamoto ซึ่งเป็นนามแฝง ไม่มีใครรู้ตัวตนที่แท้จริง"
# - Issues: The language is simple and understandable, but it lacks sophistication and reads a bit like a list of facts. The transitions between sentences could be smoother.
#
# **Coherence:** 6/10
# - Evidence: The text presents a chronological list of events and then briefly mentions the underlying technology and a common analogy.
# - Issues: The connection between the historical events and the explanation of Blockchain and "digital gold" is weak. It feels disjointed. The text jumps between topics without clear transitions.
#
# **Informativeness:** 7/10
# - Evidence: The text provides key dates and events in Bitcoin's history, including the whitepaper release, Genesis Block, the pizza transaction, price milestones, and ETF approval.
# - Issues: While it covers some important milestones, it lacks depth. It doesn't explain *why* these events were significant or provide context. For example, it mentions the pizza transaction but doesn't explain its historical importance in demonstrating Bitcoin's early use as a medium of exchange. It also doesn't explain what a Bitcoin ETF is or why its approval is significant.
#
# **Factual Consistency:** 9/10
# - Evidence: The dates and events listed generally align with commonly accepted Bitcoin history.
# - Issues: No immediately apparent factual inconsistencies.
#
# **No Hallucination:** 10/10
# - Evidence: All claims appear to be based on well-known facts.
# - Issues: None.
#
# **POTENTIAL HALLUCINATIONS:**
# - None.
#
# **CLAIMS NEEDING VERIFICATION:**
# - "ราคาทำ all-time high ที่ $69,000" - While generally accurate, the exact all-time high can vary slightly depending on the exchange used. It's best to cite a specific source for this claim.
#
# **INTERNAL CONSISTENCY:** PASS - The information presented does not contradict itself.
#
# **OVERALL QUALITY:** 7/10
# SUMMARY: The text provides a basic overview of Bitcoin's history, highlighting key events and its underlying technology. However, it lacks depth, context, and smooth transitions, making it feel somewhat disjointed and superficial. It's factually accurate but could benefit from more explanation and analysis.

# %%
# === Lab 9.4: Automated Metrics — BLEU-like & ROUGE-like Scores ===
# (Simplified implementation without external dependencies)

def simple_ngrams(text: str, n: int) -> List[Tuple]:
    """สร้าง n-grams จาก text"""
    words = text.lower().split()
    return [tuple(words[i:i+n]) for i in range(len(words)-n+1)]

def simple_bleu(reference: str, candidate: str, max_n: int = 4) -> Dict:
    """
    Simplified BLEU score calculation
    BLEU measures how many n-grams in candidate appear in reference
    
    ใช้สำหรับ: การแปลภาษา, งานที่มี reference answer
    """
    scores = {}
    
    for n in range(1, max_n + 1):
        ref_ngrams = simple_ngrams(reference, n)
        cand_ngrams = simple_ngrams(candidate, n)
        
        if not cand_ngrams:
            scores[f"bleu-{n}"] = 0.0
            continue
        
        ref_counter = Counter(ref_ngrams)
        matches = 0
        for ng in cand_ngrams:
            if ref_counter[ng] > 0:
                matches += 1
                ref_counter[ng] -= 1
        
        scores[f"bleu-{n}"] = matches / len(cand_ngrams)
    
    # Brevity penalty
    ref_len = len(reference.split())
    cand_len = len(candidate.split())
    bp = min(1.0, math.exp(1 - ref_len / cand_len)) if cand_len > 0 else 0
    
    # Geometric mean of n-gram precisions
    valid_scores = [s for s in scores.values() if s > 0]
    if valid_scores:
        geo_mean = math.exp(sum(math.log(s) for s in valid_scores) / len(valid_scores))
    else:
        geo_mean = 0
    
    scores["bleu_combined"] = bp * geo_mean
    scores["brevity_penalty"] = bp
    
    return scores

def simple_rouge_l(reference: str, candidate: str) -> Dict:
    """
    Simplified ROUGE-L score (Longest Common Subsequence)
    ROUGE measures how many n-grams in reference appear in candidate
    
    ใช้สำหรับ: Summarization
    """
    ref_words = reference.lower().split()
    cand_words = candidate.lower().split()
    
    # LCS using dynamic programming
    m, n = len(ref_words), len(cand_words)
    dp = [[0] * (n + 1) for _ in range(m + 1)]
    
    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if ref_words[i-1] == cand_words[j-1]:
                dp[i][j] = dp[i-1][j-1] + 1
            else:
                dp[i][j] = max(dp[i-1][j], dp[i][j-1])
    
    lcs_length = dp[m][n]
    
    precision = lcs_length / n if n > 0 else 0
    recall = lcs_length / m if m > 0 else 0
    f1 = (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    
    return {
        "rouge_l_precision": precision,
        "rouge_l_recall": recall,
        "rouge_l_f1": f1,
        "lcs_length": lcs_length
    }

def simple_rouge_n(reference: str, candidate: str, n: int = 1) -> Dict:
    """
    Simplified ROUGE-N score
    """
    ref_ngrams = simple_ngrams(reference, n)
    cand_ngrams = simple_ngrams(candidate, n)
    
    ref_counter = Counter(ref_ngrams)
    cand_counter = Counter(cand_ngrams)
    
    # Count overlapping n-grams
    overlap = 0
    for ng in cand_counter:
        overlap += min(cand_counter[ng], ref_counter[ng])
    
    precision = overlap / len(cand_ngrams) if cand_ngrams else 0
    recall = overlap / len(ref_ngrams) if ref_ngrams else 0
    f1 = (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    
    return {
        f"rouge_{n}_precision": precision,
        f"rouge_{n}_recall": recall,
        f"rouge_{n}_f1": f1
    }

# %%
# ทดสอบ Automated Metrics
reference_text = "Bitcoin ถูกสร้างขึ้นในปี 2009 โดยบุคคลนามแฝง Satoshi Nakamoto ใช้เทคโนโลยี Blockchain ที่มีความปลอดภัยสูง"
candidate_text = "Bitcoin สร้างขึ้นปี 2009 โดย Satoshi Nakamoto ใช้ Blockchain เป็นเทคโนโลยีหลัก มีความปลอดภัย"

print("📊 Automated Metrics:")
print("=" * 50)

bleu_scores = simple_bleu(reference_text, candidate_text)
print("BLEU Scores:")
for k, v in bleu_scores.items():
    print(f"  {k}: {v:.4f}")

print()

rouge_l = simple_rouge_l(reference_text, candidate_text)
print("ROUGE-L Scores:")
for k, v in rouge_l.items():
    print(f"  {k}: {v:.4f}" if isinstance(v, float) else f"  {k}: {v}")

print()

rouge_1 = simple_rouge_n(reference_text, candidate_text, n=1)
print("ROUGE-1 Scores:")
for k, v in rouge_1.items():
    print(f"  {k}: {v:.4f}")

rouge_2 = simple_rouge_n(reference_text, candidate_text, n=2)
print("\nROUGE-2 Scores:")
for k, v in rouge_2.items():
    print(f"  {k}: {v:.4f}")
# Out:
# 📊 Automated Metrics:
# ==================================================
# BLEU Scores:
#   bleu-1: 0.5000
#   bleu-2: 0.1111
#   bleu-3: 0.0000
#   bleu-4: 0.0000
#   bleu_combined: 0.2357
#   brevity_penalty: 1.0000
#
# ROUGE-L Scores:
#   rouge_l_precision: 0.5000
#   rouge_l_recall: 0.5556
#   rouge_l_f1: 0.5263
#   lcs_length: 5
#
# ROUGE-1 Scores:
#   rouge_1_precision: 0.5000
#   rouge_1_recall: 0.5556
#   rouge_1_f1: 0.5263
#
# ROUGE-2 Scores:
#   rouge_2_precision: 0.1111
#   rouge_2_recall: 0.1250
#   rouge_2_f1: 0.1176

# %% [markdown]
# ### 📖 ทำความเข้าใจ Automated Metrics
#
# ```
# ╔══════════════════════════════════════════════════════════════════╗
# ║               📊 UNDERSTANDING AUTOMATED METRICS                ║
# ╠══════════════════════════════════════════════════════════════════╣
# ║                                                                  ║
# ║  📘 BLEU (Bilingual Evaluation Understudy):                     ║
# ║  • วัด: n-gram ของ candidate ที่ตรงกับ reference                ║
# ║  • มุมมอง: Precision-focused                                    ║
# ║  • ดูว่า: "output มีคำ/วลีจาก reference มากเท่าไหร่"          ║
# ║  • ใช้กับ: Machine Translation, Text Generation                ║
# ║  • Score Range: 0.0 - 1.0 (สูง = ดี)                          ║
# ║                                                                  ║
# ║  📗 ROUGE (Recall-Oriented Understudy for Gisting Evaluation):  ║
# ║  • วัด: n-gram ของ reference ที่ปรากฏใน candidate              ║
# ║  • มุมมอง: Recall-focused                                      ║
# ║  • ดูว่า: "reference ถูกครอบคลุมมากเท่าไหร่"                   ║
# ║  • ใช้กับ: Summarization                                        ║
# ║  • Variants: ROUGE-1, ROUGE-2, ROUGE-L                        ║
# ║                                                                  ║
# ║  ⚖️ เปรียบเทียบ:                                                ║
# ║  ┌─────────────────────────────────────────────────────┐       ║
# ║  │ Reference: "แมวสีดำนอนบนเสื่อ"                       │       ║
# ║  │ Candidate: "แมวดำนอนอยู่บนเสื่อสีน้ำตาล"              │       ║
# ║  │                                                       │       ║
# ║  │ BLEU (Precision): candidate มีคำจาก ref กี่คำ?       │       ║
# ║  │ → "แมว", "นอน", "บน", "เสื่อ" = 4/6 ≈ 0.67        │       ║
# ║  │                                                       │       ║
# ║  │ ROUGE (Recall): ref ถูกครอบคลุมกี่คำ?                │       ║
# ║  │ → "แมว", "นอน", "บน", "เสื่อ" = 4/5 = 0.80        │       ║
# ║  └─────────────────────────────────────────────────────┘       ║
# ║                                                                  ║
# ║  ⚠️ Limitations:                                                ║
# ║  • ไม่เข้าใจ meaning (synonyms ไม่ match)                      ║
# ║  • ไม่เหมาะกับ open-ended tasks                                ║
# ║  • ต้องมี reference (ground truth)                              ║
# ║  → ใช้ร่วมกับ LLM-based evaluation เพื่อผลที่สมบูรณ์          ║
# ╚══════════════════════════════════════════════════════════════════╝
# ```

# %%
# === Lab 9.5: Semantic Similarity (LLM-based) ===

def semantic_similarity_eval(text_a: str, text_b: str) -> Dict:
    """
    ใช้ LLM ประเมิน semantic similarity ระหว่าง 2 texts
    (ใช้แทน embedding-based similarity เมื่อไม่มี embedding model)
    """
    
    eval_prompt = f"""
ประเมินความคล้ายคลึงทาง **ความหมาย** (semantic similarity) ของ 2 ข้อความต่อไปนี้:

=== Text A ===
{text_a}

=== Text B ===
{text_b}

ประเมินใน 4 มิติ:
1. **Topical Similarity** (หัวข้อเดียวกัน): 0.0 - 1.0
2. **Information Overlap** (ข้อมูลซ้อนทับ): 0.0 - 1.0
3. **Sentiment Alignment** (ความรู้สึกไปทางเดียวกัน): 0.0 - 1.0
4. **Intent Match** (เจตนาตรงกัน): 0.0 - 1.0

Overall Semantic Similarity: (เฉลี่ยถ่วงน้ำหนัก)

Format:
topical_similarity: [score]
information_overlap: [score]
sentiment_alignment: [score]
intent_match: [score]
overall_similarity: [score]
explanation: [brief explanation]
"""
    
    result = call_gemini(eval_prompt)
    
    # Extract overall similarity
    sim_match = re.search(r'overall_similarity:\s*([\d.]+)', result)
    overall_sim = float(sim_match.group(1)) if sim_match else None
    
    return {
        "text_a": text_a[:100],
        "text_b": text_b[:100],
        "evaluation": result,
        "overall_similarity": overall_sim
    }

# %%
# ทดสอบ Semantic Similarity
text_a = "AI กำลังเปลี่ยนแปลงวิธีการทำงาน หลายอาชีพอาจถูกแทนที่ด้วยระบบอัตโนมัติ"
text_b = "ปัญญาประดิษฐ์ส่งผลกระทบต่อตลาดแรงงาน งานบางประเภทอาจหายไปเนื่องจาก automation"

print("🔗 Semantic Similarity Evaluation:")
sim_result = semantic_similarity_eval(text_a, text_b)
print(sim_result["evaluation"])
print(f"\n📊 Overall Similarity: {sim_result['overall_similarity']}")
# Out:
# 🔗 Semantic Similarity Evaluation:
# Here's an evaluation of the semantic similarity between the two texts:
#
# topical_similarity: 1.0
# information_overlap: 0.9
# sentiment_alignment: 0.8
# intent_match: 1.0
# overall_similarity: 0.93
# explanation: Both texts discuss the impact of AI on the job market, specifically the potential displacement of jobs due to automation. They share a negative sentiment regarding the potential consequences. The intent is to inform about this impact.
#
#
# 📊 Overall Similarity: 0.93

# %%
# === Lab 9.6: Hallucination Detection (Dedicated) ===

def hallucination_detector(topic: str, text: str) -> Dict:
    """
    ตรวจจับ Hallucination โดยเฉพาะ
    """
    
    detection_prompt = f"""
คุณเป็นผู้เชี่ยวชาญด้านการตรวจสอบข้อเท็จจริง (Fact-checker)

=== หัวข้อ ===
{topic}

=== ข้อความที่ต้องตรวจสอบ ===
{text}

กรุณาตรวจสอบทุก factual claim ในข้อความ:

สำหรับแต่ละ claim ที่พบ:
1. ระบุ claim
2. ประเมินความน่าเชื่อถือ:
   - ✅ VERIFIED: มั่นใจว่าถูกต้อง
   - ⚠️ UNCERTAIN: ไม่แน่ใจ ต้องตรวจสอบ
   - ❌ LIKELY FALSE: น่าจะไม่ถูกต้อง
   - 🔍 UNVERIFIABLE: ไม่สามารถตรวจสอบได้
3. อธิบายเหตุผล

Format:
CLAIM 1: "[claim text]"
STATUS: [✅/⚠️/❌/🔍]
REASON: [explanation]
CORRECTION: [if false, provide correct info]

...

SUMMARY:
- Total claims found: [N]
- Verified: [N]
- Uncertain: [N]
- Likely False: [N]
- Unverifiable: [N]

HALLUCINATION_RISK: [LOW/MEDIUM/HIGH/CRITICAL]
OVERALL_TRUSTWORTHINESS: [score]/10
"""
    
    result = call_gemini(detection_prompt)
    
    # Extract risk level
    risk_match = re.search(r'HALLUCINATION_RISK:\s*(LOW|MEDIUM|HIGH|CRITICAL)', result)
    risk_level = risk_match.group(1) if risk_match else "UNKNOWN"
    
    return {
        "topic": topic,
        "text": text,
        "analysis": result,
        "hallucination_risk": risk_level
    }

# %%
# ทดสอบ Hallucination Detection
test_topic = "ประวัติศาสตร์ของประเทศไทย"
test_text_with_errors = """
ประเทศไทยไม่เคยตกเป็นอาณานิคมของชาติตะวันตก เป็นประเทศเดียวในเอเชียตะวันออกเฉียงใต้ที่รักษาเอกราชไว้ได้
กรุงเทพมหานครก่อตั้งโดยพระบาทสมเด็จพระพุทธยอดฟ้าจุฬาโลกมหาราช ในปี พ.ศ. 2325
ประเทศไทยเปลี่ยนการปกครองเป็นระบอบประชาธิปไตยในปี พ.ศ. 2475
ปัจจุบันประเทศไทยมีประชากรประมาณ 90 ล้านคน
"""

print("🔎 Hallucination Detection:")
hallucination_result = hallucination_detector(test_topic, test_text_with_errors)
print(hallucination_result["analysis"])
print(f"\n⚠️ Hallucination Risk: {hallucination_result['hallucination_risk']}")
# Out:
# 🔎 Hallucination Detection:
# Okay, I will analyze the provided text about the history of Thailand and fact-check each claim.
#
# CLAIM 1: "ประเทศไทยไม่เคยตกเป็นอาณานิคมของชาติตะวันตก เป็นประเทศเดียวในเอเชียตะวันออกเฉียงใต้ที่รักษาเอกราชไว้ได้"
# STATUS: ✅ VERIFIED
# REASON: This is a widely accepted historical fact. While Thailand (formerly Siam) faced significant pressure and ceded some territories to European powers, it was never formally colonized. It is generally considered the only country in Southeast Asia to avoid direct colonial rule.
# CORRECTION: N/A
#
# CLAIM 2: "กรุงเทพมหานครก่อตั้งโดยพระบาทสมเด็จพระพุทธยอดฟ้าจุฬาโลกมหาราช ในปี พ.ศ. 2325"
# STATUS: ✅ VERIFIED
# REASON: This is a correct statement. King Rama I (Phra Phutthayotfa Chulalok) established Bangkok as the capital in 1782 (B.E. 2325).
# CORRECTION: N/A
#
# CLAIM 3: "ประเทศไทยเปลี่ยนการปกครองเป็นระบอบประชาธิปไตยในปี พ.ศ. 2475"
# STATUS: ✅ VERIFIED
# REASON: The Siamese revolution of 1932 (B.E. 2475) marked the transition from absolute monarchy to a constitutional monarchy, which is considered the beginning of democratic governance in Thailand.
# CORRECTION: N/A
#
# CLAIM 4: "ปัจจุบันประเทศไทยมีประชากรประมาณ 90 ล้านคน"
# STATUS: ❌ LIKELY FALSE
# REASON: According to the latest official statistics, the population of Thailand is closer to 70 million. 90 million is a significant overestimation.
# CORRECTION: The current population of Thailand is approximately 70 million.
#
# SUMMARY:
# - Total claims found: 4
# - Verified: 3
# - Uncertain: 0
# - Likely False: 1
# - Unverifiable: 0
#
# HALLUCINATION_RISK: LOW
# OVERALL_TRUSTWORTHINESS: 8/10
#
#
# ⚠️ Hallucination Risk: LOW

# %%
# === Lab 9.7: Multi-Agent Debate Evaluation ===

def multi_agent_debate_eval(task: str, response: str, num_agents: int = 3) -> Dict:
    """
    ใช้หลาย "agents" (persona) ประเมินคำตอบเดียวกันจากมุมมองต่างกัน
    แล้ว synthesize ผลลัพธ์
    """
    
    agent_personas = [
        {
            "name": "Technical Expert",
            "prompt": "คุณเป็นผู้เชี่ยวชาญด้านเทคนิค ดูความถูกต้องทางเทคนิค ความแม่นยำ และ technical depth"
        },
        {
            "name": "Communication Specialist", 
            "prompt": "คุณเป็นผู้เชี่ยวชาญด้านสื่อสาร ดูความชัดเจน การจัดระเบียบ และว่าผู้อ่านทั่วไปจะเข้าใจหรือไม่"
        },
        {
            "name": "Devil's Advocate",
            "prompt": "คุณเป็นผู้คัดค้าน ดูช่องโหว่ สมมติฐานที่ผิดพลาด bias และสิ่งที่ขาดหาย พยายามหาจุดอ่อน"
        }
    ]
    
    agent_evaluations = []
    
    for i, agent in enumerate(agent_personas[:num_agents]):
        eval_prompt = f"""
{agent['prompt']}

ประเมินคำตอบนี้:

Task: {task}
Response: {response}

ให้คะแนน 1-10 และอธิบายจากมุมมองของคุณ
ระบุจุดแข็ง จุดอ่อน และข้อเสนอแนะ

SCORE: [1-10]
STRENGTHS: [list]
WEAKNESSES: [list]
SUGGESTIONS: [list]
"""
        
        result = call_gemini(eval_prompt)
        agent_evaluations.append({
            "agent": agent["name"],
            "evaluation": result
        })
        
        print(f"\n👤 {agent['name']}:")
        print(result[:300] + "..." if len(result) > 300 else result)
        time.sleep(1)
    
    # Synthesize
    all_evals = "\n\n".join([f"[{ae['agent']}]\n{ae['evaluation']}" for ae in agent_evaluations])
    
    synthesis_prompt = f"""
สรุปผลการประเมินจาก {num_agents} ผู้เชี่ยวชาญ:

{all_evals}

สร้างสรุป:
1. คะแนนเฉลี่ยจากทุกผู้เชี่ยวชาญ
2. จุดที่เห็นพ้องกัน (ทั้งจุดแข็งและจุดอ่อน)
3. จุดที่ขัดแย้งกัน
4. ข้อเสนอแนะสุดท้าย

CONSENSUS_SCORE: [1-10]
"""
    
    synthesis = call_gemini(synthesis_prompt)
    
    return {
        "task": task,
        "response": response,
        "agent_evaluations": agent_evaluations,
        "synthesis": synthesis
    }

# %%
# ทดสอบ Multi-Agent Debate
debate_task = "อธิบาย Quantum Computing สำหรับผู้เริ่มต้น"
debate_response = """
Quantum Computing ใช้ qubit แทน bit ปกติ ทำให้คำนวณได้เร็วกว่าหลายล้านเท่า
Qubit สามารถเป็นทั้ง 0 และ 1 พร้อมกัน (superposition)
Google มี quantum computer ที่ทำงานเร็วกว่า supercomputer ทั่วไป
ในอนาคต quantum computing จะทำให้ encryption ทั้งหมดไม่ปลอดภัย
"""

print("🤝 Multi-Agent Debate Evaluation:")
debate_result = multi_agent_debate_eval(debate_task, debate_response, num_agents=3)
print("\n📊 Synthesis:")
print(debate_result["synthesis"])
# Out:
# 🤝 Multi-Agent Debate Evaluation:
#
# 👤 Technical Expert:
# ## การประเมินคำอธิบาย Quantum Computing สำหรับผู้เริ่มต้น
#
# **SCORE: 6/10**
#
# **STRENGTHS:**
#
# *   **Simple Language:** ใช้ภาษาที่เข้าใจง่าย เหมาะสำหรับผู้เริ่มต้น
# *   **Highlights Key Concepts:** กล่าวถึง qubit และ superposition ซึ่งเป็นหัวใจสำคัญของ Quantum Computing
# *   **Relatable Example:** อ้างถึ...
#
# 👤 Communication Specialist:
# ## การประเมินคำอธิบาย Quantum Computing สำหรับผู้เริ่มต้น
#
# **SCORE: 5/10**
#
# **STRENGTHS:**
#
# *   **กระชับ:** คำตอบสั้นและตรงประเด็น ทำให้ง่ายต่อการอ่านและทำความเข้าใจในเบื้องต้น
# *   **เน้นความแตกต่าง:** การเปรียบเทียบ qubit กับ bit ปกติ ช่วยให้เห็นภาพความแตกต่างและศักยภาพของ Quantum Computing ได้ชัดเ...
#
# 👤 Devil's Advocate:
# ในฐานะผู้คัดค้าน ผมจะประเมินคำตอบนี้อย่างละเอียดเพื่อหาจุดอ่อนและสมมติฐานที่ผิดพลาด
#
# **SCORE: 4/10**
#
# **STRENGTHS:**
#
# *   **Simple Introduction:** พยายามอธิบายแนวคิดหลักด้วยภาษาที่เข้าใจง่ายสำหรับผู้เริ่มต้น
# *   **Highlights Key Concepts:** กล่าวถึง qubit และ superposition ซึ่งเป็นหัวใจสำคัญของ Quan...
#
# 📊 Synthesis:
# ## สรุปผลการประเมินคำอธิบาย Quantum Computing สำหรับผู้เริ่มต้น
#
# **1. คะแนนเฉลี่ยจากทุกผู้เชี่ยวชาญ:**
#
# (6 + 5 + 4) / 3 = **5/10**
#
# **2. จุดที่เห็นพ้องกัน (ทั้งจุดแข็งและจุดอ่อน):**
#
# *   **จุดแข็ง:**
#     *   **ภาษาที่เข้าใจง่าย:** ทุกคนเห็นพ้องกันว่าคำอธิบายใช้ภาษาที่เข้าใจง่าย เหมาะสำหรับผู้เริ่มต้น
#     *   **การกล่าวถึงแนวคิดหลัก:** ทุกคนเห็นพ้องกันว่าการกล่าวถึง qubit และ superposition เป็นสิ่งสำคัญ
#     *   **การยกตัวอย่าง:** การอ้างถึง Google ช่วยให้เห็นภาพว่าเทคโนโลยีนี้มีอยู่จริง
#
# *   **จุดอ่อน:**
#     *   **การกล่าวอ้างที่เกินจริงและไม่แม่นยำ:** ทุกคนเห็นพ้องกันว่าการกล่าวอ้างเรื่องความเร็ว ("เร็วกว่าหลายล้านเท่า") เป็นการกล่าวอ้างที่เกินจริงและไม่มีบริบทที่ชัดเจน
#     *   **ความไม่ถูกต้องและขาดความลึกซึ้งในการอธิบาย Superposition:** ทุกคนเห็นพ้องกันว่าคำอธิบาย superposition ขาดความลึกซึ้งและอาจทำให้เกิดความเข้าใจผิด
#     *   **ขาดบริบท:** ทุกคนเห็นพ้องกันว่าคำอธิบายขาดบริบทที่สำคัญ เช่น ประเภทของปัญหาที่ Quantum Computing เหมาะสม, ข้อจำกัดของ Quantum Computing ในปัจจุบัน, และความแตกต่างระหว่าง Quantum Computing กับ Classical Computing
#     *   **การกล่าวถึงผลกระทบต่อ Encryption ที่อาจทำให้เข้าใจผิด:** ทุกคนเห็นพ้องกันว่าการกล่าวถึงผลกระทบต่อ encryption อาจสร้างความตื่นตระหนกโดยไม่จำเป็น และควรกล่าวถึงการพัฒนา post-quantum cryptography ควบคู่กันไปด้วย
#
# **3. จุดที่ขัดแย้งกัน:**
#
# *   **ความกระชับ vs. ความชัดเจน:** Communication Specialist มองว่าความกระชับเป็นจุดแข็ง ในขณะที่ Technical Expert และ Devil's Advocate มองว่าคำอธิบายสั้นเกินไปจนขาดความชัดเจนและรายละเอียดที่จำเป็น
# *   **การใช้ศัพท์เฉพาะ:** Communication Specialist มองว่าการใช้ศัพท์เฉพาะมากเกินไปอาจทำให้ผู้เริ่มต้นสับสน ในขณะที่ Technical Expert มองว่าการกล่าวถึง concepts ที่สำคัญอื่นๆ (เช่น entanglement, quantum gate, และ quantum algorithm) เป็นสิ่งที่ควรทำ (แม้จะกล่าวถึงอย่างสั้นๆ)
#
# **4. ข้อเสนอแนะสุดท้าย:**
#
# คำอธิบาย Quantum Computing สำหรับผู้เริ่มต้นนี้มีศักยภาพ แต่จำเป็นต้องปรับปรุงในหลายด้านเพื่อให้มีความถูกต้อง แม่นยำ และเข้าใจง่ายยิ่งขึ้น ข้อเสนอแนะหลักๆ คือ:
#
# *   **ปรับปรุงความแม่นยำ:** หลีกเลี่ยงการกล่าวอ้างที่เกินจริงและให้ข้อมูลที่ถูกต้องและมีบริบทมากขึ้น โดยเฉพาะอย่างยิ่งในเรื่องความเร็วและ superposition
# *   **เพิ่มบริบท:** อธิบายว่า Quantum Computing คืออะไร, ทำงานอย่างไร, และแตกต่างจาก Classical Computing อย่างไร รวมถึงกล่าวถึงข้อจำกัดของ Quantum Computing ในปัจจุบัน
# *   **ให้ความสมดุล:** อธิบายผลกระทบที่อาจเกิดขึ้นอย่างสมดุล โดยเน้นทั้งโอกาสและความท้าทาย โดยเฉพาะอย่างยิ่งในเรื่อง encryption
# *   **ใช้ภาษาที่เข้าใจง่าย:** หลีกเลี่ยงศัพท์เฉพาะทางที่ไม่จำเป็น และใช้ภาษาที่ผู้เริ่มต้นสามารถเข้าใจได้ง่าย
# *   **พิจารณาเพิ่มรายละเอียด (อย่างระมัดระวัง):** หากต้องการเพิ่มความลึกซึ้ง อาจกล่าวถึง concepts ที่สำคัญอื่นๆ เช่น entanglement, quantum gate, หรือ quantum algorithm อย่างสั้นๆ แต่ต้องระมัดระวังไม่ให้ซับซ้อนเกินไปสำหรับผู้เริ่มต้น
#
# โดยรวมแล้ว การปรับปรุงตามข้อเสนอแนะเหล่านี้จะช่วยให้คำอธิบายมีความถูกต้อง แม่นยำ และเข้าใจง่ายยิ่งขึ้น ทำให้ผู้เริ่มต้นมีความเข้าใจที่ถูกต้องและครอบคลุมเกี่ยวกับ Quantum Computing

# %% [markdown]
# ---
# # 📊 Part 10: Comprehensive Evaluation Framework
# **รวมทุกวิธี Evaluation เข้าด้วยกัน**
#
# ---
#
# ### 📊 Evaluation Framework Architecture
#
# ```
# ╔══════════════════════════════════════════════════════════════════╗
# ║          🏗️ COMPREHENSIVE EVALUATION ARCHITECTURE               ║
# ╠══════════════════════════════════════════════════════════════════╣
# ║                                                                  ║
# ║  Input: (task, response)                                        ║
# ║         │                                                        ║
# ║         ├──▶ [LLM-as-Judge] ──▶ Multi-aspect scores            ║
# ║         │                                                        ║
# ║         ├──▶ [Reference-free] ──▶ Quality assessment            ║
# ║         │                                                        ║
# ║         ├──▶ [Hallucination Check] ──▶ Risk level              ║
# ║         │                                                        ║
# ║         ├──▶ [Automated Metrics] ──▶ BLEU/ROUGE (if ref)       ║
# ║         │                                                        ║
# ║         ├──▶ [Multi-Agent Debate] ──▶ Diverse perspectives     ║
# ║         │                                                        ║
# ║         └──▶ [Pairwise Compare] ──▶ Relative ranking           ║
# ║                     │                                            ║
# ║                     ▼                                            ║
# ║         ┌─────────────────────────┐                             ║
# ║         │  📊 AGGREGATION LAYER   │                             ║
# ║         │  • Weighted average     │                             ║
# ║         │  • Confidence interval  │                             ║
# ║         │  • Risk assessment      │                             ║
# ║         └──────────┬──────────────┘                             ║
# ║                    ▼                                             ║
# ║         ┌─────────────────────────┐                             ║
# ║         │  📋 EVALUATION REPORT   │                             ║
# ║         │  • Overall score        │                             ║
# ║         │  • Dimension scores     │                             ║
# ║         │  • Risk flags           │                             ║
# ║         │  • Improvement areas    │                             ║
# ║         │  • Recommendations      │                             ║
# ║         └─────────────────────────┘                             ║
# ╚══════════════════════════════════════════════════════════════════╝
# ```

# %%
# === Lab 10.1: Complete Evaluation Pipeline ===

class ComprehensiveEvaluator:
    """
    Evaluation Framework ที่รวมหลายวิธีเข้าด้วยกัน
    """
    
    def __init__(self, model_name: str):
        self.model_name = model_name
    
    def evaluate(self, task: str, response: str, 
                 reference: str = None,
                 include_pairwise: bool = False, 
                 alternative_response: str = None,
                 include_multi_agent: bool = False) -> Dict:
        """
        ประเมินแบบครบวงจร
        """
        results = {
            "task": task,
            "response": response,
            "evaluations": {},
            "flags": []
        }
        
        print("🔍 Starting Comprehensive Evaluation...")
        print("=" * 60)
        
        # 1. LLM-as-a-Judge (Multi-aspect)
        print("\n📊 1. LLM-as-a-Judge Evaluation")
        judge_result = llm_as_judge(task, response)
        results["evaluations"]["llm_judge"] = judge_result
        score = judge_result.get('overall_score', 'N/A')
        print(f"   Score: {score}/10")
        if isinstance(score, (int, float)) and score < 5:
            results["flags"].append("⚠️ LOW QUALITY: LLM Judge score < 5")
        
        time.sleep(1)
        
        # 2. Reference-free Evaluation
        print("\n📋 2. Reference-free Evaluation")
        ref_free_result = reference_free_evaluation(task, response)
        results["evaluations"]["reference_free"] = ref_free_result
        
        time.sleep(1)
        
        # 3. Hallucination Check
        print("\n🔎 3. Hallucination Detection")
        hallucination_result = hallucination_detector(task, response)
        results["evaluations"]["hallucination_check"] = hallucination_result
        if hallucination_result["hallucination_risk"] in ["HIGH", "CRITICAL"]:
            results["flags"].append(f"🚨 HALLUCINATION RISK: {hallucination_result['hallucination_risk']}")
        
        time.sleep(1)
        
        # 4. Automated Metrics (if reference provided)
        if reference:
            print("\n📏 4. Automated Metrics (BLEU/ROUGE)")
            bleu = simple_bleu(reference, response)
            rouge_l = simple_rouge_l(reference, response)
            rouge_1 = simple_rouge_n(reference, response, n=1)
            results["evaluations"]["automated_metrics"] = {
                "bleu": bleu,
                "rouge_l": rouge_l,
                "rouge_1": rouge_1
            }
            print(f"   BLEU Combined: {bleu['bleu_combined']:.4f}")
            print(f"   ROUGE-L F1: {rouge_l['rouge_l_f1']:.4f}")
            print(f"   ROUGE-1 F1: {rouge_1['rouge_1_f1']:.4f}")
        
        # 5. Pairwise Comparison (if alternative provided)
        if include_pairwise and alternative_response:
            print("\n⚖️ 5. Pairwise Comparison (Debiased)")
            pairwise_result = pairwise_comparison_debiased(task, response, alternative_response)
            results["evaluations"]["pairwise"] = pairwise_result
            print(f"   Winner: {pairwise_result['final_winner']}")
            time.sleep(1)
        
        # 6. Multi-Agent Debate (optional)
        if include_multi_agent:
            print("\n🤝 6. Multi-Agent Debate")
            debate_result = multi_agent_debate_eval(task, response, num_agents=3)
            results["evaluations"]["multi_agent_debate"] = debate_result
        
        # 7. Aggregate Score
        results["aggregate"] = self._calculate_aggregate(results)
        
        # 8. Generate Report
        results["report"] = self._generate_report(results)
        
        return results
    
    def _calculate_aggregate(self, results: Dict) -> Dict:
        """Calculate aggregate score from all evaluations"""
        scores = []
        
        if "llm_judge" in results["evaluations"]:
            judge = results["evaluations"]["llm_judge"]
            if judge.get("overall_score"):
                scores.append(("LLM Judge", judge["overall_score"]))
        
        if scores:
            avg = sum(s[1] for s in scores) / len(scores)
            return {
                "average_score": round(avg, 2),
                "individual_scores": scores,
                "num_evaluations": len(scores),
                "flags_count": len(results.get("flags", []))
            }
        return {"average_score": None, "num_evaluations": 0, "flags_count": 0}
    
    def _generate_report(self, results: Dict) -> str:
        """Generate human-readable evaluation report"""
        report = []
        report.append("=" * 60)
        report.append("📋 COMPREHENSIVE EVALUATION REPORT")
        report.append("=" * 60)
        
        agg = results.get("aggregate", {})
        report.append(f"\n📊 Overall Score: {agg.get('average_score', 'N/A')}/10")
        report.append(f"📊 Evaluations Used: {agg.get('num_evaluations', 0)}")
        
        flags = results.get("flags", [])
        if flags:
            report.append(f"\n🚩 Flags ({len(flags)}):")
            for f in flags:
                report.append(f"   {f}")
        else:
            report.append("\n✅ No flags raised")
        
        if "hallucination_check" in results["evaluations"]:
            risk = results["evaluations"]["hallucination_check"]["hallucination_risk"]
            report.append(f"\n🔎 Hallucination Risk: {risk}")
        
        report.append("\n" + "=" * 60)
        
        return "\n".join(report)

# %%
# ทดสอบ Comprehensive Evaluator
evaluator = ComprehensiveEvaluator(MODEL_NAME)

test_task = "อธิบายความแตกต่างระหว่าง Machine Learning กับ Deep Learning"

test_response = """
Machine Learning (ML) และ Deep Learning (DL) มีความแตกต่างกันดังนี้:

Machine Learning:
- ใช้ algorithm แบบดั้งเดิม เช่น Decision Tree, SVM, Linear Regression
- ต้อง feature engineering ด้วยมือ
- ใช้ข้อมูลน้อยกว่า
- เหมาะกับปัญหาที่ไม่ซับซ้อนมาก

Deep Learning:
- ใช้ Neural Networks หลายชั้น
- สามารถเรียนรู้ features เอง
- ต้องการข้อมูลมาก
- เหมาะกับ image, text, speech

DL เป็น subset ของ ML ที่พัฒนาขึ้นมาเพื่อจัดการกับปัญหาที่ซับซ้อนขึ้น
"""

test_reference = """
Machine Learning เป็นสาขาของ AI ที่ใช้ algorithms เรียนรู้จากข้อมูล 
Deep Learning เป็น subset ของ ML ที่ใช้ neural networks หลายชั้น
ML ต้อง feature engineering แต่ DL เรียนรู้ features เอง
DL ต้องการข้อมูลและ computing power มากกว่า
"""

evaluation_results = evaluator.evaluate(
    test_task, 
    test_response,
    reference=test_reference
)

print(evaluation_results["report"])
# Out:
# 🔍 Starting Comprehensive Evaluation...
# ============================================================
#
# 📊 1. LLM-as-a-Judge Evaluation
#    Score: 9.0/10
#
# 📋 2. Reference-free Evaluation
#
# 🔎 3. Hallucination Detection
#
# 📏 4. Automated Metrics (BLEU/ROUGE)
#    BLEU Combined: 0.0992
#    ROUGE-L F1: 0.2381
#    ROUGE-1 F1: 0.4048
# ============================================================
# 📋 COMPREHENSIVE EVALUATION REPORT
# ============================================================
#
# 📊 Overall Score: 9.0/10
# 📊 Evaluations Used: 1
#
# ✅ No flags raised
#
# 🔎 Hallucination Risk: LOW
#
# ============================================================

# %% [markdown]
# ---
# # 🎯 Part 11: Final Challenge — Combined Techniques
# **รวมทุกเทคนิคที่เรียนมา**
#
# ---
#
# ### 📊 Challenge Architecture
#
# ```
# ╔══════════════════════════════════════════════════════════════════════╗
# ║                 🏆 FINAL CHALLENGE PIPELINE                         ║
# ╠══════════════════════════════════════════════════════════════════════╣
# ║                                                                      ║
# ║  Input: Complex Problem                                             ║
# ║         │                                                            ║
# ║  Stage 1: Few-shot CoT ──▶ Initial Analysis                        ║
# ║         │                                                            ║
# ║  Stage 2: Tree-of-Thought ──▶ Multiple Solutions                   ║
# ║         │                                                            ║
# ║  Stage 3: Reflection ──▶ Improved Plan                             ║
# ║         │                                                            ║
# ║  Stage 4: Self-Critique ──▶ Stress-tested Plan                     ║
# ║         │                                                            ║
# ║  Stage 5: Synthesis ──▶ Final Comprehensive Plan                   ║
# ║         │                                                            ║
# ║  Stage 6: Comprehensive Evaluation ──▶ Quality Report              ║
# ║                                                                      ║
# ╚══════════════════════════════════════════════════════════════════════╝
# ```

# %%
# === Final Challenge: Build a Complete Analysis System ===

def advanced_analysis_system(problem: str) -> Dict:
    """
    ระบบวิเคราะห์ที่รวมหลายเทคนิค:
    1. Few-shot CoT สำหรับ initial analysis
    2. Tree-of-Thought สำหรับสร้างทางเลือก
    3. Reflection สำหรับปรับปรุง
    4. Self-Critique สำหรับตรวจสอบ
    5. Synthesis สำหรับคำตอบสุดท้าย
    6. Comprehensive Evaluation สำหรับประเมิน
    """
    
    results = {"stages": {}}
    
    print("🚀 Starting Advanced Analysis System")
    print("=" * 60)
    
    # Stage 1: Few-shot + CoT for initial analysis
    print("\n📌 Stage 1: Initial Analysis with Few-shot CoT")
    stage1_prompt = f"""
วิเคราะห์ปัญหาต่อไปนี้โดยใช้ตัวอย่างเป็นแนวทาง:

ตัวอย่าง:
ปัญหา: ร้านค้าปลีกยอดขายลดลง
วิเคราะห์:
- ขั้นตอน 1: ระบุสาเหตุ → แข่งขันสูง, เศรษฐกิจ, พฤติกรรมผู้บริโภค
- ขั้นตอน 2: ประเมินผลกระทบ → รายได้ลด, กำไรลด
- ขั้นตอน 3: หาทางออก → ปรับกลยุทธ์, ลดต้นทุน

ปัญหาของคุณ:
{problem}

วิเคราะห์ทีละขั้นตอนอย่างละเอียด
"""
    
    response1 = call_gemini(stage1_prompt)
    results["stages"]["initial_analysis"] = response1
    print(response1[:500] + "...")
    
    time.sleep(1)
    
    # Stage 2: Tree-of-Thought for solutions
    print("\n📌 Stage 2: Tree-of-Thought for Solutions")
    stage2_prompt = f"""
จากการวิเคราะห์:
{results['stages']['initial_analysis'][:1000]}

สร้าง 3 ทางเลือกในการแก้ปัญหา โดยแต่ละทางเลือกต้องมี:
- แนวคิดหลัก
- ข้อดี/ข้อเสีย
- ความเป็นไปได้ (1-10)

แล้วเลือกทางที่ดีที่สุดพร้อมเหตุผล
"""
    
    response2 = call_gemini(stage2_prompt, temperature=0.5)
    results["stages"]["solutions_tree"] = response2
    print(response2[:500] + "...")
    
    time.sleep(1)
    
    # Stage 3: Reflection and Improvement
    print("\n📌 Stage 3: Reflection & Improvement")
    stage3_prompt = f"""
ทบทวนทางออกที่เลือก:
{results['stages']['solutions_tree'][:1000]}

1. จุดแข็งของแผน
2. จุดอ่อนที่ต้องแก้ไข
3. ความเสี่ยงที่อาจเกิด
4. ปรับปรุงแผนให้ดีขึ้น
"""
    
    response3 = call_gemini(stage3_prompt)
    results["stages"]["reflection"] = response3
    print(response3[:500] + "...")
    
    time.sleep(1)
    
    # Stage 4: Self-Critique
    print("\n📌 Stage 4: Self-Critique")
    stage4_prompt = f"""
ในฐานะนักวิจารณ์ที่เข้มงวด วิพากษ์แผนนี้:
{results['stages']['reflection'][:1000]}

หา:
1. ข้อผิดพลาดทางตรรกะ
2. สมมติฐานที่อาจผิด
3. สิ่งที่ขาดหาย
4. ความเสี่ยงที่มองข้าม
"""
    
    response4 = call_gemini(stage4_prompt)
    results["stages"]["critique"] = response4
    print(response4[:500] + "...")
    
    time.sleep(1)
    
    # Stage 5: Final Synthesis
    print("\n📌 Stage 5: Final Synthesis")
    stage5_prompt = f"""
สังเคราะห์ทุกอย่างที่ได้:

ปัญหา: {problem}

การวิเคราะห์: {results['stages']['initial_analysis'][:500]}
ทางออก: {results['stages']['solutions_tree'][:500]}
การปรับปรุง: {results['stages']['reflection'][:500]}
การวิพากษ์: {results['stages']['critique'][:500]}

สร้างแผนสุดท้ายที่:
1. แก้ไขทุกจุดอ่อนที่พบ
2. มีความเป็นไปได้สูง
3. มี action items ที่ชัดเจน
4. มี timeline และ KPIs
"""
    
    response5 = call_gemini(stage5_prompt)
    results["stages"]["final_plan"] = response5
    print(response5)
    
    time.sleep(1)
    
    # Stage 6: Comprehensive Evaluation
    print("\n📌 Stage 6: Comprehensive Evaluation")
    eval_result = llm_as_judge(
        problem, 
        results["stages"]["final_plan"],
        rubric={
            "feasibility": "แผนนี้เป็นไปได้จริงมากน้อยเพียงใด",
            "completeness": "แผนครบถ้วน ครอบคลุมทุกด้านหรือไม่",
            "practicality": "มี action items ที่ปฏิบัติได้จริงหรือไม่",
            "innovation": "มีความคิดสร้างสรรค์ แตกต่างจากแนวทางทั่วไปหรือไม่",
            "risk_management": "มีการจัดการความเสี่ยงที่ดีหรือไม่"
        }
    )
    results["evaluation"] = eval_result
    print(eval_result["evaluation"])
    
    return results

# %%
# ทดสอบ Advanced Analysis System
complex_problem = """
บริษัท Startup ด้าน EdTech มีแอป e-learning ที่มีผู้ใช้ 10,000 คน
แต่ retention rate ต่ำมาก (เพียง 15% กลับมาใช้หลัง 1 เดือน)
มีงบประมาณ 2 ล้านบาท และต้องเพิ่ม retention เป็น 40% ภายใน 6 เดือน
ทีมมี developer 3 คน และ designer 1 คน
"""

print("🎯 Running Final Challenge...")
final_results = advanced_analysis_system(complex_problem)
# Out:
# 🎯 Running Final Challenge...
# 🚀 Starting Advanced Analysis System
# ============================================================
#
# 📌 Stage 1: Initial Analysis with Few-shot CoT
# ## วิเคราะห์ปัญหา Retention Rate ต่ำของ Startup EdTech
#
# **ปัญหา:** บริษัท Startup ด้าน EdTech มีแอป e-learning ที่มีผู้ใช้ 10,000 คน แต่ retention rate ต่ำมาก (เพียง 15% กลับมาใช้หลัง 1 เดือน) มีงบประมาณ 2 ล้านบาท และต้องเพิ่ม retention เป็น 40% ภายใน 6 เดือน ทีมมี developer 3 คน และ designer 1 คน
#
# **วิเคราะห์:**
#
# **ขั้นตอน 1: ระบุสาเหตุ (Root Cause Analysis)**
#
# *   **คุณภาพของเนื้อหา:**
#     *   **เนื้อหาไม่น่าสนใจ/ไม่เกี่ยวข้อง:** เนื้อหาอาจไม่ตรงกับความต้องการของผู้ใช้, ไม่ทันสมัย, หรือไม่น่าส...
#
# 📌 Stage 2: Tree-of-Thought for Solutions
# ## 3 ทางเลือกในการแก้ปัญหา Retention Rate ต่ำของ Startup EdTech
#
# **ทางเลือกที่ 1: ปรับปรุงเนื้อหาและประสบการณ์การเรียนรู้ (Content & Learning Experience Enhancement)**
#
# *   **แนวคิดหลัก:** มุ่งเน้นการปรับปรุงคุณภาพเนื้อหาให้ตรงใจผู้ใช้มากขึ้น และออกแบบประสบการณ์การเรียนรู้ที่น่าสนใจและมีประสิทธิภาพ เพื่อดึงดูดให้ผู้ใช้กลับมาเรียนรู้ซ้ำ
# *   **รายละเอียด:**
#     *   **วิเคราะห์ข้อมูลผู้ใช้:** ศึกษาข้อมูลการใช้งาน, ผลตอบรับ, และความต้องการของผู้ใช้ เพื่อระบุจุดที่ต้องปรับปรุง
#     *   **ปรับปรุงเนื้อ...
#
# 📌 Stage 3: Reflection & Improvement
# ## ทบทวนทางออกที่ 1: ปรับปรุงเนื้อหาและประสบการณ์การเรียนรู้ (Content & Learning Experience Enhancement)
#
# **1. จุดแข็งของแผน:**
#
# *   **แก้ไขปัญหาที่ต้นเหตุ:** การปรับปรุงเนื้อหาและประสบการณ์การเรียนรู้โดยตรงเป็นการแก้ปัญหาที่รากเหง้าของปัญหา Retention Rate ต่ำ หากเนื้อหาไม่น่าสนใจหรือยากเกินไป ผู้ใช้ก็จะไม่กลับมาเรียน
# *   **สร้างความพึงพอใจและความผูกพัน:** เนื้อหาที่ดีและประสบการณ์การเรียนรู้ที่สนุกสนานจะสร้างความพึงพอใจให้กับผู้ใช้ ทำให้พวกเขารู้สึกผูกพันกับแพลตฟอร์มและอยากกลับมาเรียนรู้ซ้ำ
# *  ...
#
# 📌 Stage 4: Self-Critique
# ในฐานะนักวิจารณ์ที่เข้มงวด ผมขอวิพากษ์แผน "ปรับปรุงเนื้อหาและประสบการณ์การเรียนรู้" ดังนี้:
#
# **1. ข้อผิดพลาดทางตรรกะ:**
#
# *   **การสรุปแบบเหมารวม:** แผนนี้สรุปว่า Retention Rate ต่ำเกิดจากเนื้อหาและประสบการณ์การเรียนรู้ที่ไม่ดีเพียงอย่างเดียว ซึ่งอาจไม่เป็นความจริง ปัจจัยอื่นๆ เช่น ราคา, การตลาด, การสนับสนุนลูกค้า, หรือแม้แต่ความต้องการของผู้เรียนเอง ก็อาจมีผลต่อ Retention Rate ด้วย
# *   **การเชื่อมโยงแบบเส้นตรง:** แผนนี้เชื่อมโยง "เนื้อหาที่ดี" กับ "ความพึงพอใจ" และ "ความผูกพัน" โดยตรง ซึ่งอาจไม่...
#
# 📌 Stage 5: Final Synthesis
# ## แผนสุดท้าย: บูรณาการการปรับปรุงเนื้อหา, ประสบการณ์ผู้ใช้, และการตลาดเพื่อเพิ่ม Retention Rate
#
# **เป้าหมาย:** เพิ่ม Retention Rate จาก 15% เป็น 40% ภายใน 6 เดือน
#
# **หลักการ:** แก้ไขปัญหาที่ต้นเหตุ (เนื้อหาและประสบการณ์ผู้ใช้) ควบคู่ไปกับการปรับปรุงการตลาดและการสื่อสาร เพื่อสร้างความพึงพอใจ, ความผูกพัน, และกระตุ้นให้ผู้ใช้กลับมาใช้งานอย่างต่อเนื่อง
#
# **ระยะเวลา:** 6 เดือน
#
# **งบประมาณ:** 2 ล้านบาท
#
# **ทีม:** Developer 3 คน, Designer 1 คน (อาจต้องจ้าง Freelancer เพิ่มเติมตามความจำเป็น)
#
# **ขั้นตอนที่ 1: การวิเคราะห์และวางแผน (เดือนที่ 1)**
#
# *   **Action Items:**
#     *   **วิเคราะห์ข้อมูลเชิงลึก (2 สัปดาห์):**
#         *   **KPI:** สรุปรายงานการวิเคราะห์ข้อมูลผู้ใช้ (User Segmentation, Usage Patterns, Drop-off Points, Feedback Analysis)
#         *   **ผู้รับผิดชอบ:** Developer 1 คน, Designer 1 คน
#         *   **รายละเอียด:** วิเคราะห์ข้อมูลการใช้งานแอปอย่างละเอียด, สัมภาษณ์ผู้ใช้ที่เลิกใช้งาน (Churned Users) เพื่อหาเหตุผล, ทำ User Segmentation เพื่อแบ่งกลุ่มผู้ใช้ตามความต้องการและพฤติกรรม, วิเคราะห์ Feedback จาก App Store/Play Store และช่องทางอื่นๆ
#     *   **ประเมินคุณภาพเนื้อหา (1 สัปดาห์):**
#         *   **KPI:** สรุปรายงานการประเมินเนื้อหา (Content Audit, Gap Analysis, Competitor Analysis)
#         *   **ผู้รับผิดชอบ:** Designer 1 คน, (อาจจ้าง Freelancer Content Specialist)
#         *   **รายละเอียด:** ประเมินเนื้อหาที่มีอยู่ว่าตรงกับความต้องการของผู้ใช้หรือไม่, เปรียบเทียบกับคู่แข่ง, หาช่องว่างของเนื้อหาที่ควรเพิ่มเติม
#     *   **กำหนดกลยุทธ์และแผนการดำเนินงาน (1 สัปดาห์):**
#         *   **KPI:** แผนการดำเนินงานที่ชัดเจนพร้อม Timeline, งบประมาณ, และ KPIs
#         *   **ผู้รับผิดชอบ:** ทีมทั้งหมด
#         *   **รายละเอียด:** กำหนดกลยุทธ์หลักในการปรับปรุงเนื้อหา, ประสบการณ์ผู้ใช้, และการตลาด, กำหนด Action Items ที่ชัดเจน, จัดสรรงบประมาณ, กำหนด KPIs สำหรับแต่ละ Action Item
#
# **ขั้นตอนที่ 2: ปรับปรุงเนื้อหาและประสบการณ์ผู้ใช้ (เดือนที่ 2-4)**
#
# *   **Action Items:**
#     *   **ปรับปรุงเนื้อหา (6 สัปดาห์):**
#         *   **KPI:** จำนวนเนื้อหาที่ปรับปรุง/เพิ่มใหม่, คะแนนความพึงพอใจของเนื้อหา (Content Satisfaction Score)
#         *   **ผู้รับผิดชอบ:** (อาจจ้าง Freelancer Content Creator/Subject Matter Expert)
#         *   **รายละเอียด:** สร้าง/ปรับปรุงเนื้อหาให้ตรงกับความต้องการของผู้ใช้, ทำให้เนื้อหาน่าสนใจและเข้าใจง่าย, เพิ่มเนื้อหาที่ขาดหายไป, ปรับปรุงรูปแบบการนำเสนอเนื้อหาให้เหมาะสมกับแต่ละกลุ่มผู้ใช้
#     *   **ปรับปรุง User Interface (UI) และ User Experience (UX) (6 สัปดาห์):**
#         *   **KPI:** คะแนนความพึงพอใจของ UI/UX (UI/UX Satisfaction Score), อัตราการใช้งาน Feature ต่างๆ
#         *   **ผู้รับผิดชอบ:** Designer 1 คน, Developer 2 คน
#         *   **รายละเอียด:** ปรับปรุง UI ให้ใช้งานง่ายและสวยงาม, ปรับปรุง UX ให้ราบรื่นและน่าพึงพอใจ, เพิ่ม Feature ที่ผู้ใช้ต้องการ, ลดขั้นตอนที่ซับซ้อน, ปรับปรุง Onboarding Process ให้เข้าใจง่าย
#     *   **พัฒนา Gamification และ Social Features (4 สัปดาห์):**
#         *   **KPI:** จำนวนผู้ใช้ที่ใช้ Gamification/Social Features, อัตราการมีส่วนร่วม (Engagement Rate)
#         *   **ผู้รับผิดชอบ:** Developer 2 คน, Designer 1 คน
#         *   **รายละเอียด:** เพิ่ม Gamification Elements (คะแนน, Badge, Leaderboard) เพื่อกระตุ้นการเรียนรู้, เพิ่ม Social Features (Forum, Group Chat) เพื่อให้ผู้ใช้สามารถแลกเปลี่ยนความรู้และช่วยเหลือกัน
#
# **ขั้นตอนที่ 3: การตลาดและการสื่อสาร (เดือนที่ 2-6)**
#
# *   **Action Items:**
#     *   **ปรับปรุง Onboarding Process (2 สัปดาห์):**
#         *   **KPI:** Completion Rate ของ Onboarding Process, Conversion Rate จาก Trial User เป็น Paid User
#         *   **ผู้รับผิดชอบ:** Designer 1 คน, Developer 1 คน
#         *   **รายละเอียด:** ทำให้ Onboarding Process เข้าใจง่ายและน่าสนใจ, เน้นประโยชน์ที่ผู้ใช้จะได้รับ, ให้คำแนะนำในการใช้งาน Feature ต่างๆ
#     *   **Email Marketing (ต่อเนื่อง):**
#         *   **KPI:** Open Rate, Click-Through Rate, Conversion Rate
#         *   **ผู้รับผิดชอบ:** (อาจจ้าง Freelancer Marketing Specialist)
#         *   **รายละเอียด:** ส่ง Email ที่มีเนื้อหาที่น่าสนใจและเกี่ยวข้องกับผู้ใช้แต่ละกลุ่ม, แจ้งข่าวสารเกี่ยวกับเนื้อหาใหม่, โปรโมชั่น, และกิจกรรมต่างๆ
#     *   **Push Notifications (ต่อเนื่อง):**
#         *   **KPI:** Click-Through Rate, Conversion Rate
#         *   **ผู้รับผิดชอบ:** Developer 1 คน
#         *   **รายละเอียด:** ส่ง Push Notifications ที่มีเนื้อหาที่น่าสนใจและเกี่ยวข้องกับผู้ใช้แต่ละกลุ่ม, เตือนให้ผู้ใช้กลับมาเรียนรู้, แจ้งข่าวสารเกี่ยวกับเนื้อหาใหม่
#     *   **Social Media Marketing (ต่อเนื่อง):**
#         *   **KPI:** Engagement Rate, Reach, Website Traffic
#         *   **ผู้รับผิดชอบ:** (อาจจ้าง Freelancer Marketing Specialist)
#         *   **รายละเอียด:** สร้าง Content ที่น่าสนใจและเกี่ยวข้องกับผู้ใช้, โปรโมทแอปบน Social Media, จัดกิจกรรมต่างๆ เพื่อดึงดูดผู้ใช้ใหม่
#     *   **Referral Program (เดือนที่ 4):**
#         *   **KPI:** จำนวนผู้ใช้ใหม่ที่มาจาก Referral Program
#         *   **ผู้รับผิดชอบ:** Developer 1 คน, Designer 1 คน
#         *   **รายละเอียด:** สร้าง Referral Program ที่ให้รางวัลแก่ผู้ใช้ที่แนะนำเพื่อนมาใช้งานแอป
#
# **ขั้นตอนที่ 4: การวัดผลและปรับปรุง (เดือนที่ 5-6)**
#
# *   **Action Items:**
#     *   **ติดตาม KPIs อย่างสม่ำเสมอ (ต่อเนื่อง):**
#         *   **KPI:** Retention Rate, Content Satisfaction Score, UI/UX Satisfaction Score, Engagement Rate, Conversion Rate
#         *   **ผู้รับผิดชอบ:** ทีมทั้งหมด
#         *   **รายละเอียด:** ติดตาม KPIs อย่างสม่ำเสมอเพื่อวัดผลการดำเนินงาน, วิเคราะห์ข้อมูลเพื่อหาจุดที่ต้องปรับปรุง
#     *   **ปรับปรุงแผนการดำเนินงานตามผลการวัด (ต่อเนื่อง):**
#         *   **KPI:** Improvement in KPIs
#         *   **ผู้รับผิดชอบ:** ทีมทั้งหมด
#         *   **รายละเอียด:** ปรับปรุงแผนการดำเนินงานตามผลการวัด, ทดลองแนวทางใหม่ๆ เพื่อเพิ่ม Retention Rate
#
# **การจัดสรรงบประมาณ (โดยประมาณ):**
#
# *   **Freelancer (Content Creator, Marketing Specialist):** 500,000 บาท
# *   **Marketing (Advertising, Social Media):** 500,000 บาท
# *   **Software/Tools (Analytics, Marketing Automation):** 200,000 บาท
# *   **ค่าใช้จ่ายอื่นๆ (Research, User Testing):** 100,000 บาท
# *   **สำรอง:** 700,000 บาท
#
# **ความเสี่ยงและแผนสำรอง:**
#
# *   **ความเสี่ยง:** การปรับปรุงเนื้อหาและประสบการณ์ผู้ใช้อาจไม่ตรงกับความต้องการของผู้ใช้
#     *   **แผนสำรอง:** ทำ User Testing อย่างสม่ำเสมอเพื่อรับฟังความคิดเห็นของผู้ใช้และปรับปรุงแผนการดำเนินงาน
# *   **ความเสี่ยง:** การตลาดและการสื่อสารอาจไม่ได้ผล
#     *   **แผนสำรอง:** ปรับปรุงกลยุทธ์การตลาดและการสื่อสาร, ทดลองช่องทางใหม่ๆ
#
# **KPIs หลัก:**
#
# *   **Retention Rate (เป้าหมาย: 40% ภายใน 6 เดือน)**
# *   **Content Satisfaction Score**
# *   **UI/UX Satisfaction Score**
# *   **Engagement Rate**
# *   **Conversion Rate**
#
# **หมายเหตุ:** แผนนี้เป็นเพียงแนวทางเบื้องต้น ทีมงานต้องปรับปรุงแผนให้เหมาะสมกับสถานการณ์จริงและผลการวัดผลอย่างสม่ำเสมอ การจ้าง Freelancer ที่มีความเชี่ยวชาญในด้านต่างๆ จะช่วยให้การดำเนินงานมีประสิทธิภาพมากยิ่งขึ้น
#
#
# 📌 Stage 6: Comprehensive Evaluation
# SCORES:
# - feasibility: 7/10 - การเพิ่ม retention rate จาก 15% เป็น 40% ภายใน 6 เดือนด้วยงบประมาณและทีมงานที่มีอยู่ค่อนข้างท้าทาย แม้แผนจะดูครอบคลุม แต่การดำเนินการจริงอาจต้องเผชิญกับข้อจำกัดหลายอย่าง เช่น การหา Freelancer ที่มีคุณภาพในงบประมาณที่จำกัด
# - completeness: 8/10 - แผนค่อนข้างครบถ้วน ครอบคลุมทั้งการวิเคราะห์, ปรับปรุงเนื้อหาและ UX/UI, การตลาด, และการวัดผล มีการระบุ KPIs และผู้รับผิดชอบชัดเจน
# - practicality: 8/10 - Action items ส่วนใหญ่ปฏิบัติได้จริง มีการแบ่งระยะเวลาและผู้รับผิดชอบชัดเจน แต่บาง Action items อาจต้องใช้เวลามากกว่าที่กำหนด เช่น การปรับปรุงเนื้อหาทั้งหมด
# - innovation: 6/10 - แผนไม่ได้มีแนวคิดที่แปลกใหม่มากนัก เป็นการผสมผสานแนวทางที่ใช้กันทั่วไปในการเพิ่ม retention rate แต่ก็มีการนำ Gamification และ Social Features มาใช้ซึ่งเป็นสิ่งที่น่าสนใจ
# - risk_management: 7/10 - มีการระบุความเสี่ยงและแผนสำรอง แต่แผนสำรองยังค่อนข้างกว้างและอาจต้องลงรายละเอียดมากกว่านี้ เช่น หากการปรับปรุงเนื้อหาไม่ตรงกับความต้องการของผู้ใช้ จะมีกระบวนการในการปรับปรุงเนื้อหาอย่างไร
#
# OVERALL: 7/10
#
# STRENGTHS:
# - แผนมีความครอบคลุมและเป็นระบบ
# - มีการระบุ KPIs และผู้รับผิดชอบชัดเจน
# - มีการพิจารณาความเสี่ยงและแผนสำรอง
# - มีการจัดสรรงบประมาณอย่างคร่าวๆ
#
# WEAKNESSES:
# - เป้าหมาย retention rate ที่ 40% ภายใน 6 เดือน อาจท้าทายเกินไป
# - แผนสำรองยังค่อนข้างกว้างและอาจต้องลงรายละเอียดมากกว่านี้
# - การจัดสรรงบประมาณอาจต้องปรับเปลี่ยนตามสถานการณ์จริง
# - การพึ่งพา Freelancer อาจทำให้การควบคุมคุณภาพเป็นไปได้ยาก
#
# SUGGESTIONS:
# - ควรตั้งเป้าหมาย retention rate ที่สมเหตุสมผลมากขึ้น อาจเริ่มต้นด้วยเป้าหมายที่ต่ำกว่า 40% ก่อน
# - ควรลงรายละเอียดในแผนสำรองให้มากขึ้น เช่น หากการปรับปรุงเนื้อหาไม่ตรงกับความต้องการของผู้ใช้ จะมีกระบวนการในการปรับปรุงเนื้อหาอย่างไร
# - ควรมีการประเมินผลการดำเนินงานอย่างสม่ำเสมอและปรับแผนตามความเหมาะสม
# - ควรพิจารณาการใช้เครื่องมือ analytics ที่มีประสิทธิภาพเพื่อติดตามพฤติกรรมผู้ใช้และวัดผลการดำเนินงาน
# - ควรมีการสื่อสารภายในทีมอย่างสม่ำเสมอเพื่อให้ทุกคนเข้าใจเป้าหมายและแผนการดำเนินงาน
# - ควรมีการทำ User Testing อย่างสม่ำเสมอเพื่อรับฟังความคิดเห็นของผู้ใช้และปรับปรุงผลิตภัณฑ์

# %% [markdown]
# ---
# # 📝 Summary & Comprehensive Cheat Sheet
#
# ---
#
# ## 🗺️ Technique Selection Decision Tree
#
# ```
# ╔══════════════════════════════════════════════════════════════════╗
# ║         🎯 TECHNIQUE SELECTION DECISION TREE                    ║
# ╠══════════════════════════════════════════════════════════════════╣
# ║                                                                  ║
# ║  What type of task?                                              ║
# ║  │                                                               ║
# ║  ├─▶ Simple format/classification → Few-shot ⭐                  ║
# ║  │                                                               ║
# ║  ├─▶ Requires reasoning/math?                                   ║
# ║  │   ├─▶ Low stakes → CoT ⭐⭐                                   ║
# ║  │   └─▶ High stakes → Self-Consistency CoT ⭐⭐⭐                ║
# ║  │                                                               ║
# ║  ├─▶ Complex multi-step task?                                   ║
# ║  │   └─▶ Prompt Chaining ⭐⭐⭐                                   ║
# ║  │                                                               ║
# ║  ├─▶ Need to explore multiple approaches?                       ║
# ║  │   └─▶ Tree-of-Thought ⭐⭐⭐⭐⭐                                ║
# ║  │                                                               ║
# ║  ├─▶ Want to improve quality iteratively?                       ║
# ║  │   ├─▶ General improvement → Reflection ⭐⭐⭐⭐                 ║
# ║  │   ├─▶ Criteria-based → Self-Feedback ⭐⭐⭐⭐                   ║
# ║  │   └─▶ Find all flaws → Self-Critique ⭐⭐⭐⭐⭐                 ║
# ║  │                                                               ║
# ║  └─▶ Need evaluation?                                           ║
# ║      ├─▶ Single output → LLM-as-Judge                           ║
# ║      ├─▶ Compare options → Pairwise Comparison                  ║
# ║      ├─▶ No reference → Reference-free                          ║
# ║      ├─▶ With reference → BLEU/ROUGE                            ║
# ║      ├─▶ Check facts → Hallucination Detection                  ║
# ║      └─▶ Multiple perspectives → Multi-Agent Debate             ║
# ╚══════════════════════════════════════════════════════════════════╝
# ```
#
# ## 📊 เทคนิคและเมื่อไหร่ควรใช้:
#
# | เทคนิค | ใช้เมื่อ | ความซับซ้อน | API Calls | Cost |
# |--------|---------|------------|-----------|------|
# | Few-shot | ต้องการ format เฉพาะ | ⭐ | 1 | ต่ำ |
# | Chain-of-Thought | ปัญหาต้องใช้เหตุผล | ⭐⭐ | 1 | ต่ำ |
# | Self-Consistency | ต้องการความมั่นใจ | ⭐⭐⭐ | N (3-10) | กลาง |
# | Prompt Chaining | งานซับซ้อนหลายขั้นตอน | ⭐⭐⭐ | K steps | กลาง |
# | Reflection | ต้องการปรับปรุงคำตอบ | ⭐⭐⭐⭐ | 3 | กลาง |
# | Tree-of-Thought | ปัญหามีหลายทางเลือก | ⭐⭐⭐⭐⭐ | 3-5 | สูง |
# | Self-Feedback | ต้องการประเมินตามเกณฑ์ | ⭐⭐⭐⭐ | 3 | กลาง |
# | Self-Critique | ต้องการหาจุดอ่อน | ⭐⭐⭐⭐⭐ | 4-6 | สูง |
#
# ## 📊 Evaluation Methods:
#
# | วิธี | ต้องการ Reference? | Scalable? | Best For |
# |------|-------------------|-----------|----------|
# | LLM-as-a-Judge | ❌ | ✅ | General quality |
# | Pairwise Comparison | ❌ | ✅ | Comparing 2 options |
# | Reference-free | ❌ | ✅ | Open-ended tasks |
# | BLEU | ✅ | ✅ | Translation |
# | ROUGE | ✅ | ✅ | Summarization |
# | Semantic Similarity | ❌ | ✅ | Meaning comparison |
# | Hallucination Detection | ❌ | ✅ | Factual accuracy |
# | Multi-Agent Debate | ❌ | ⚠️ | Diverse perspectives |
# | Human Evaluation | ❌ | ❌ | Gold standard |

# %% [markdown]
# ---
# # 🏁 End of Lab
#
# ## 📚 แหล่งเรียนรู้เพิ่มเติม:
#
# ### Core Papers:
# - [Brown et al. (2020) - "Language Models are Few-Shot Learners"](https://arxiv.org/abs/2005.14165)
# - [Wei et al. (2022) - "Chain-of-Thought Prompting"](https://arxiv.org/abs/2201.11903)
# - [Wang et al. (2023) - "Self-Consistency Improves CoT"](https://arxiv.org/abs/2203.11171)
# - [Yao et al. (2023) - "Tree of Thoughts"](https://arxiv.org/abs/2305.10601)
# - [Madaan et al. (2023) - "Self-Refine"](https://arxiv.org/abs/2303.17651)
# - [Shinn et al. (2023) - "Reflexion"](https://arxiv.org/abs/2303.11366)
# - [Zheng et al. (2023) - "Judging LLM-as-a-Judge"](https://arxiv.org/abs/2306.05685)
#
# ### Guides & Documentation:
# - [Google AI Documentation](https://ai.google.dev/)
# - [Prompt Engineering Guide](https://www.promptingguide.ai/)
# - [Anthropic Prompt Engineering Guide](https://docs.anthropic.com/claude/docs/prompt-engineering)
#
# ## ✅ สิ่งที่ได้เรียนรู้:
# 1. ✅ เทคนิค Prompt Engineering 8 เทคนิค พร้อมทฤษฎีเชิงลึก
# 2. ✅ วิธี Evaluation 8+ วิธี (LLM-based + Automated Metrics)
# 3. ✅ การเลือกเทคนิคที่เหมาะสมกับปัญหา (Decision Tree)
# 4. ✅ การรวมเทคนิคเพื่อแก้ปัญหาซับซ้อน (Final Challenge)
# 5. ✅ Bias awareness ใน LLM evaluation
# 6. ✅ Best practices สำหรับ production use
#
# **Happy Prompting! 🎉**
# ```
#
# ---
#
# # 📋 สรุป Lab Structure (Enhanced)
#
# | Part | หัวข้อ | ระดับ | Theory | Infographic | Evaluation |
# |------|--------|-------|--------|-------------|------------|
# | 0 | Setup & Fundamentals | 🟢 | API & LLM Pipeline | ✅ Temperature, Architecture | - |
# | 1 | Few-shot Prompting | ⭐ | Shot types, Design principles | ✅ Shot Spectrum | Sensitivity Analysis |
# | 2 | Chain-of-Thought | ⭐⭐ | CoT mechanism, Trigger phrases | ✅ CoT vs Standard | When to use |
# | 3 | Self-Consistency CoT | ⭐⭐⭐ | Voting strategies, Parameters | ✅ SC mechanism | Consistency Score |
# | 4 | Prompt Chaining | ⭐⭐⭐ | Chaining patterns, Benefits | ✅ 4 patterns | Per-step validation |
# | 5 | Reflection | ⭐⭐⭐⭐ | Reflection cycle, Research | ✅ Cycle diagram | Iteration tracking |
# | 6 | Tree-of-Thought | ⭐⭐⭐⭐⭐ | ToT architecture, BFS/DFS | ✅ Tree structure | Branch scoring |
# | 7 | Self-Feedback | ⭐⭐⭐⭐ | Criteria-based assessment | ✅ vs Reflection | Score progression |
# | 8 | Self-Critique | ⭐⭐⭐⭐⭐ | Intensity spectrum, Checklist | ✅ Spectrum diagram | Adversarial rounds |
# | 9 | Evaluation Methods (Extended) | ⭐⭐⭐ | Taxonomy, Biases | ✅ Full taxonomy | **8 methods** |
# | 10 | Comprehensive Framework | ⭐⭐⭐⭐ | Architecture | ✅ Pipeline diagram | Combined report |
# | 11 | Final Challenge | ⭐⭐⭐⭐⭐ | Decision Tree | ✅ Challenge pipeline | Full pipeline |
#
# ## 🆕 New Evaluation Techniques Added:
# 1. **BLEU Score** — n-gram precision (translation/generation)
# 2. **ROUGE Score** — ROUGE-1, ROUGE-2, ROUGE-L (summarization)
# 3. **Semantic Similarity** — LLM-based meaning comparison
# 4. **Hallucination Detection** — Dedicated fact-checking
# 5. **Multi-Agent Debate** — Multiple persona evaluation
# 6. **Position-Debiased Pairwise** — Bias-mitigated comparison
# 7. **Sensitivity Analysis** — Few-shot example count impact
# 8. **Comprehensive Report Generation** — Aggregated quality report
